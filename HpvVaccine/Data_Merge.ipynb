# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

import plotly.express as px

from scipy import stats

import seaborn as sns

plt.rcParams['font.family']=['Times New Roman']

# %%
# Read Hpv data
file_address = '../Data/NassauCountyHPV.csv'

df_hpv_nassau = pd.read_csv(file_address)

file_address = '../Data/SuffolkCountyHPV.csv'

df_hpv_suffolk = pd.read_csv(file_address)

# Read TDAP data
file_address = '../Data/NassauCountyTDAP.csv'

df_tdap_nassau = pd.read_csv(file_address)

file_address = '../Data/SuffolkCountyTDAP.csv'

df_tdap_suffolk = pd.read_csv(file_address)

# %%
file_address = '../Data/2022_2023Data/NassauCountyHPV2022_23.xlsx'

df_hpv_nassau_22 = pd.read_excel(file_address)

file_address = '../Data/2022_2023Data/NassauCountyTDAP2022_23.xlsx'

df_tdap_nassau_22 = pd.read_excel(file_address)


file_address = '../Data/2022_2023Data/SuffolkCountyHPV2022_23.xlsx'

df_hpv_suffolk_22 = pd.read_excel(file_address)

file_address = '../Data/2022_2023Data/SuffolkCountyTDAP2022_23.xlsx'

df_tdap_suffolk_22 = pd.read_excel(file_address)

# %%
len(df_tdap_nassau_22)+len(df_hpv_nassau_22)
# Out:
# 188548

# %%
len(df_tdap_suffolk_22)+len(df_hpv_suffolk_22)
# Out:
# 132455

# %% [markdown]
# # Merge New Data

# %%
df_hpv_n = pd.concat([df_hpv_nassau,df_hpv_nassau_22])

# %%
df_tdap_n = pd.concat([df_tdap_nassau,df_tdap_nassau_22])

# %%
df_tdap_s = pd.concat([df_tdap_suffolk,df_tdap_suffolk_22])
df_hpv_s = pd.concat([df_hpv_suffolk,df_hpv_suffolk_22])

# %%
df_hpv_n.to_excel('../Data/Merged_data/NassauCountyHPV.xlsx',index = False)

# %%
df_hpv_s.to_excel('../Data/Merged_data/SuffolkCountyHPV.xlsx',index = False)

# %%
df_tdap_n.to_excel('../Data/Merged_data/NassauCountyTDAP.xlsx',index = False)

# %%
df_tdap_s.to_excel('../Data/Merged_data/SuffolkCountyTDAP.xlsx',index = False)

# %% [markdown]
# # Unique HPV Patients Data Generated

# %%
# Rename:

df_hpv_nassau = df_hpv_n
df_hpv_suffolk = df_hpv_s
df_tdap_nassau = df_tdap_n
df_tdap_suffolk = df_tdap_s

# %%
file_address = '../Data/longislandzip.csv'

df_zipcode = pd.read_csv(file_address)

# %%
# Clean Data , drop N/A zipcode
df_hpv_nassau.dropna(subset=['PatientZip'], inplace=True)
df_hpv_suffolk.dropna(subset=['PatientZip'], inplace=True)
df_tdap_nassau.dropna(subset=['PatientZip'], inplace=True)
df_tdap_suffolk.dropna(subset=['PatientZip'], inplace=True)


zips = np.array(df_zipcode['zip'])
# Clean Data, drop zipcode not on the Long Island
df_hpv_nassau = df_hpv_nassau[df_hpv_nassau['PatientZip'].isin(zips)]
df_hpv_suffolk = df_hpv_suffolk[df_hpv_suffolk['PatientZip'].isin(zips)]
df_tdap_nassau = df_tdap_nassau[df_tdap_nassau['PatientZip'].isin(zips)]
df_tdap_suffolk = df_tdap_suffolk[df_tdap_suffolk['PatientZip'].isin(zips)]

df_tdap = pd.concat([df_tdap_nassau,df_tdap_suffolk])

# %%
# Aggregate and prepare for the table generated
df_tdap=pd.concat([df_tdap_nassau,df_tdap_suffolk])
df_hpv = pd.concat([df_hpv_nassau,df_hpv_suffolk])
df=pd.concat([df_hpv_nassau,df_hpv_suffolk,df_tdap_nassau,df_tdap_suffolk])

df_tdap = df_tdap.sort_values(by=['vax_year','vax_month'],ascending=True)
df_hpv = df_hpv.sort_values(by=['vax_year','vax_month'],ascending=True)
df=df.sort_values(by=['vax_year','vax_month'],ascending=True)


df_tdap_distinct = df_tdap.drop_duplicates(subset=['client_id'], keep='first')
df_distinct = df.drop_duplicates(subset=['client_id'], keep='first')
df_hpv_distinct = df_hpv.drop_duplicates(subset = ['client_id'],keep='first')


df_hpv_distinct= df_hpv_distinct.reset_index()
df_distinct= df_distinct.reset_index()
df_tdap_distinct = df_tdap_distinct.reset_index()

# %%
len(df_distinct)
# Out:
# 1120113

# %%
years = [2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021,2022,2023]

# %%
#Total Table Generated

tdap_table = pd.DataFrame(columns=['client_id', 'RACE_DESC', 'ETHNICITY_DESC','PatientZip','PatientCounty','GENDER',
                                   2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015,
                                   2016, 2017, 2018, 2019, 2020, 2021,2022,2023])
cur = 0
batches = len(df_tdap_distinct)//1100
for i in range(1101):
    tmp_df = df_tdap_distinct.iloc[cur:cur+batches]
    final = cur + batches
    if final > len(df_tdap_distinct):
        final = len(df_tdap_distinct)
    for j in range(cur,final):
        tmp = {}
        tmp['client_id'] = df_tdap_distinct['client_id'][j]
        tmp['ETHNICITY_DESC'] = df_tdap_distinct['ETHNICITY_DESC'][j]
        tmp['RACE_DESC'] = df_tdap_distinct['RACE_DESC'][j]
        tmp['PatientZip'] = df_tdap_distinct['PatientZip'][j]
        tmp['GENDER'] = df_tdap_distinct['GENDER'][j]
        tmp['PatientCounty'] = df_tdap_distinct['PatientCounty'][j]
        vax_year = df_tdap_distinct['vax_year'][j]
        vax_age = df_tdap_distinct['PatientAge'][j]
        for year in years:
            if year<vax_year:
                tmp[year] = np.nan
            else:
                tmp[year] = vax_age
                vax_age += 1
    #     print(tmp)
        tmp_df = pd.DataFrame([tmp])
        tdap_table = pd.concat([tdap_table, tmp_df], ignore_index=True)
    tdap_table.to_csv('../Data/Merged_data/AgeOut_tdap.csv', mode='a', header=(i==0), index=False)
    cur += batches
    print('complete batch',i,'add data',len(tdap_table),'rows')
    tdap_table = tdap_table.iloc[0:0]

print(cur,final)
# Out:
# complete batch 0 add data 950 rows
# complete batch 1 add data 950 rows
# complete batch 2 add data 950 rows
# complete batch 3 add data 950 rows
# complete batch 4 add data 950 rows
# complete batch 5 add data 950 rows
# complete batch 6 add data 950 rows
# complete batch 7 add data 950 rows
# complete batch 8 add data 950 rows
# complete batch 9 add data 950 rows
# complete batch 10 add data 950 rows
# complete batch 11 add data 950 rows
# complete batch 12 add data 950 rows
# complete batch 13 add data 950 rows
# complete batch 14 add data 950 rows
# complete batch 15 add data 950 rows
# complete batch 16 add data 950 rows
# complete batch 17 add data 950 rows
# complete batch 18 add data 950 rows
# complete batch 19 add data 950 rows
# complete batch 20 add data 950 rows
# complete batch 21 add data 950 rows
# complete batch 22 add data 950 rows
# complete batch 23 add data 950 rows
# complete batch 24 add data 950 rows
# complete batch 25 add data 950 rows
# complete batch 26 add data 950 rows
# complete batch 27 add data 950 rows
# complete batch 28 add data 950 rows
# complete batch 29 add data 950 rows
# complete batch 30 add data 950 rows
# complete batch 31 add data 950 rows
# complete batch 32 add data 950 rows
# complete batch 33 add data 950 rows
# complete batch 34 add data 950 rows
# complete batch 35 add data 950 rows
# complete batch 36 add data 950 rows
# complete batch 37 add data 950 rows
# complete batch 38 add data 950 rows
# complete batch 39 add data 950 rows
# complete batch 40 add data 950 rows
# complete batch 41 add data 950 rows
# complete batch 42 add data 950 rows
# complete batch 43 add data 950 rows
# complete batch 44 add data 950 rows
# complete batch 45 add data 950 rows
# complete batch 46 add data 950 rows
# complete batch 47 add data 950 rows
# complete batch 48 add data 950 rows
# complete batch 49 add data 950 rows
# complete batch 50 add data 950 rows
# complete batch 51 add data 950 rows
# complete batch 52 add data 950 rows
# complete batch 53 add data 950 rows
# complete batch 54 add data 950 rows
# complete batch 55 add data 950 rows
# complete batch 56 add data 950 rows
# complete batch 57 add data 950 rows
# complete batch 58 add data 950 rows
# complete batch 59 add data 950 rows
# complete batch 60 add data 950 rows
# complete batch 61 add data 950 rows
# complete batch 62 add data 950 rows
# complete batch 63 add data 950 rows
# complete batch 64 add data 950 rows
# complete batch 65 add data 950 rows
# complete batch 66 add data 950 rows
# complete batch 67 add data 950 rows
# complete batch 68 add data 950 rows
# complete batch 69 add data 950 rows
# complete batch 70 add data 950 rows
# complete batch 71 add data 950 rows
# complete batch 72 add data 950 rows
# complete batch 73 add data 950 rows
# complete batch 74 add data 950 rows
# complete batch 75 add data 950 rows
# complete batch 76 add data 950 rows
# complete batch 77 add data 950 rows
# complete batch 78 add data 950 rows
# complete batch 79 add data 950 rows
# complete batch 80 add data 950 rows
# complete batch 81 add data 950 rows
# complete batch 82 add data 950 rows
# complete batch 83 add data 950 rows
# complete batch 84 add data 950 rows
# complete batch 85 add data 950 rows
# complete batch 86 add data 950 rows
# complete batch 87 add data 950 rows
# complete batch 88 add data 950 rows
# complete batch 89 add data 950 rows
# complete batch 90 add data 950 rows
# complete batch 91 add data 950 rows
# complete batch 92 add data 950 rows
# complete batch 93 add data 950 rows
# complete batch 94 add data 950 rows
# complete batch 95 add data 950 rows
# complete batch 96 add data 950 rows
# complete batch 97 add data 950 rows
# complete batch 98 add data 950 rows
# complete batch 99 add data 950 rows
# complete batch 100 add data 950 rows
# complete batch 101 add data 950 rows
# complete batch 102 add data 950 rows
# complete batch 103 add data 950 rows
# complete batch 104 add data 950 rows
# complete batch 105 add data 950 rows
# complete batch 106 add data 950 rows
# complete batch 107 add data 950 rows
# complete batch 108 add data 950 rows
# complete batch 109 add data 950 rows
# complete batch 110 add data 950 rows
# complete batch 111 add data 950 rows
# complete batch 112 add data 950 rows
# complete batch 113 add data 950 rows
# complete batch 114 add data 950 rows
# complete batch 115 add data 950 rows
# complete batch 116 add data 950 rows
# complete batch 117 add data 950 rows
# complete batch 118 add data 950 rows
# complete batch 119 add data 950 rows
# complete batch 120 add data 950 rows
# complete batch 121 add data 950 rows
# complete batch 122 add data 950 rows
# complete batch 123 add data 950 rows
# complete batch 124 add data 950 rows
# complete batch 125 add data 950 rows
# complete batch 126 add data 950 rows
# complete batch 127 add data 950 rows
# complete batch 128 add data 950 rows
# complete batch 129 add data 950 rows
# complete batch 130 add data 950 rows
# complete batch 131 add data 950 rows
# complete batch 132 add data 950 rows
# complete batch 133 add data 950 rows
# complete batch 134 add data 950 rows
# complete batch 135 add data 950 rows
# complete batch 136 add data 950 rows
# complete batch 137 add data 950 rows
# complete batch 138 add data 950 rows
# complete batch 139 add data 950 rows
# complete batch 140 add data 950 rows
# complete batch 141 add data 950 rows
# complete batch 142 add data 950 rows
# complete batch 143 add data 950 rows
# complete batch 144 add data 950 rows
# complete batch 145 add data 950 rows
# complete batch 146 add data 950 rows
# complete batch 147 add data 950 rows
# complete batch 148 add data 950 rows
# complete batch 149 add data 950 rows
# complete batch 150 add data 950 rows
# complete batch 151 add data 950 rows
# complete batch 152 add data 950 rows
# complete batch 153 add data 950 rows
# complete batch 154 add data 950 rows
# complete batch 155 add data 950 rows
# complete batch 156 add data 950 rows
# complete batch 157 add data 950 rows
# complete batch 158 add data 950 rows
# complete batch 159 add data 950 rows
# complete batch 160 add data 950 rows
# complete batch 161 add data 950 rows
# complete batch 162 add data 950 rows
# complete batch 163 add data 950 rows
# complete batch 164 add data 950 rows
# complete batch 165 add data 950 rows
# complete batch 166 add data 950 rows
# complete batch 167 add data 950 rows
# complete batch 168 add data 950 rows
# complete batch 169 add data 950 rows
# complete batch 170 add data 950 rows
# complete batch 171 add data 950 rows
# complete batch 172 add data 950 rows
# complete batch 173 add data 950 rows
# complete batch 174 add data 950 rows
# complete batch 175 add data 950 rows
# complete batch 176 add data 950 rows
# complete batch 177 add data 950 rows
# complete batch 178 add data 950 rows
# complete batch 179 add data 950 rows
# complete batch 180 add data 950 rows
# complete batch 181 add data 950 rows
# complete batch 182 add data 950 rows
# complete batch 183 add data 950 rows
# complete batch 184 add data 950 rows
# complete batch 185 add data 950 rows
# complete batch 186 add data 950 rows
# complete batch 187 add data 950 rows
# complete batch 188 add data 950 rows
# complete batch 189 add data 950 rows
# complete batch 190 add data 950 rows
# complete batch 191 add data 950 rows
# complete batch 192 add data 950 rows
# complete batch 193 add data 950 rows
# complete batch 194 add data 950 rows
# complete batch 195 add data 950 rows
# complete batch 196 add data 950 rows
# complete batch 197 add data 950 rows
# complete batch 198 add data 950 rows
# complete batch 199 add data 950 rows
# complete batch 200 add data 950 rows
# complete batch 201 add data 950 rows
# complete batch 202 add data 950 rows
# complete batch 203 add data 950 rows
# complete batch 204 add data 950 rows
# complete batch 205 add data 950 rows
# complete batch 206 add data 950 rows
# complete batch 207 add data 950 rows
# complete batch 208 add data 950 rows
# complete batch 209 add data 950 rows
# complete batch 210 add data 950 rows
# complete batch 211 add data 950 rows
# complete batch 212 add data 950 rows
# complete batch 213 add data 950 rows
# complete batch 214 add data 950 rows
# complete batch 215 add data 950 rows
# complete batch 216 add data 950 rows
# complete batch 217 add data 950 rows
# complete batch 218 add data 950 rows
# complete batch 219 add data 950 rows
# complete batch 220 add data 950 rows
# complete batch 221 add data 950 rows
# complete batch 222 add data 950 rows
# complete batch 223 add data 950 rows
# complete batch 224 add data 950 rows
# complete batch 225 add data 950 rows
# complete batch 226 add data 950 rows
# complete batch 227 add data 950 rows
# complete batch 228 add data 950 rows
# complete batch 229 add data 950 rows
# complete batch 230 add data 950 rows
# complete batch 231 add data 950 rows
# complete batch 232 add data 950 rows
# complete batch 233 add data 950 rows
# complete batch 234 add data 950 rows
# complete batch 235 add data 950 rows
# complete batch 236 add data 950 rows
# complete batch 237 add data 950 rows
# complete batch 238 add data 950 rows
# complete batch 239 add data 950 rows
# complete batch 240 add data 950 rows
# complete batch 241 add data 950 rows
# complete batch 242 add data 950 rows
# complete batch 243 add data 950 rows
# complete batch 244 add data 950 rows
# complete batch 245 add data 950 rows
# complete batch 246 add data 950 rows
# complete batch 247 add data 950 rows
# complete batch 248 add data 950 rows
# complete batch 249 add data 950 rows
# complete batch 250 add data 950 rows
# complete batch 251 add data 950 rows
# complete batch 252 add data 950 rows
# complete batch 253 add data 950 rows
# complete batch 254 add data 950 rows
# complete batch 255 add data 950 rows
# complete batch 256 add data 950 rows
# complete batch 257 add data 950 rows
# complete batch 258 add data 950 rows
# complete batch 259 add data 950 rows
# complete batch 260 add data 950 rows
# complete batch 261 add data 950 rows
# complete batch 262 add data 950 rows
# complete batch 263 add data 950 rows
# complete batch 264 add data 950 rows
# complete batch 265 add data 950 rows
# complete batch 266 add data 950 rows
# complete batch 267 add data 950 rows
# complete batch 268 add data 950 rows
# complete batch 269 add data 950 rows
# complete batch 270 add data 950 rows
# complete batch 271 add data 950 rows
# complete batch 272 add data 950 rows
# complete batch 273 add data 950 rows
# complete batch 274 add data 950 rows
# complete batch 275 add data 950 rows
# complete batch 276 add data 950 rows
# complete batch 277 add data 950 rows
# complete batch 278 add data 950 rows
# complete batch 279 add data 950 rows
# complete batch 280 add data 950 rows
# complete batch 281 add data 950 rows
# complete batch 282 add data 950 rows
# complete batch 283 add data 950 rows
# complete batch 284 add data 950 rows
# complete batch 285 add data 950 rows
# complete batch 286 add data 950 rows
# complete batch 287 add data 950 rows
# complete batch 288 add data 950 rows
# complete batch 289 add data 950 rows
# complete batch 290 add data 950 rows
# complete batch 291 add data 950 rows
# complete batch 292 add data 950 rows
# complete batch 293 add data 950 rows
# complete batch 294 add data 950 rows
# complete batch 295 add data 950 rows
# complete batch 296 add data 950 rows
# complete batch 297 add data 950 rows
# complete batch 298 add data 950 rows
# complete batch 299 add data 950 rows
# complete batch 300 add data 950 rows
# complete batch 301 add data 950 rows
# complete batch 302 add data 950 rows
# complete batch 303 add data 950 rows
# complete batch 304 add data 950 rows
# complete batch 305 add data 950 rows
# complete batch 306 add data 950 rows
# complete batch 307 add data 950 rows
# complete batch 308 add data 950 rows
# complete batch 309 add data 950 rows
# complete batch 310 add data 950 rows
# complete batch 311 add data 950 rows
# complete batch 312 add data 950 rows
# complete batch 313 add data 950 rows
# complete batch 314 add data 950 rows
# complete batch 315 add data 950 rows
# complete batch 316 add data 950 rows
# complete batch 317 add data 950 rows
# complete batch 318 add data 950 rows
# complete batch 319 add data 950 rows
# complete batch 320 add data 950 rows
# complete batch 321 add data 950 rows
# complete batch 322 add data 950 rows
# complete batch 323 add data 950 rows
# complete batch 324 add data 950 rows
# complete batch 325 add data 950 rows
# complete batch 326 add data 950 rows
# complete batch 327 add data 950 rows
# complete batch 328 add data 950 rows
# complete batch 329 add data 950 rows
# complete batch 330 add data 950 rows
# complete batch 331 add data 950 rows
# complete batch 332 add data 950 rows
# complete batch 333 add data 950 rows
# complete batch 334 add data 950 rows
# complete batch 335 add data 950 rows
# complete batch 336 add data 950 rows
# complete batch 337 add data 950 rows
# complete batch 338 add data 950 rows
# complete batch 339 add data 950 rows
# complete batch 340 add data 950 rows
# complete batch 341 add data 950 rows
# complete batch 342 add data 950 rows
# complete batch 343 add data 950 rows
# complete batch 344 add data 950 rows
# complete batch 345 add data 950 rows
# complete batch 346 add data 950 rows
# complete batch 347 add data 950 rows
# complete batch 348 add data 950 rows
# complete batch 349 add data 950 rows
# complete batch 350 add data 950 rows
# complete batch 351 add data 950 rows
# complete batch 352 add data 950 rows
# complete batch 353 add data 950 rows
# complete batch 354 add data 950 rows
# complete batch 355 add data 950 rows
# complete batch 356 add data 950 rows
# complete batch 357 add data 950 rows
# complete batch 358 add data 950 rows
# complete batch 359 add data 950 rows
# complete batch 360 add data 950 rows
# complete batch 361 add data 950 rows
# complete batch 362 add data 950 rows
# complete batch 363 add data 950 rows
# complete batch 364 add data 950 rows
# complete batch 365 add data 950 rows
# complete batch 366 add data 950 rows
# complete batch 367 add data 950 rows
# complete batch 368 add data 950 rows
# complete batch 369 add data 950 rows
# complete batch 370 add data 950 rows
# complete batch 371 add data 950 rows
# complete batch 372 add data 950 rows
# complete batch 373 add data 950 rows
# complete batch 374 add data 950 rows
# complete batch 375 add data 950 rows
# complete batch 376 add data 950 rows
# complete batch 377 add data 950 rows
# complete batch 378 add data 950 rows
# complete batch 379 add data 950 rows
# complete batch 380 add data 950 rows
# complete batch 381 add data 950 rows
# complete batch 382 add data 950 rows
# complete batch 383 add data 950 rows
# complete batch 384 add data 950 rows
# complete batch 385 add data 950 rows
# complete batch 386 add data 950 rows
# complete batch 387 add data 950 rows
# complete batch 388 add data 950 rows
# complete batch 389 add data 950 rows
# complete batch 390 add data 950 rows
# complete batch 391 add data 950 rows
# complete batch 392 add data 950 rows
# complete batch 393 add data 950 rows
# complete batch 394 add data 950 rows
# complete batch 395 add data 950 rows
# complete batch 396 add data 950 rows
# complete batch 397 add data 950 rows
# complete batch 398 add data 950 rows
# complete batch 399 add data 950 rows
# complete batch 400 add data 950 rows
# complete batch 401 add data 950 rows
# complete batch 402 add data 950 rows
# complete batch 403 add data 950 rows
# complete batch 404 add data 950 rows
# complete batch 405 add data 950 rows
# complete batch 406 add data 950 rows
# complete batch 407 add data 950 rows
# complete batch 408 add data 950 rows
# complete batch 409 add data 950 rows
# complete batch 410 add data 950 rows
# complete batch 411 add data 950 rows
# complete batch 412 add data 950 rows
# complete batch 413 add data 950 rows
# complete batch 414 add data 950 rows
# complete batch 415 add data 950 rows
# complete batch 416 add data 950 rows
# complete batch 417 add data 950 rows
# complete batch 418 add data 950 rows
# complete batch 419 add data 950 rows
# complete batch 420 add data 950 rows
# complete batch 421 add data 950 rows
# complete batch 422 add data 950 rows
# complete batch 423 add data 950 rows
# complete batch 424 add data 950 rows
# complete batch 425 add data 950 rows
# complete batch 426 add data 950 rows
# complete batch 427 add data 950 rows
# complete batch 428 add data 950 rows
# complete batch 429 add data 950 rows
# complete batch 430 add data 950 rows
# complete batch 431 add data 950 rows
# complete batch 432 add data 950 rows
# complete batch 433 add data 950 rows
# complete batch 434 add data 950 rows
# complete batch 435 add data 950 rows
# complete batch 436 add data 950 rows
# complete batch 437 add data 950 rows
# complete batch 438 add data 950 rows
# complete batch 439 add data 950 rows
# complete batch 440 add data 950 rows
# complete batch 441 add data 950 rows
# complete batch 442 add data 950 rows
# complete batch 443 add data 950 rows
# complete batch 444 add data 950 rows
# complete batch 445 add data 950 rows
# complete batch 446 add data 950 rows
# complete batch 447 add data 950 rows
# complete batch 448 add data 950 rows
# complete batch 449 add data 950 rows
# complete batch 450 add data 950 rows
# complete batch 451 add data 950 rows
# complete batch 452 add data 950 rows
# complete batch 453 add data 950 rows
# complete batch 454 add data 950 rows
# complete batch 455 add data 950 rows
# complete batch 456 add data 950 rows
# complete batch 457 add data 950 rows
# complete batch 458 add data 950 rows
# complete batch 459 add data 950 rows
# complete batch 460 add data 950 rows
# complete batch 461 add data 950 rows
# complete batch 462 add data 950 rows
# complete batch 463 add data 950 rows
# complete batch 464 add data 950 rows
# complete batch 465 add data 950 rows
# complete batch 466 add data 950 rows
# complete batch 467 add data 950 rows
# complete batch 468 add data 950 rows
# complete batch 469 add data 950 rows
# complete batch 470 add data 950 rows
# complete batch 471 add data 950 rows
# complete batch 472 add data 950 rows
# complete batch 473 add data 950 rows
# complete batch 474 add data 950 rows
# complete batch 475 add data 950 rows
# complete batch 476 add data 950 rows
# complete batch 477 add data 950 rows
# complete batch 478 add data 950 rows
# complete batch 479 add data 950 rows
# complete batch 480 add data 950 rows
# complete batch 481 add data 950 rows
# complete batch 482 add data 950 rows
# complete batch 483 add data 950 rows
# complete batch 484 add data 950 rows
# complete batch 485 add data 950 rows
# complete batch 486 add data 950 rows
# complete batch 487 add data 950 rows
# complete batch 488 add data 950 rows
# complete batch 489 add data 950 rows
# complete batch 490 add data 950 rows
# complete batch 491 add data 950 rows
# complete batch 492 add data 950 rows
# complete batch 493 add data 950 rows
# complete batch 494 add data 950 rows
# complete batch 495 add data 950 rows
# complete batch 496 add data 950 rows
# complete batch 497 add data 950 rows
# complete batch 498 add data 950 rows
# complete batch 499 add data 950 rows
# complete batch 500 add data 950 rows
# complete batch 501 add data 950 rows
# complete batch 502 add data 950 rows
# complete batch 503 add data 950 rows
# complete batch 504 add data 950 rows
# complete batch 505 add data 950 rows
# complete batch 506 add data 950 rows
# complete batch 507 add data 950 rows
# complete batch 508 add data 950 rows
# complete batch 509 add data 950 rows
# complete batch 510 add data 950 rows
# complete batch 511 add data 950 rows
# complete batch 512 add data 950 rows
# complete batch 513 add data 950 rows
# complete batch 514 add data 950 rows
# complete batch 515 add data 950 rows
# complete batch 516 add data 950 rows
# complete batch 517 add data 950 rows
# complete batch 518 add data 950 rows
# complete batch 519 add data 950 rows
# complete batch 520 add data 950 rows
# complete batch 521 add data 950 rows
# complete batch 522 add data 950 rows
# complete batch 523 add data 950 rows
# complete batch 524 add data 950 rows
# complete batch 525 add data 950 rows
# complete batch 526 add data 950 rows
# complete batch 527 add data 950 rows
# complete batch 528 add data 950 rows
# complete batch 529 add data 950 rows
# complete batch 530 add data 950 rows
# complete batch 531 add data 950 rows
# complete batch 532 add data 950 rows
# complete batch 533 add data 950 rows
# complete batch 534 add data 950 rows
# complete batch 535 add data 950 rows
# complete batch 536 add data 950 rows
# complete batch 537 add data 950 rows
# complete batch 538 add data 950 rows
# complete batch 539 add data 950 rows
# complete batch 540 add data 950 rows
# complete batch 541 add data 950 rows
# complete batch 542 add data 950 rows
# complete batch 543 add data 950 rows
# complete batch 544 add data 950 rows
# complete batch 545 add data 950 rows
# complete batch 546 add data 950 rows
# complete batch 547 add data 950 rows
# complete batch 548 add data 950 rows
# complete batch 549 add data 950 rows
# complete batch 550 add data 950 rows
# complete batch 551 add data 950 rows
# complete batch 552 add data 950 rows
# complete batch 553 add data 950 rows
# complete batch 554 add data 950 rows
# complete batch 555 add data 950 rows
# complete batch 556 add data 950 rows
# complete batch 557 add data 950 rows
# complete batch 558 add data 950 rows
# complete batch 559 add data 950 rows
# complete batch 560 add data 950 rows
# complete batch 561 add data 950 rows
# complete batch 562 add data 950 rows
# complete batch 563 add data 950 rows
# complete batch 564 add data 950 rows
# complete batch 565 add data 950 rows
# complete batch 566 add data 950 rows
# complete batch 567 add data 950 rows
# complete batch 568 add data 950 rows
# complete batch 569 add data 950 rows
# complete batch 570 add data 950 rows
# complete batch 571 add data 950 rows
# complete batch 572 add data 950 rows
# complete batch 573 add data 950 rows
# complete batch 574 add data 950 rows
# complete batch 575 add data 950 rows
# complete batch 576 add data 950 rows
# complete batch 577 add data 950 rows
# complete batch 578 add data 950 rows
# complete batch 579 add data 950 rows
# complete batch 580 add data 950 rows
# complete batch 581 add data 950 rows
# complete batch 582 add data 950 rows
# complete batch 583 add data 950 rows
# complete batch 584 add data 950 rows
# complete batch 585 add data 950 rows
# complete batch 586 add data 950 rows
# complete batch 587 add data 950 rows
# complete batch 588 add data 950 rows
# complete batch 589 add data 950 rows
# complete batch 590 add data 950 rows
# complete batch 591 add data 950 rows
# complete batch 592 add data 950 rows
# complete batch 593 add data 950 rows
# complete batch 594 add data 950 rows
# complete batch 595 add data 950 rows
# complete batch 596 add data 950 rows
# complete batch 597 add data 950 rows
# complete batch 598 add data 950 rows
# complete batch 599 add data 950 rows
# complete batch 600 add data 950 rows
# complete batch 601 add data 950 rows
# complete batch 602 add data 950 rows
# complete batch 603 add data 950 rows
# complete batch 604 add data 950 rows
# complete batch 605 add data 950 rows
# complete batch 606 add data 950 rows
# complete batch 607 add data 950 rows
# complete batch 608 add data 950 rows
# complete batch 609 add data 950 rows
# complete batch 610 add data 950 rows
# complete batch 611 add data 950 rows
# complete batch 612 add data 950 rows
# complete batch 613 add data 950 rows
# complete batch 614 add data 950 rows
# complete batch 615 add data 950 rows
# complete batch 616 add data 950 rows
# complete batch 617 add data 950 rows
# complete batch 618 add data 950 rows
# complete batch 619 add data 950 rows
# complete batch 620 add data 950 rows
# complete batch 621 add data 950 rows
# complete batch 622 add data 950 rows
# complete batch 623 add data 950 rows
# complete batch 624 add data 950 rows
# complete batch 625 add data 950 rows
# complete batch 626 add data 950 rows
# complete batch 627 add data 950 rows
# complete batch 628 add data 950 rows
# complete batch 629 add data 950 rows
# complete batch 630 add data 950 rows
# complete batch 631 add data 950 rows
# complete batch 632 add data 950 rows
# complete batch 633 add data 950 rows
# complete batch 634 add data 950 rows
# complete batch 635 add data 950 rows
# complete batch 636 add data 950 rows
# complete batch 637 add data 950 rows
# complete batch 638 add data 950 rows
# complete batch 639 add data 950 rows
# complete batch 640 add data 950 rows
# complete batch 641 add data 950 rows
# complete batch 642 add data 950 rows
# complete batch 643 add data 950 rows
# complete batch 644 add data 950 rows
# complete batch 645 add data 950 rows
# complete batch 646 add data 950 rows
# complete batch 647 add data 950 rows
# complete batch 648 add data 950 rows
# complete batch 649 add data 950 rows
# complete batch 650 add data 950 rows
# complete batch 651 add data 950 rows
# complete batch 652 add data 950 rows
# complete batch 653 add data 950 rows
# complete batch 654 add data 950 rows
# complete batch 655 add data 950 rows
# complete batch 656 add data 950 rows
# complete batch 657 add data 950 rows
# complete batch 658 add data 950 rows
# complete batch 659 add data 950 rows
# complete batch 660 add data 950 rows
# complete batch 661 add data 950 rows
# complete batch 662 add data 950 rows
# complete batch 663 add data 950 rows
# complete batch 664 add data 950 rows
# complete batch 665 add data 950 rows
# complete batch 666 add data 950 rows
# complete batch 667 add data 950 rows
# complete batch 668 add data 950 rows
# complete batch 669 add data 950 rows
# complete batch 670 add data 950 rows
# complete batch 671 add data 950 rows
# complete batch 672 add data 950 rows
# complete batch 673 add data 950 rows
# complete batch 674 add data 950 rows
# complete batch 675 add data 950 rows
# complete batch 676 add data 950 rows
# complete batch 677 add data 950 rows
# complete batch 678 add data 950 rows
# complete batch 679 add data 950 rows
# complete batch 680 add data 950 rows
# complete batch 681 add data 950 rows
# complete batch 682 add data 950 rows
# complete batch 683 add data 950 rows
# complete batch 684 add data 950 rows
# complete batch 685 add data 950 rows
# complete batch 686 add data 950 rows
# complete batch 687 add data 950 rows
# complete batch 688 add data 950 rows
# complete batch 689 add data 950 rows
# complete batch 690 add data 950 rows
# complete batch 691 add data 950 rows
# complete batch 692 add data 950 rows
# complete batch 693 add data 950 rows
# complete batch 694 add data 950 rows
# complete batch 695 add data 950 rows
# complete batch 696 add data 950 rows
# complete batch 697 add data 950 rows
# complete batch 698 add data 950 rows
# complete batch 699 add data 950 rows
# complete batch 700 add data 950 rows
# complete batch 701 add data 950 rows
# complete batch 702 add data 950 rows
# complete batch 703 add data 950 rows
# complete batch 704 add data 950 rows
# complete batch 705 add data 950 rows
# complete batch 706 add data 950 rows
# complete batch 707 add data 950 rows
# complete batch 708 add data 950 rows
# complete batch 709 add data 950 rows
# complete batch 710 add data 950 rows
# complete batch 711 add data 950 rows
# complete batch 712 add data 950 rows
# complete batch 713 add data 950 rows
# complete batch 714 add data 950 rows
# complete batch 715 add data 950 rows
# complete batch 716 add data 950 rows
# complete batch 717 add data 950 rows
# complete batch 718 add data 950 rows
# complete batch 719 add data 950 rows
# complete batch 720 add data 950 rows
# complete batch 721 add data 950 rows
# complete batch 722 add data 950 rows
# complete batch 723 add data 950 rows
# complete batch 724 add data 950 rows
# complete batch 725 add data 950 rows
# complete batch 726 add data 950 rows
# complete batch 727 add data 950 rows
# complete batch 728 add data 950 rows
# complete batch 729 add data 950 rows
# complete batch 730 add data 950 rows
# complete batch 731 add data 950 rows
# complete batch 732 add data 950 rows
# complete batch 733 add data 950 rows
# complete batch 734 add data 950 rows
# complete batch 735 add data 950 rows
# complete batch 736 add data 950 rows
# complete batch 737 add data 950 rows
# complete batch 738 add data 950 rows
# complete batch 739 add data 950 rows
# complete batch 740 add data 950 rows
# complete batch 741 add data 950 rows
# complete batch 742 add data 950 rows
# complete batch 743 add data 950 rows
# complete batch 744 add data 950 rows
# complete batch 745 add data 950 rows
# complete batch 746 add data 950 rows
# complete batch 747 add data 950 rows
# complete batch 748 add data 950 rows
# complete batch 749 add data 950 rows
# complete batch 750 add data 950 rows
# complete batch 751 add data 950 rows
# complete batch 752 add data 950 rows
# complete batch 753 add data 950 rows
# complete batch 754 add data 950 rows
# complete batch 755 add data 950 rows
# complete batch 756 add data 950 rows
# complete batch 757 add data 950 rows
# complete batch 758 add data 950 rows
# complete batch 759 add data 950 rows
# complete batch 760 add data 950 rows
# complete batch 761 add data 950 rows
# complete batch 762 add data 950 rows
# complete batch 763 add data 950 rows
# complete batch 764 add data 950 rows
# complete batch 765 add data 950 rows
# complete batch 766 add data 950 rows
# complete batch 767 add data 950 rows
# complete batch 768 add data 950 rows
# complete batch 769 add data 950 rows
# complete batch 770 add data 950 rows
# complete batch 771 add data 950 rows
# complete batch 772 add data 950 rows
# complete batch 773 add data 950 rows
# complete batch 774 add data 950 rows
# complete batch 775 add data 950 rows
# complete batch 776 add data 950 rows
# complete batch 777 add data 950 rows
# complete batch 778 add data 950 rows
# complete batch 779 add data 950 rows
# complete batch 780 add data 950 rows
# complete batch 781 add data 950 rows
# complete batch 782 add data 950 rows
# complete batch 783 add data 950 rows
# complete batch 784 add data 950 rows
# complete batch 785 add data 950 rows
# complete batch 786 add data 950 rows
# complete batch 787 add data 950 rows
# complete batch 788 add data 950 rows
# complete batch 789 add data 950 rows
# complete batch 790 add data 950 rows
# complete batch 791 add data 950 rows
# complete batch 792 add data 950 rows
# complete batch 793 add data 950 rows
# complete batch 794 add data 950 rows
# complete batch 795 add data 950 rows
# complete batch 796 add data 950 rows
# complete batch 797 add data 950 rows
# complete batch 798 add data 950 rows
# complete batch 799 add data 950 rows
# complete batch 800 add data 950 rows
# complete batch 801 add data 950 rows
# complete batch 802 add data 950 rows
# complete batch 803 add data 950 rows
# complete batch 804 add data 950 rows
# complete batch 805 add data 950 rows
# complete batch 806 add data 950 rows
# complete batch 807 add data 950 rows
# complete batch 808 add data 950 rows
# complete batch 809 add data 950 rows
# complete batch 810 add data 950 rows
# complete batch 811 add data 950 rows
# complete batch 812 add data 950 rows
# complete batch 813 add data 950 rows
# complete batch 814 add data 950 rows
# complete batch 815 add data 950 rows
# complete batch 816 add data 950 rows
# complete batch 817 add data 950 rows
# complete batch 818 add data 950 rows
# complete batch 819 add data 950 rows
# complete batch 820 add data 950 rows
# complete batch 821 add data 950 rows
# complete batch 822 add data 950 rows
# complete batch 823 add data 950 rows
# complete batch 824 add data 950 rows
# complete batch 825 add data 950 rows
# complete batch 826 add data 950 rows
# complete batch 827 add data 950 rows
# complete batch 828 add data 950 rows
# complete batch 829 add data 950 rows
# complete batch 830 add data 950 rows
# complete batch 831 add data 950 rows
# complete batch 832 add data 950 rows
# complete batch 833 add data 950 rows
# complete batch 834 add data 950 rows
# complete batch 835 add data 950 rows
# complete batch 836 add data 950 rows
# complete batch 837 add data 950 rows
# complete batch 838 add data 950 rows
# complete batch 839 add data 950 rows
# complete batch 840 add data 950 rows
# complete batch 841 add data 950 rows
# complete batch 842 add data 950 rows
# complete batch 843 add data 950 rows
# complete batch 844 add data 950 rows
# complete batch 845 add data 950 rows
# complete batch 846 add data 950 rows
# complete batch 847 add data 950 rows
# complete batch 848 add data 950 rows
# complete batch 849 add data 950 rows
# complete batch 850 add data 950 rows
# complete batch 851 add data 950 rows
# complete batch 852 add data 950 rows
# complete batch 853 add data 950 rows
# complete batch 854 add data 950 rows
# complete batch 855 add data 950 rows
# complete batch 856 add data 950 rows
# complete batch 857 add data 950 rows
# complete batch 858 add data 950 rows
# complete batch 859 add data 950 rows
# complete batch 860 add data 950 rows
# complete batch 861 add data 950 rows
# complete batch 862 add data 950 rows
# complete batch 863 add data 950 rows
# complete batch 864 add data 950 rows
# complete batch 865 add data 950 rows
# complete batch 866 add data 950 rows
# complete batch 867 add data 950 rows
# complete batch 868 add data 950 rows
# complete batch 869 add data 950 rows
# complete batch 870 add data 950 rows
# complete batch 871 add data 950 rows
# complete batch 872 add data 950 rows
# complete batch 873 add data 950 rows
# complete batch 874 add data 950 rows
# complete batch 875 add data 950 rows
# complete batch 876 add data 950 rows
# complete batch 877 add data 950 rows
# complete batch 878 add data 950 rows
# complete batch 879 add data 950 rows
# complete batch 880 add data 950 rows
# complete batch 881 add data 950 rows
# complete batch 882 add data 950 rows
# complete batch 883 add data 950 rows
# complete batch 884 add data 950 rows
# complete batch 885 add data 950 rows
# complete batch 886 add data 950 rows
# complete batch 887 add data 950 rows
# complete batch 888 add data 950 rows
# complete batch 889 add data 950 rows
# complete batch 890 add data 950 rows
# complete batch 891 add data 950 rows
# complete batch 892 add data 950 rows
# complete batch 893 add data 950 rows
# complete batch 894 add data 950 rows
# complete batch 895 add data 950 rows
# complete batch 896 add data 950 rows
# complete batch 897 add data 950 rows
# complete batch 898 add data 950 rows
# complete batch 899 add data 950 rows
# complete batch 900 add data 950 rows
# complete batch 901 add data 950 rows
# complete batch 902 add data 950 rows
# complete batch 903 add data 950 rows
# complete batch 904 add data 950 rows
# complete batch 905 add data 950 rows
# complete batch 906 add data 950 rows
# complete batch 907 add data 950 rows
# complete batch 908 add data 950 rows
# complete batch 909 add data 950 rows
# complete batch 910 add data 950 rows
# complete batch 911 add data 950 rows
# complete batch 912 add data 950 rows
# complete batch 913 add data 950 rows
# complete batch 914 add data 950 rows
# complete batch 915 add data 950 rows
# complete batch 916 add data 950 rows
# complete batch 917 add data 950 rows
# complete batch 918 add data 950 rows
# complete batch 919 add data 950 rows
# complete batch 920 add data 950 rows
# complete batch 921 add data 950 rows
# complete batch 922 add data 950 rows
# complete batch 923 add data 950 rows
# complete batch 924 add data 950 rows
# complete batch 925 add data 950 rows
# complete batch 926 add data 950 rows
# complete batch 927 add data 950 rows
# complete batch 928 add data 950 rows
# complete batch 929 add data 950 rows
# complete batch 930 add data 950 rows
# complete batch 931 add data 950 rows
# complete batch 932 add data 950 rows
# complete batch 933 add data 950 rows
# complete batch 934 add data 950 rows
# complete batch 935 add data 950 rows
# complete batch 936 add data 950 rows
# complete batch 937 add data 950 rows
# complete batch 938 add data 950 rows
# complete batch 939 add data 950 rows
# complete batch 940 add data 950 rows
# complete batch 941 add data 950 rows
# complete batch 942 add data 950 rows
# complete batch 943 add data 950 rows
# complete batch 944 add data 950 rows
# complete batch 945 add data 950 rows
# complete batch 946 add data 950 rows
# complete batch 947 add data 950 rows
# complete batch 948 add data 950 rows
# complete batch 949 add data 950 rows
# complete batch 950 add data 950 rows
# complete batch 951 add data 950 rows
# complete batch 952 add data 950 rows
# complete batch 953 add data 950 rows
# complete batch 954 add data 950 rows
# complete batch 955 add data 950 rows
# complete batch 956 add data 950 rows
# complete batch 957 add data 950 rows
# complete batch 958 add data 950 rows
# complete batch 959 add data 950 rows
# complete batch 960 add data 950 rows
# complete batch 961 add data 950 rows
# complete batch 962 add data 950 rows
# complete batch 963 add data 950 rows
# complete batch 964 add data 950 rows
# complete batch 965 add data 950 rows
# complete batch 966 add data 950 rows
# complete batch 967 add data 950 rows
# complete batch 968 add data 950 rows
# complete batch 969 add data 950 rows
# complete batch 970 add data 950 rows
# complete batch 971 add data 950 rows
# complete batch 972 add data 950 rows
# complete batch 973 add data 950 rows
# complete batch 974 add data 950 rows
# complete batch 975 add data 950 rows
# complete batch 976 add data 950 rows
# complete batch 977 add data 950 rows
# complete batch 978 add data 950 rows
# complete batch 979 add data 950 rows
# complete batch 980 add data 950 rows
# complete batch 981 add data 950 rows
# complete batch 982 add data 950 rows
# complete batch 983 add data 950 rows
# complete batch 984 add data 950 rows
# complete batch 985 add data 950 rows
# complete batch 986 add data 950 rows
# complete batch 987 add data 950 rows
# complete batch 988 add data 950 rows
# complete batch 989 add data 950 rows
# complete batch 990 add data 950 rows
# complete batch 991 add data 950 rows
# complete batch 992 add data 950 rows
# complete batch 993 add data 950 rows
# complete batch 994 add data 950 rows
# complete batch 995 add data 950 rows
# complete batch 996 add data 950 rows
# complete batch 997 add data 950 rows
# complete batch 998 add data 950 rows
# complete batch 999 add data 950 rows
# complete batch 1000 add data 950 rows
# complete batch 1001 add data 950 rows
# complete batch 1002 add data 950 rows
# complete batch 1003 add data 950 rows
# complete batch 1004 add data 950 rows
# complete batch 1005 add data 950 rows
# complete batch 1006 add data 950 rows
# complete batch 1007 add data 950 rows
# complete batch 1008 add data 950 rows
# complete batch 1009 add data 950 rows
# complete batch 1010 add data 950 rows
# complete batch 1011 add data 950 rows
# complete batch 1012 add data 950 rows
# complete batch 1013 add data 950 rows
# complete batch 1014 add data 950 rows
# complete batch 1015 add data 950 rows
# complete batch 1016 add data 950 rows
# complete batch 1017 add data 950 rows
# complete batch 1018 add data 950 rows
# complete batch 1019 add data 950 rows
# complete batch 1020 add data 950 rows
# complete batch 1021 add data 950 rows
# complete batch 1022 add data 950 rows
# complete batch 1023 add data 950 rows
# complete batch 1024 add data 950 rows
# complete batch 1025 add data 950 rows
# complete batch 1026 add data 950 rows
# complete batch 1027 add data 950 rows
# complete batch 1028 add data 950 rows
# complete batch 1029 add data 950 rows
# complete batch 1030 add data 950 rows
# complete batch 1031 add data 950 rows
# complete batch 1032 add data 950 rows
# complete batch 1033 add data 950 rows
# complete batch 1034 add data 950 rows
# complete batch 1035 add data 950 rows
# complete batch 1036 add data 950 rows
# complete batch 1037 add data 950 rows
# complete batch 1038 add data 950 rows
# complete batch 1039 add data 950 rows
# complete batch 1040 add data 950 rows
# complete batch 1041 add data 950 rows
# complete batch 1042 add data 950 rows
# complete batch 1043 add data 950 rows
# complete batch 1044 add data 950 rows
# complete batch 1045 add data 950 rows
# complete batch 1046 add data 950 rows
# complete batch 1047 add data 950 rows
# complete batch 1048 add data 950 rows
# complete batch 1049 add data 950 rows
# complete batch 1050 add data 950 rows
# complete batch 1051 add data 950 rows
# complete batch 1052 add data 950 rows
# complete batch 1053 add data 950 rows
# complete batch 1054 add data 950 rows
# complete batch 1055 add data 950 rows
# complete batch 1056 add data 950 rows
# complete batch 1057 add data 950 rows
# complete batch 1058 add data 950 rows
# complete batch 1059 add data 950 rows
# complete batch 1060 add data 950 rows
# complete batch 1061 add data 950 rows
# complete batch 1062 add data 950 rows
# complete batch 1063 add data 950 rows
# complete batch 1064 add data 950 rows
# complete batch 1065 add data 950 rows
# complete batch 1066 add data 950 rows
# complete batch 1067 add data 950 rows
# complete batch 1068 add data 950 rows
# complete batch 1069 add data 950 rows
# complete batch 1070 add data 950 rows
# complete batch 1071 add data 950 rows
# complete batch 1072 add data 950 rows
# complete batch 1073 add data 950 rows
# complete batch 1074 add data 950 rows
# complete batch 1075 add data 950 rows
# complete batch 1076 add data 950 rows
# complete batch 1077 add data 950 rows
# complete batch 1078 add data 950 rows
# complete batch 1079 add data 950 rows
# complete batch 1080 add data 950 rows
# complete batch 1081 add data 950 rows
# complete batch 1082 add data 950 rows
# complete batch 1083 add data 950 rows
# complete batch 1084 add data 950 rows
# complete batch 1085 add data 950 rows
# complete batch 1086 add data 950 rows
# complete batch 1087 add data 950 rows
# complete batch 1088 add data 950 rows
# complete batch 1089 add data 950 rows
# complete batch 1090 add data 950 rows
# complete batch 1091 add data 950 rows
# complete batch 1092 add data 950 rows
# complete batch 1093 add data 950 rows
# complete batch 1094 add data 950 rows
# complete batch 1095 add data 950 rows
# complete batch 1096 add data 950 rows
# complete batch 1097 add data 950 rows
# complete batch 1098 add data 950 rows
# complete batch 1099 add data 950 rows
# complete batch 1100 add data 524 rows
# 1045950 1045524

# %%
total_table = pd.DataFrame(columns=['client_id', 'RACE_DESC', 'ETHNICITY_DESC','PatientZip','PatientCounty','GENDER',
                                   2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015,
                                   2016, 2017, 2018, 2019, 2020, 2021,2022,2023])
batches= len(df_distinct)//1500
cur = 0
for i in range(1501):

    tmp_df = df_distinct.iloc[cur:cur+batches]
    final = cur + batches
    if final > len(df_distinct):
        final = len(df_distinct)
    for j in range(cur,final):
        tmp = {}
        tmp['client_id'] = df_distinct['client_id'][j]
        tmp['ETHNICITY_DESC'] = df_distinct['ETHNICITY_DESC'][j]
        tmp['RACE_DESC'] = df_distinct['RACE_DESC'][j]
        tmp['PatientZip'] = df_distinct['PatientZip'][j]
        tmp['GENDER'] = df_distinct['GENDER'][j]
        tmp['PatientCounty'] = df_distinct['PatientCounty'][j]
        vax_year = df_distinct['vax_year'][j]
        vax_age = df_distinct['PatientAge'][j]
#         print(j)
        for year in years:
            if year<vax_year:
                tmp[year] = np.nan
            else:
                tmp[year] = vax_age
                vax_age += 1
    #     print(tmp)
        tmp_df = pd.DataFrame([tmp])
        total_table = pd.concat([total_table, tmp_df], ignore_index=True)
    total_table.to_csv('../Data/Merged_data/AgeOut_total.csv', mode='a', header=(i==0), index=False)
    cur += batches
    print('complete batch',i,'add data',len(total_table),'rows')
    total_table = total_table.iloc[0:0]

print(cur,final)
# Out:
# complete batch 0 add data 746 rows
# complete batch 1 add data 746 rows
# complete batch 2 add data 746 rows
# complete batch 3 add data 746 rows
# complete batch 4 add data 746 rows
# complete batch 5 add data 746 rows
# complete batch 6 add data 746 rows
# complete batch 7 add data 746 rows
# complete batch 8 add data 746 rows
# complete batch 9 add data 746 rows
# complete batch 10 add data 746 rows
# complete batch 11 add data 746 rows
# complete batch 12 add data 746 rows
# complete batch 13 add data 746 rows
# complete batch 14 add data 746 rows
# complete batch 15 add data 746 rows
# complete batch 16 add data 746 rows
# complete batch 17 add data 746 rows
# complete batch 18 add data 746 rows
# complete batch 19 add data 746 rows
# complete batch 20 add data 746 rows
# complete batch 21 add data 746 rows
# complete batch 22 add data 746 rows
# complete batch 23 add data 746 rows
# complete batch 24 add data 746 rows
# complete batch 25 add data 746 rows
# complete batch 26 add data 746 rows
# complete batch 27 add data 746 rows
# complete batch 28 add data 746 rows
# complete batch 29 add data 746 rows
# complete batch 30 add data 746 rows
# complete batch 31 add data 746 rows
# complete batch 32 add data 746 rows
# complete batch 33 add data 746 rows
# complete batch 34 add data 746 rows
# complete batch 35 add data 746 rows
# complete batch 36 add data 746 rows
# complete batch 37 add data 746 rows
# complete batch 38 add data 746 rows
# complete batch 39 add data 746 rows
# complete batch 40 add data 746 rows
# complete batch 41 add data 746 rows
# complete batch 42 add data 746 rows
# complete batch 43 add data 746 rows
# complete batch 44 add data 746 rows
# complete batch 45 add data 746 rows
# complete batch 46 add data 746 rows
# complete batch 47 add data 746 rows
# complete batch 48 add data 746 rows
# complete batch 49 add data 746 rows
# complete batch 50 add data 746 rows
# complete batch 51 add data 746 rows
# complete batch 52 add data 746 rows
# complete batch 53 add data 746 rows
# complete batch 54 add data 746 rows
# complete batch 55 add data 746 rows
# complete batch 56 add data 746 rows
# complete batch 57 add data 746 rows
# complete batch 58 add data 746 rows
# complete batch 59 add data 746 rows
# complete batch 60 add data 746 rows
# complete batch 61 add data 746 rows
# complete batch 62 add data 746 rows
# complete batch 63 add data 746 rows
# complete batch 64 add data 746 rows
# complete batch 65 add data 746 rows
# complete batch 66 add data 746 rows
# complete batch 67 add data 746 rows
# complete batch 68 add data 746 rows
# complete batch 69 add data 746 rows
# complete batch 70 add data 746 rows
# complete batch 71 add data 746 rows
# complete batch 72 add data 746 rows
# complete batch 73 add data 746 rows
# complete batch 74 add data 746 rows
# complete batch 75 add data 746 rows
# complete batch 76 add data 746 rows
# complete batch 77 add data 746 rows
# complete batch 78 add data 746 rows
# complete batch 79 add data 746 rows
# complete batch 80 add data 746 rows
# complete batch 81 add data 746 rows
# complete batch 82 add data 746 rows
# complete batch 83 add data 746 rows
# complete batch 84 add data 746 rows
# complete batch 85 add data 746 rows
# complete batch 86 add data 746 rows
# complete batch 87 add data 746 rows
# complete batch 88 add data 746 rows
# complete batch 89 add data 746 rows
# complete batch 90 add data 746 rows
# complete batch 91 add data 746 rows
# complete batch 92 add data 746 rows
# complete batch 93 add data 746 rows
# complete batch 94 add data 746 rows
# complete batch 95 add data 746 rows
# complete batch 96 add data 746 rows
# complete batch 97 add data 746 rows
# complete batch 98 add data 746 rows
# complete batch 99 add data 746 rows
# complete batch 100 add data 746 rows
# complete batch 101 add data 746 rows
# complete batch 102 add data 746 rows
# complete batch 103 add data 746 rows
# complete batch 104 add data 746 rows
# complete batch 105 add data 746 rows
# complete batch 106 add data 746 rows
# complete batch 107 add data 746 rows
# complete batch 108 add data 746 rows
# complete batch 109 add data 746 rows
# complete batch 110 add data 746 rows
# complete batch 111 add data 746 rows
# complete batch 112 add data 746 rows
# complete batch 113 add data 746 rows
# complete batch 114 add data 746 rows
# complete batch 115 add data 746 rows
# complete batch 116 add data 746 rows
# complete batch 117 add data 746 rows
# complete batch 118 add data 746 rows
# complete batch 119 add data 746 rows
# complete batch 120 add data 746 rows
# complete batch 121 add data 746 rows
# complete batch 122 add data 746 rows
# complete batch 123 add data 746 rows
# complete batch 124 add data 746 rows
# complete batch 125 add data 746 rows
# complete batch 126 add data 746 rows
# complete batch 127 add data 746 rows
# complete batch 128 add data 746 rows
# complete batch 129 add data 746 rows
# complete batch 130 add data 746 rows
# complete batch 131 add data 746 rows
# complete batch 132 add data 746 rows
# complete batch 133 add data 746 rows
# complete batch 134 add data 746 rows
# complete batch 135 add data 746 rows
# complete batch 136 add data 746 rows
# complete batch 137 add data 746 rows
# complete batch 138 add data 746 rows
# complete batch 139 add data 746 rows
# complete batch 140 add data 746 rows
# complete batch 141 add data 746 rows
# complete batch 142 add data 746 rows
# complete batch 143 add data 746 rows
# complete batch 144 add data 746 rows
# complete batch 145 add data 746 rows
# complete batch 146 add data 746 rows
# complete batch 147 add data 746 rows
# complete batch 148 add data 746 rows
# complete batch 149 add data 746 rows
# complete batch 150 add data 746 rows
# complete batch 151 add data 746 rows
# complete batch 152 add data 746 rows
# complete batch 153 add data 746 rows
# complete batch 154 add data 746 rows
# complete batch 155 add data 746 rows
# complete batch 156 add data 746 rows
# complete batch 157 add data 746 rows
# complete batch 158 add data 746 rows
# complete batch 159 add data 746 rows
# complete batch 160 add data 746 rows
# complete batch 161 add data 746 rows
# complete batch 162 add data 746 rows
# complete batch 163 add data 746 rows
# complete batch 164 add data 746 rows
# complete batch 165 add data 746 rows
# complete batch 166 add data 746 rows
# complete batch 167 add data 746 rows
# complete batch 168 add data 746 rows
# complete batch 169 add data 746 rows
# complete batch 170 add data 746 rows
# complete batch 171 add data 746 rows
# complete batch 172 add data 746 rows
# complete batch 173 add data 746 rows
# complete batch 174 add data 746 rows
# complete batch 175 add data 746 rows
# complete batch 176 add data 746 rows
# complete batch 177 add data 746 rows
# complete batch 178 add data 746 rows
# complete batch 179 add data 746 rows
# complete batch 180 add data 746 rows
# complete batch 181 add data 746 rows
# complete batch 182 add data 746 rows
# complete batch 183 add data 746 rows
# complete batch 184 add data 746 rows
# complete batch 185 add data 746 rows
# complete batch 186 add data 746 rows
# complete batch 187 add data 746 rows
# complete batch 188 add data 746 rows
# complete batch 189 add data 746 rows
# complete batch 190 add data 746 rows
# complete batch 191 add data 746 rows
# complete batch 192 add data 746 rows
# complete batch 193 add data 746 rows
# complete batch 194 add data 746 rows
# complete batch 195 add data 746 rows
# complete batch 196 add data 746 rows
# complete batch 197 add data 746 rows
# complete batch 198 add data 746 rows
# complete batch 199 add data 746 rows
# complete batch 200 add data 746 rows
# complete batch 201 add data 746 rows
# complete batch 202 add data 746 rows
# complete batch 203 add data 746 rows
# complete batch 204 add data 746 rows
# complete batch 205 add data 746 rows
# complete batch 206 add data 746 rows
# complete batch 207 add data 746 rows
# complete batch 208 add data 746 rows
# complete batch 209 add data 746 rows
# complete batch 210 add data 746 rows
# complete batch 211 add data 746 rows
# complete batch 212 add data 746 rows
# complete batch 213 add data 746 rows
# complete batch 214 add data 746 rows
# complete batch 215 add data 746 rows
# complete batch 216 add data 746 rows
# complete batch 217 add data 746 rows
# complete batch 218 add data 746 rows
# complete batch 219 add data 746 rows
# complete batch 220 add data 746 rows
# complete batch 221 add data 746 rows
# complete batch 222 add data 746 rows
# complete batch 223 add data 746 rows
# complete batch 224 add data 746 rows
# complete batch 225 add data 746 rows
# complete batch 226 add data 746 rows
# complete batch 227 add data 746 rows
# complete batch 228 add data 746 rows
# complete batch 229 add data 746 rows
# complete batch 230 add data 746 rows
# complete batch 231 add data 746 rows
# complete batch 232 add data 746 rows
# complete batch 233 add data 746 rows
# complete batch 234 add data 746 rows
# complete batch 235 add data 746 rows
# complete batch 236 add data 746 rows
# complete batch 237 add data 746 rows
# complete batch 238 add data 746 rows
# complete batch 239 add data 746 rows
# complete batch 240 add data 746 rows
# complete batch 241 add data 746 rows
# complete batch 242 add data 746 rows
# complete batch 243 add data 746 rows
# complete batch 244 add data 746 rows
# complete batch 245 add data 746 rows
# complete batch 246 add data 746 rows
# complete batch 247 add data 746 rows
# complete batch 248 add data 746 rows
# complete batch 249 add data 746 rows
# complete batch 250 add data 746 rows
# complete batch 251 add data 746 rows
# complete batch 252 add data 746 rows
# complete batch 253 add data 746 rows
# complete batch 254 add data 746 rows
# complete batch 255 add data 746 rows
# complete batch 256 add data 746 rows
# complete batch 257 add data 746 rows
# complete batch 258 add data 746 rows
# complete batch 259 add data 746 rows
# complete batch 260 add data 746 rows
# complete batch 261 add data 746 rows
# complete batch 262 add data 746 rows
# complete batch 263 add data 746 rows
# complete batch 264 add data 746 rows
# complete batch 265 add data 746 rows
# complete batch 266 add data 746 rows
# complete batch 267 add data 746 rows
# complete batch 268 add data 746 rows
# complete batch 269 add data 746 rows
# complete batch 270 add data 746 rows
# complete batch 271 add data 746 rows
# complete batch 272 add data 746 rows
# complete batch 273 add data 746 rows
# complete batch 274 add data 746 rows
# complete batch 275 add data 746 rows
# complete batch 276 add data 746 rows
# complete batch 277 add data 746 rows
# complete batch 278 add data 746 rows
# complete batch 279 add data 746 rows
# complete batch 280 add data 746 rows
# complete batch 281 add data 746 rows
# complete batch 282 add data 746 rows
# complete batch 283 add data 746 rows
# complete batch 284 add data 746 rows
# complete batch 285 add data 746 rows
# complete batch 286 add data 746 rows
# complete batch 287 add data 746 rows
# complete batch 288 add data 746 rows
# complete batch 289 add data 746 rows
# complete batch 290 add data 746 rows
# complete batch 291 add data 746 rows
# complete batch 292 add data 746 rows
# complete batch 293 add data 746 rows
# complete batch 294 add data 746 rows
# complete batch 295 add data 746 rows
# complete batch 296 add data 746 rows
# complete batch 297 add data 746 rows
# complete batch 298 add data 746 rows
# complete batch 299 add data 746 rows
# complete batch 300 add data 746 rows
# complete batch 301 add data 746 rows
# complete batch 302 add data 746 rows
# complete batch 303 add data 746 rows
# complete batch 304 add data 746 rows
# complete batch 305 add data 746 rows
# complete batch 306 add data 746 rows
# complete batch 307 add data 746 rows
# complete batch 308 add data 746 rows
# complete batch 309 add data 746 rows
# complete batch 310 add data 746 rows
# complete batch 311 add data 746 rows
# complete batch 312 add data 746 rows
# complete batch 313 add data 746 rows
# complete batch 314 add data 746 rows
# complete batch 315 add data 746 rows
# complete batch 316 add data 746 rows
# complete batch 317 add data 746 rows
# complete batch 318 add data 746 rows
# complete batch 319 add data 746 rows
# complete batch 320 add data 746 rows
# complete batch 321 add data 746 rows
# complete batch 322 add data 746 rows
# complete batch 323 add data 746 rows
# complete batch 324 add data 746 rows
# complete batch 325 add data 746 rows
# complete batch 326 add data 746 rows
# complete batch 327 add data 746 rows
# complete batch 328 add data 746 rows
# complete batch 329 add data 746 rows
# complete batch 330 add data 746 rows
# complete batch 331 add data 746 rows
# complete batch 332 add data 746 rows
# complete batch 333 add data 746 rows
# complete batch 334 add data 746 rows
# complete batch 335 add data 746 rows
# complete batch 336 add data 746 rows
# complete batch 337 add data 746 rows
# complete batch 338 add data 746 rows
# complete batch 339 add data 746 rows
# complete batch 340 add data 746 rows
# complete batch 341 add data 746 rows
# complete batch 342 add data 746 rows
# complete batch 343 add data 746 rows
# complete batch 344 add data 746 rows
# complete batch 345 add data 746 rows
# complete batch 346 add data 746 rows
# complete batch 347 add data 746 rows
# complete batch 348 add data 746 rows
# complete batch 349 add data 746 rows
# complete batch 350 add data 746 rows
# complete batch 351 add data 746 rows
# complete batch 352 add data 746 rows
# complete batch 353 add data 746 rows
# complete batch 354 add data 746 rows
# complete batch 355 add data 746 rows
# complete batch 356 add data 746 rows
# complete batch 357 add data 746 rows
# complete batch 358 add data 746 rows
# complete batch 359 add data 746 rows
# complete batch 360 add data 746 rows
# complete batch 361 add data 746 rows
# complete batch 362 add data 746 rows
# complete batch 363 add data 746 rows
# complete batch 364 add data 746 rows
# complete batch 365 add data 746 rows
# complete batch 366 add data 746 rows
# complete batch 367 add data 746 rows
# complete batch 368 add data 746 rows
# complete batch 369 add data 746 rows
# complete batch 370 add data 746 rows
# complete batch 371 add data 746 rows
# complete batch 372 add data 746 rows
# complete batch 373 add data 746 rows
# complete batch 374 add data 746 rows
# complete batch 375 add data 746 rows
# complete batch 376 add data 746 rows
# complete batch 377 add data 746 rows
# complete batch 378 add data 746 rows
# complete batch 379 add data 746 rows
# complete batch 380 add data 746 rows
# complete batch 381 add data 746 rows
# complete batch 382 add data 746 rows
# complete batch 383 add data 746 rows
# complete batch 384 add data 746 rows
# complete batch 385 add data 746 rows
# complete batch 386 add data 746 rows
# complete batch 387 add data 746 rows
# complete batch 388 add data 746 rows
# complete batch 389 add data 746 rows
# complete batch 390 add data 746 rows
# complete batch 391 add data 746 rows
# complete batch 392 add data 746 rows
# complete batch 393 add data 746 rows
# complete batch 394 add data 746 rows
# complete batch 395 add data 746 rows
# complete batch 396 add data 746 rows
# complete batch 397 add data 746 rows
# complete batch 398 add data 746 rows
# complete batch 399 add data 746 rows
# complete batch 400 add data 746 rows
# complete batch 401 add data 746 rows
# complete batch 402 add data 746 rows
# complete batch 403 add data 746 rows
# complete batch 404 add data 746 rows
# complete batch 405 add data 746 rows
# complete batch 406 add data 746 rows
# complete batch 407 add data 746 rows
# complete batch 408 add data 746 rows
# complete batch 409 add data 746 rows
# complete batch 410 add data 746 rows
# complete batch 411 add data 746 rows
# complete batch 412 add data 746 rows
# complete batch 413 add data 746 rows
# complete batch 414 add data 746 rows
# complete batch 415 add data 746 rows
# complete batch 416 add data 746 rows
# complete batch 417 add data 746 rows
# complete batch 418 add data 746 rows
# complete batch 419 add data 746 rows
# complete batch 420 add data 746 rows
# complete batch 421 add data 746 rows
# complete batch 422 add data 746 rows
# complete batch 423 add data 746 rows
# complete batch 424 add data 746 rows
# complete batch 425 add data 746 rows
# complete batch 426 add data 746 rows
# complete batch 427 add data 746 rows
# complete batch 428 add data 746 rows
# complete batch 429 add data 746 rows
# complete batch 430 add data 746 rows
# complete batch 431 add data 746 rows
# complete batch 432 add data 746 rows
# complete batch 433 add data 746 rows
# complete batch 434 add data 746 rows
# complete batch 435 add data 746 rows
# complete batch 436 add data 746 rows
# complete batch 437 add data 746 rows
# complete batch 438 add data 746 rows
# complete batch 439 add data 746 rows
# complete batch 440 add data 746 rows
# complete batch 441 add data 746 rows
# complete batch 442 add data 746 rows
# complete batch 443 add data 746 rows
# complete batch 444 add data 746 rows
# complete batch 445 add data 746 rows
# complete batch 446 add data 746 rows
# complete batch 447 add data 746 rows
# complete batch 448 add data 746 rows
# complete batch 449 add data 746 rows
# complete batch 450 add data 746 rows
# complete batch 451 add data 746 rows
# complete batch 452 add data 746 rows
# complete batch 453 add data 746 rows
# complete batch 454 add data 746 rows
# complete batch 455 add data 746 rows
# complete batch 456 add data 746 rows
# complete batch 457 add data 746 rows
# complete batch 458 add data 746 rows
# complete batch 459 add data 746 rows
# complete batch 460 add data 746 rows
# complete batch 461 add data 746 rows
# complete batch 462 add data 746 rows
# complete batch 463 add data 746 rows
# complete batch 464 add data 746 rows
# complete batch 465 add data 746 rows
# complete batch 466 add data 746 rows
# complete batch 467 add data 746 rows
# complete batch 468 add data 746 rows
# complete batch 469 add data 746 rows
# complete batch 470 add data 746 rows
# complete batch 471 add data 746 rows
# complete batch 472 add data 746 rows
# complete batch 473 add data 746 rows
# complete batch 474 add data 746 rows
# complete batch 475 add data 746 rows
# complete batch 476 add data 746 rows
# complete batch 477 add data 746 rows
# complete batch 478 add data 746 rows
# complete batch 479 add data 746 rows
# complete batch 480 add data 746 rows
# complete batch 481 add data 746 rows
# complete batch 482 add data 746 rows
# complete batch 483 add data 746 rows
# complete batch 484 add data 746 rows
# complete batch 485 add data 746 rows
# complete batch 486 add data 746 rows
# complete batch 487 add data 746 rows
# complete batch 488 add data 746 rows
# complete batch 489 add data 746 rows
# complete batch 490 add data 746 rows
# complete batch 491 add data 746 rows
# complete batch 492 add data 746 rows
# complete batch 493 add data 746 rows
# complete batch 494 add data 746 rows
# complete batch 495 add data 746 rows
# complete batch 496 add data 746 rows
# complete batch 497 add data 746 rows
# complete batch 498 add data 746 rows
# complete batch 499 add data 746 rows
# complete batch 500 add data 746 rows
# complete batch 501 add data 746 rows
# complete batch 502 add data 746 rows
# complete batch 503 add data 746 rows
# complete batch 504 add data 746 rows
# complete batch 505 add data 746 rows
# complete batch 506 add data 746 rows
# complete batch 507 add data 746 rows
# complete batch 508 add data 746 rows
# complete batch 509 add data 746 rows
# complete batch 510 add data 746 rows
# complete batch 511 add data 746 rows
# complete batch 512 add data 746 rows
# complete batch 513 add data 746 rows
# complete batch 514 add data 746 rows
# complete batch 515 add data 746 rows
# complete batch 516 add data 746 rows
# complete batch 517 add data 746 rows
# complete batch 518 add data 746 rows
# complete batch 519 add data 746 rows
# complete batch 520 add data 746 rows
# complete batch 521 add data 746 rows
# complete batch 522 add data 746 rows
# complete batch 523 add data 746 rows
# complete batch 524 add data 746 rows
# complete batch 525 add data 746 rows
# complete batch 526 add data 746 rows
# complete batch 527 add data 746 rows
# complete batch 528 add data 746 rows
# complete batch 529 add data 746 rows
# complete batch 530 add data 746 rows
# complete batch 531 add data 746 rows
# complete batch 532 add data 746 rows
# complete batch 533 add data 746 rows
# complete batch 534 add data 746 rows
# complete batch 535 add data 746 rows
# complete batch 536 add data 746 rows
# complete batch 537 add data 746 rows
# complete batch 538 add data 746 rows
# complete batch 539 add data 746 rows
# complete batch 540 add data 746 rows
# complete batch 541 add data 746 rows
# complete batch 542 add data 746 rows
# complete batch 543 add data 746 rows
# complete batch 544 add data 746 rows
# complete batch 545 add data 746 rows
# complete batch 546 add data 746 rows
# complete batch 547 add data 746 rows
# complete batch 548 add data 746 rows
# complete batch 549 add data 746 rows
# complete batch 550 add data 746 rows
# complete batch 551 add data 746 rows
# complete batch 552 add data 746 rows
# complete batch 553 add data 746 rows
# complete batch 554 add data 746 rows
# complete batch 555 add data 746 rows
# complete batch 556 add data 746 rows
# complete batch 557 add data 746 rows
# complete batch 558 add data 746 rows
# complete batch 559 add data 746 rows
# complete batch 560 add data 746 rows
# complete batch 561 add data 746 rows
# complete batch 562 add data 746 rows
# complete batch 563 add data 746 rows
# complete batch 564 add data 746 rows
# complete batch 565 add data 746 rows
# complete batch 566 add data 746 rows
# complete batch 567 add data 746 rows
# complete batch 568 add data 746 rows
# complete batch 569 add data 746 rows
# complete batch 570 add data 746 rows
# complete batch 571 add data 746 rows
# complete batch 572 add data 746 rows
# complete batch 573 add data 746 rows
# complete batch 574 add data 746 rows
# complete batch 575 add data 746 rows
# complete batch 576 add data 746 rows
# complete batch 577 add data 746 rows
# complete batch 578 add data 746 rows
# complete batch 579 add data 746 rows
# complete batch 580 add data 746 rows
# complete batch 581 add data 746 rows
# complete batch 582 add data 746 rows
# complete batch 583 add data 746 rows
# complete batch 584 add data 746 rows
# complete batch 585 add data 746 rows
# complete batch 586 add data 746 rows
# complete batch 587 add data 746 rows
# complete batch 588 add data 746 rows
# complete batch 589 add data 746 rows
# complete batch 590 add data 746 rows
# complete batch 591 add data 746 rows
# complete batch 592 add data 746 rows
# complete batch 593 add data 746 rows
# complete batch 594 add data 746 rows
# complete batch 595 add data 746 rows
# complete batch 596 add data 746 rows
# complete batch 597 add data 746 rows
# complete batch 598 add data 746 rows
# complete batch 599 add data 746 rows
# complete batch 600 add data 746 rows
# complete batch 601 add data 746 rows
# complete batch 602 add data 746 rows
# complete batch 603 add data 746 rows
# complete batch 604 add data 746 rows
# complete batch 605 add data 746 rows
# complete batch 606 add data 746 rows
# complete batch 607 add data 746 rows
# complete batch 608 add data 746 rows
# complete batch 609 add data 746 rows
# complete batch 610 add data 746 rows
# complete batch 611 add data 746 rows
# complete batch 612 add data 746 rows
# complete batch 613 add data 746 rows
# complete batch 614 add data 746 rows
# complete batch 615 add data 746 rows
# complete batch 616 add data 746 rows
# complete batch 617 add data 746 rows
# complete batch 618 add data 746 rows
# complete batch 619 add data 746 rows
# complete batch 620 add data 746 rows
# complete batch 621 add data 746 rows
# complete batch 622 add data 746 rows
# complete batch 623 add data 746 rows
# complete batch 624 add data 746 rows
# complete batch 625 add data 746 rows
# complete batch 626 add data 746 rows
# complete batch 627 add data 746 rows
# complete batch 628 add data 746 rows
# complete batch 629 add data 746 rows
# complete batch 630 add data 746 rows
# complete batch 631 add data 746 rows
# complete batch 632 add data 746 rows
# complete batch 633 add data 746 rows
# complete batch 634 add data 746 rows
# complete batch 635 add data 746 rows
# complete batch 636 add data 746 rows
# complete batch 637 add data 746 rows
# complete batch 638 add data 746 rows
# complete batch 639 add data 746 rows
# complete batch 640 add data 746 rows
# complete batch 641 add data 746 rows
# complete batch 642 add data 746 rows
# complete batch 643 add data 746 rows
# complete batch 644 add data 746 rows
# complete batch 645 add data 746 rows
# complete batch 646 add data 746 rows
# complete batch 647 add data 746 rows
# complete batch 648 add data 746 rows
# complete batch 649 add data 746 rows
# complete batch 650 add data 746 rows
# complete batch 651 add data 746 rows
# complete batch 652 add data 746 rows
# complete batch 653 add data 746 rows
# complete batch 654 add data 746 rows
# complete batch 655 add data 746 rows
# complete batch 656 add data 746 rows
# complete batch 657 add data 746 rows
# complete batch 658 add data 746 rows
# complete batch 659 add data 746 rows
# complete batch 660 add data 746 rows
# complete batch 661 add data 746 rows
# complete batch 662 add data 746 rows
# complete batch 663 add data 746 rows
# complete batch 664 add data 746 rows
# complete batch 665 add data 746 rows
# complete batch 666 add data 746 rows
# complete batch 667 add data 746 rows
# complete batch 668 add data 746 rows
# complete batch 669 add data 746 rows
# complete batch 670 add data 746 rows
# complete batch 671 add data 746 rows
# complete batch 672 add data 746 rows
# complete batch 673 add data 746 rows
# complete batch 674 add data 746 rows
# complete batch 675 add data 746 rows
# complete batch 676 add data 746 rows
# complete batch 677 add data 746 rows
# complete batch 678 add data 746 rows
# complete batch 679 add data 746 rows
# complete batch 680 add data 746 rows
# complete batch 681 add data 746 rows
# complete batch 682 add data 746 rows
# complete batch 683 add data 746 rows
# complete batch 684 add data 746 rows
# complete batch 685 add data 746 rows
# complete batch 686 add data 746 rows
# complete batch 687 add data 746 rows
# complete batch 688 add data 746 rows
# complete batch 689 add data 746 rows
# complete batch 690 add data 746 rows
# complete batch 691 add data 746 rows
# complete batch 692 add data 746 rows
# complete batch 693 add data 746 rows
# complete batch 694 add data 746 rows
# complete batch 695 add data 746 rows
# complete batch 696 add data 746 rows
# complete batch 697 add data 746 rows
# complete batch 698 add data 746 rows
# complete batch 699 add data 746 rows
# complete batch 700 add data 746 rows
# complete batch 701 add data 746 rows
# complete batch 702 add data 746 rows
# complete batch 703 add data 746 rows
# complete batch 704 add data 746 rows
# complete batch 705 add data 746 rows
# complete batch 706 add data 746 rows
# complete batch 707 add data 746 rows
# complete batch 708 add data 746 rows
# complete batch 709 add data 746 rows
# complete batch 710 add data 746 rows
# complete batch 711 add data 746 rows
# complete batch 712 add data 746 rows
# complete batch 713 add data 746 rows
# complete batch 714 add data 746 rows
# complete batch 715 add data 746 rows
# complete batch 716 add data 746 rows
# complete batch 717 add data 746 rows
# complete batch 718 add data 746 rows
# complete batch 719 add data 746 rows
# complete batch 720 add data 746 rows
# complete batch 721 add data 746 rows
# complete batch 722 add data 746 rows
# complete batch 723 add data 746 rows
# complete batch 724 add data 746 rows
# complete batch 725 add data 746 rows
# complete batch 726 add data 746 rows
# complete batch 727 add data 746 rows
# complete batch 728 add data 746 rows
# complete batch 729 add data 746 rows
# complete batch 730 add data 746 rows
# complete batch 731 add data 746 rows
# complete batch 732 add data 746 rows
# complete batch 733 add data 746 rows
# complete batch 734 add data 746 rows
# complete batch 735 add data 746 rows
# complete batch 736 add data 746 rows
# complete batch 737 add data 746 rows
# complete batch 738 add data 746 rows
# complete batch 739 add data 746 rows
# complete batch 740 add data 746 rows
# complete batch 741 add data 746 rows
# complete batch 742 add data 746 rows
# complete batch 743 add data 746 rows
# complete batch 744 add data 746 rows
# complete batch 745 add data 746 rows
# complete batch 746 add data 746 rows
# complete batch 747 add data 746 rows
# complete batch 748 add data 746 rows
# complete batch 749 add data 746 rows
# complete batch 750 add data 746 rows
# complete batch 751 add data 746 rows
# complete batch 752 add data 746 rows
# complete batch 753 add data 746 rows
# complete batch 754 add data 746 rows
# complete batch 755 add data 746 rows
# complete batch 756 add data 746 rows
# complete batch 757 add data 746 rows
# complete batch 758 add data 746 rows
# complete batch 759 add data 746 rows
# complete batch 760 add data 746 rows
# complete batch 761 add data 746 rows
# complete batch 762 add data 746 rows
# complete batch 763 add data 746 rows
# complete batch 764 add data 746 rows
# complete batch 765 add data 746 rows
# complete batch 766 add data 746 rows
# complete batch 767 add data 746 rows
# complete batch 768 add data 746 rows
# complete batch 769 add data 746 rows
# complete batch 770 add data 746 rows
# complete batch 771 add data 746 rows
# complete batch 772 add data 746 rows
# complete batch 773 add data 746 rows
# complete batch 774 add data 746 rows
# complete batch 775 add data 746 rows
# complete batch 776 add data 746 rows
# complete batch 777 add data 746 rows
# complete batch 778 add data 746 rows
# complete batch 779 add data 746 rows
# complete batch 780 add data 746 rows
# complete batch 781 add data 746 rows
# complete batch 782 add data 746 rows
# complete batch 783 add data 746 rows
# complete batch 784 add data 746 rows
# complete batch 785 add data 746 rows
# complete batch 786 add data 746 rows
# complete batch 787 add data 746 rows
# complete batch 788 add data 746 rows
# complete batch 789 add data 746 rows
# complete batch 790 add data 746 rows
# complete batch 791 add data 746 rows
# complete batch 792 add data 746 rows
# complete batch 793 add data 746 rows
# complete batch 794 add data 746 rows
# complete batch 795 add data 746 rows
# complete batch 796 add data 746 rows
# complete batch 797 add data 746 rows
# complete batch 798 add data 746 rows
# complete batch 799 add data 746 rows
# complete batch 800 add data 746 rows
# complete batch 801 add data 746 rows
# complete batch 802 add data 746 rows
# complete batch 803 add data 746 rows
# complete batch 804 add data 746 rows
# complete batch 805 add data 746 rows
# complete batch 806 add data 746 rows
# complete batch 807 add data 746 rows
# complete batch 808 add data 746 rows
# complete batch 809 add data 746 rows
# complete batch 810 add data 746 rows
# complete batch 811 add data 746 rows
# complete batch 812 add data 746 rows
# complete batch 813 add data 746 rows
# complete batch 814 add data 746 rows
# complete batch 815 add data 746 rows
# complete batch 816 add data 746 rows
# complete batch 817 add data 746 rows
# complete batch 818 add data 746 rows
# complete batch 819 add data 746 rows
# complete batch 820 add data 746 rows
# complete batch 821 add data 746 rows
# complete batch 822 add data 746 rows
# complete batch 823 add data 746 rows
# complete batch 824 add data 746 rows
# complete batch 825 add data 746 rows
# complete batch 826 add data 746 rows
# complete batch 827 add data 746 rows
# complete batch 828 add data 746 rows
# complete batch 829 add data 746 rows
# complete batch 830 add data 746 rows
# complete batch 831 add data 746 rows
# complete batch 832 add data 746 rows
# complete batch 833 add data 746 rows
# complete batch 834 add data 746 rows
# complete batch 835 add data 746 rows
# complete batch 836 add data 746 rows
# complete batch 837 add data 746 rows
# complete batch 838 add data 746 rows
# complete batch 839 add data 746 rows
# complete batch 840 add data 746 rows
# complete batch 841 add data 746 rows
# complete batch 842 add data 746 rows
# complete batch 843 add data 746 rows
# complete batch 844 add data 746 rows
# complete batch 845 add data 746 rows
# complete batch 846 add data 746 rows
# complete batch 847 add data 746 rows
# complete batch 848 add data 746 rows
# complete batch 849 add data 746 rows
# complete batch 850 add data 746 rows
# complete batch 851 add data 746 rows
# complete batch 852 add data 746 rows
# complete batch 853 add data 746 rows
# complete batch 854 add data 746 rows
# complete batch 855 add data 746 rows
# complete batch 856 add data 746 rows
# complete batch 857 add data 746 rows
# complete batch 858 add data 746 rows
# complete batch 859 add data 746 rows
# complete batch 860 add data 746 rows
# complete batch 861 add data 746 rows
# complete batch 862 add data 746 rows
# complete batch 863 add data 746 rows
# complete batch 864 add data 746 rows
# complete batch 865 add data 746 rows
# complete batch 866 add data 746 rows
# complete batch 867 add data 746 rows
# complete batch 868 add data 746 rows
# complete batch 869 add data 746 rows
# complete batch 870 add data 746 rows
# complete batch 871 add data 746 rows
# complete batch 872 add data 746 rows
# complete batch 873 add data 746 rows
# complete batch 874 add data 746 rows
# complete batch 875 add data 746 rows
# complete batch 876 add data 746 rows
# complete batch 877 add data 746 rows
# complete batch 878 add data 746 rows
# complete batch 879 add data 746 rows
# complete batch 880 add data 746 rows
# complete batch 881 add data 746 rows
# complete batch 882 add data 746 rows
# complete batch 883 add data 746 rows
# complete batch 884 add data 746 rows
# complete batch 885 add data 746 rows
# complete batch 886 add data 746 rows
# complete batch 887 add data 746 rows
# complete batch 888 add data 746 rows
# complete batch 889 add data 746 rows
# complete batch 890 add data 746 rows
# complete batch 891 add data 746 rows
# complete batch 892 add data 746 rows
# complete batch 893 add data 746 rows
# complete batch 894 add data 746 rows
# complete batch 895 add data 746 rows
# complete batch 896 add data 746 rows
# complete batch 897 add data 746 rows
# complete batch 898 add data 746 rows
# complete batch 899 add data 746 rows
# complete batch 900 add data 746 rows
# complete batch 901 add data 746 rows
# complete batch 902 add data 746 rows
# complete batch 903 add data 746 rows
# complete batch 904 add data 746 rows
# complete batch 905 add data 746 rows
# complete batch 906 add data 746 rows
# complete batch 907 add data 746 rows
# complete batch 908 add data 746 rows
# complete batch 909 add data 746 rows
# complete batch 910 add data 746 rows
# complete batch 911 add data 746 rows
# complete batch 912 add data 746 rows
# complete batch 913 add data 746 rows
# complete batch 914 add data 746 rows
# complete batch 915 add data 746 rows
# complete batch 916 add data 746 rows
# complete batch 917 add data 746 rows
# complete batch 918 add data 746 rows
# complete batch 919 add data 746 rows
# complete batch 920 add data 746 rows
# complete batch 921 add data 746 rows
# complete batch 922 add data 746 rows
# complete batch 923 add data 746 rows
# complete batch 924 add data 746 rows
# complete batch 925 add data 746 rows
# complete batch 926 add data 746 rows
# complete batch 927 add data 746 rows
# complete batch 928 add data 746 rows
# complete batch 929 add data 746 rows
# complete batch 930 add data 746 rows
# complete batch 931 add data 746 rows
# complete batch 932 add data 746 rows
# complete batch 933 add data 746 rows
# complete batch 934 add data 746 rows
# complete batch 935 add data 746 rows
# complete batch 936 add data 746 rows
# complete batch 937 add data 746 rows
# complete batch 938 add data 746 rows
# complete batch 939 add data 746 rows
# complete batch 940 add data 746 rows
# complete batch 941 add data 746 rows
# complete batch 942 add data 746 rows
# complete batch 943 add data 746 rows
# complete batch 944 add data 746 rows
# complete batch 945 add data 746 rows
# complete batch 946 add data 746 rows
# complete batch 947 add data 746 rows
# complete batch 948 add data 746 rows
# complete batch 949 add data 746 rows
# complete batch 950 add data 746 rows
# complete batch 951 add data 746 rows
# complete batch 952 add data 746 rows
# complete batch 953 add data 746 rows
# complete batch 954 add data 746 rows
# complete batch 955 add data 746 rows
# complete batch 956 add data 746 rows
# complete batch 957 add data 746 rows
# complete batch 958 add data 746 rows
# complete batch 959 add data 746 rows
# complete batch 960 add data 746 rows
# complete batch 961 add data 746 rows
# complete batch 962 add data 746 rows
# complete batch 963 add data 746 rows
# complete batch 964 add data 746 rows
# complete batch 965 add data 746 rows
# complete batch 966 add data 746 rows
# complete batch 967 add data 746 rows
# complete batch 968 add data 746 rows
# complete batch 969 add data 746 rows
# complete batch 970 add data 746 rows
# complete batch 971 add data 746 rows
# complete batch 972 add data 746 rows
# complete batch 973 add data 746 rows
# complete batch 974 add data 746 rows
# complete batch 975 add data 746 rows
# complete batch 976 add data 746 rows
# complete batch 977 add data 746 rows
# complete batch 978 add data 746 rows
# complete batch 979 add data 746 rows
# complete batch 980 add data 746 rows
# complete batch 981 add data 746 rows
# complete batch 982 add data 746 rows
# complete batch 983 add data 746 rows
# complete batch 984 add data 746 rows
# complete batch 985 add data 746 rows
# complete batch 986 add data 746 rows
# complete batch 987 add data 746 rows
# complete batch 988 add data 746 rows
# complete batch 989 add data 746 rows
# complete batch 990 add data 746 rows
# complete batch 991 add data 746 rows
# complete batch 992 add data 746 rows
# complete batch 993 add data 746 rows
# complete batch 994 add data 746 rows
# complete batch 995 add data 746 rows
# complete batch 996 add data 746 rows
# complete batch 997 add data 746 rows
# complete batch 998 add data 746 rows
# complete batch 999 add data 746 rows
# complete batch 1000 add data 746 rows
# complete batch 1001 add data 746 rows
# complete batch 1002 add data 746 rows
# complete batch 1003 add data 746 rows
# complete batch 1004 add data 746 rows
# complete batch 1005 add data 746 rows
# complete batch 1006 add data 746 rows
# complete batch 1007 add data 746 rows
# complete batch 1008 add data 746 rows
# complete batch 1009 add data 746 rows
# complete batch 1010 add data 746 rows
# complete batch 1011 add data 746 rows
# complete batch 1012 add data 746 rows
# complete batch 1013 add data 746 rows
# complete batch 1014 add data 746 rows
# complete batch 1015 add data 746 rows
# complete batch 1016 add data 746 rows
# complete batch 1017 add data 746 rows
# complete batch 1018 add data 746 rows
# complete batch 1019 add data 746 rows
# complete batch 1020 add data 746 rows
# complete batch 1021 add data 746 rows
# complete batch 1022 add data 746 rows
# complete batch 1023 add data 746 rows
# complete batch 1024 add data 746 rows
# complete batch 1025 add data 746 rows
# complete batch 1026 add data 746 rows
# complete batch 1027 add data 746 rows
# complete batch 1028 add data 746 rows
# complete batch 1029 add data 746 rows
# complete batch 1030 add data 746 rows
# complete batch 1031 add data 746 rows
# complete batch 1032 add data 746 rows
# complete batch 1033 add data 746 rows
# complete batch 1034 add data 746 rows
# complete batch 1035 add data 746 rows
# complete batch 1036 add data 746 rows
# complete batch 1037 add data 746 rows
# complete batch 1038 add data 746 rows
# complete batch 1039 add data 746 rows
# complete batch 1040 add data 746 rows
# complete batch 1041 add data 746 rows
# complete batch 1042 add data 746 rows
# complete batch 1043 add data 746 rows
# complete batch 1044 add data 746 rows
# complete batch 1045 add data 746 rows
# complete batch 1046 add data 746 rows
# complete batch 1047 add data 746 rows
# complete batch 1048 add data 746 rows
# complete batch 1049 add data 746 rows
# complete batch 1050 add data 746 rows
# complete batch 1051 add data 746 rows
# complete batch 1052 add data 746 rows
# complete batch 1053 add data 746 rows
# complete batch 1054 add data 746 rows
# complete batch 1055 add data 746 rows
# complete batch 1056 add data 746 rows
# complete batch 1057 add data 746 rows
# complete batch 1058 add data 746 rows
# complete batch 1059 add data 746 rows
# complete batch 1060 add data 746 rows
# complete batch 1061 add data 746 rows
# complete batch 1062 add data 746 rows
# complete batch 1063 add data 746 rows
# complete batch 1064 add data 746 rows
# complete batch 1065 add data 746 rows
# complete batch 1066 add data 746 rows
# complete batch 1067 add data 746 rows
# complete batch 1068 add data 746 rows
# complete batch 1069 add data 746 rows
# complete batch 1070 add data 746 rows
# complete batch 1071 add data 746 rows
# complete batch 1072 add data 746 rows
# complete batch 1073 add data 746 rows
# complete batch 1074 add data 746 rows
# complete batch 1075 add data 746 rows
# complete batch 1076 add data 746 rows
# complete batch 1077 add data 746 rows
# complete batch 1078 add data 746 rows
# complete batch 1079 add data 746 rows
# complete batch 1080 add data 746 rows
# complete batch 1081 add data 746 rows
# complete batch 1082 add data 746 rows
# complete batch 1083 add data 746 rows
# complete batch 1084 add data 746 rows
# complete batch 1085 add data 746 rows
# complete batch 1086 add data 746 rows
# complete batch 1087 add data 746 rows
# complete batch 1088 add data 746 rows
# complete batch 1089 add data 746 rows
# complete batch 1090 add data 746 rows
# complete batch 1091 add data 746 rows
# complete batch 1092 add data 746 rows
# complete batch 1093 add data 746 rows
# complete batch 1094 add data 746 rows
# complete batch 1095 add data 746 rows
# complete batch 1096 add data 746 rows
# complete batch 1097 add data 746 rows
# complete batch 1098 add data 746 rows
# complete batch 1099 add data 746 rows
# complete batch 1100 add data 746 rows
# complete batch 1101 add data 746 rows
# complete batch 1102 add data 746 rows
# complete batch 1103 add data 746 rows
# complete batch 1104 add data 746 rows
# complete batch 1105 add data 746 rows
# complete batch 1106 add data 746 rows
# complete batch 1107 add data 746 rows
# complete batch 1108 add data 746 rows
# complete batch 1109 add data 746 rows
# complete batch 1110 add data 746 rows
# complete batch 1111 add data 746 rows
# complete batch 1112 add data 746 rows
# complete batch 1113 add data 746 rows
# complete batch 1114 add data 746 rows
# complete batch 1115 add data 746 rows
# complete batch 1116 add data 746 rows
# complete batch 1117 add data 746 rows
# complete batch 1118 add data 746 rows
# complete batch 1119 add data 746 rows
# complete batch 1120 add data 746 rows
# complete batch 1121 add data 746 rows
# complete batch 1122 add data 746 rows
# complete batch 1123 add data 746 rows
# complete batch 1124 add data 746 rows
# complete batch 1125 add data 746 rows
# complete batch 1126 add data 746 rows
# complete batch 1127 add data 746 rows
# complete batch 1128 add data 746 rows
# complete batch 1129 add data 746 rows
# complete batch 1130 add data 746 rows
# complete batch 1131 add data 746 rows
# complete batch 1132 add data 746 rows
# complete batch 1133 add data 746 rows
# complete batch 1134 add data 746 rows
# complete batch 1135 add data 746 rows
# complete batch 1136 add data 746 rows
# complete batch 1137 add data 746 rows
# complete batch 1138 add data 746 rows
# complete batch 1139 add data 746 rows
# complete batch 1140 add data 746 rows
# complete batch 1141 add data 746 rows
# complete batch 1142 add data 746 rows
# complete batch 1143 add data 746 rows
# complete batch 1144 add data 746 rows
# complete batch 1145 add data 746 rows
# complete batch 1146 add data 746 rows
# complete batch 1147 add data 746 rows
# complete batch 1148 add data 746 rows
# complete batch 1149 add data 746 rows
# complete batch 1150 add data 746 rows
# complete batch 1151 add data 746 rows
# complete batch 1152 add data 746 rows
# complete batch 1153 add data 746 rows
# complete batch 1154 add data 746 rows
# complete batch 1155 add data 746 rows
# complete batch 1156 add data 746 rows
# complete batch 1157 add data 746 rows
# complete batch 1158 add data 746 rows
# complete batch 1159 add data 746 rows
# complete batch 1160 add data 746 rows
# complete batch 1161 add data 746 rows
# complete batch 1162 add data 746 rows
# complete batch 1163 add data 746 rows
# complete batch 1164 add data 746 rows
# complete batch 1165 add data 746 rows
# complete batch 1166 add data 746 rows
# complete batch 1167 add data 746 rows
# complete batch 1168 add data 746 rows
# complete batch 1169 add data 746 rows
# complete batch 1170 add data 746 rows
# complete batch 1171 add data 746 rows
# complete batch 1172 add data 746 rows
# complete batch 1173 add data 746 rows
# complete batch 1174 add data 746 rows
# complete batch 1175 add data 746 rows
# complete batch 1176 add data 746 rows
# complete batch 1177 add data 746 rows
# complete batch 1178 add data 746 rows
# complete batch 1179 add data 746 rows
# complete batch 1180 add data 746 rows
# complete batch 1181 add data 746 rows
# complete batch 1182 add data 746 rows
# complete batch 1183 add data 746 rows
# complete batch 1184 add data 746 rows
# complete batch 1185 add data 746 rows
# complete batch 1186 add data 746 rows
# complete batch 1187 add data 746 rows
# complete batch 1188 add data 746 rows
# complete batch 1189 add data 746 rows
# complete batch 1190 add data 746 rows
# complete batch 1191 add data 746 rows
# complete batch 1192 add data 746 rows
# complete batch 1193 add data 746 rows
# complete batch 1194 add data 746 rows
# complete batch 1195 add data 746 rows
# complete batch 1196 add data 746 rows
# complete batch 1197 add data 746 rows
# complete batch 1198 add data 746 rows
# complete batch 1199 add data 746 rows
# complete batch 1200 add data 746 rows
# complete batch 1201 add data 746 rows
# complete batch 1202 add data 746 rows
# complete batch 1203 add data 746 rows
# complete batch 1204 add data 746 rows
# complete batch 1205 add data 746 rows
# complete batch 1206 add data 746 rows
# complete batch 1207 add data 746 rows
# complete batch 1208 add data 746 rows
# complete batch 1209 add data 746 rows
# complete batch 1210 add data 746 rows
# complete batch 1211 add data 746 rows
# complete batch 1212 add data 746 rows
# complete batch 1213 add data 746 rows
# complete batch 1214 add data 746 rows
# complete batch 1215 add data 746 rows
# complete batch 1216 add data 746 rows
# complete batch 1217 add data 746 rows
# complete batch 1218 add data 746 rows
# complete batch 1219 add data 746 rows
# complete batch 1220 add data 746 rows
# complete batch 1221 add data 746 rows
# complete batch 1222 add data 746 rows
# complete batch 1223 add data 746 rows
# complete batch 1224 add data 746 rows
# complete batch 1225 add data 746 rows
# complete batch 1226 add data 746 rows
# complete batch 1227 add data 746 rows
# complete batch 1228 add data 746 rows
# complete batch 1229 add data 746 rows
# complete batch 1230 add data 746 rows
# complete batch 1231 add data 746 rows
# complete batch 1232 add data 746 rows
# complete batch 1233 add data 746 rows
# complete batch 1234 add data 746 rows
# complete batch 1235 add data 746 rows
# complete batch 1236 add data 746 rows
# complete batch 1237 add data 746 rows
# complete batch 1238 add data 746 rows
# complete batch 1239 add data 746 rows
# complete batch 1240 add data 746 rows
# complete batch 1241 add data 746 rows
# complete batch 1242 add data 746 rows
# complete batch 1243 add data 746 rows
# complete batch 1244 add data 746 rows
# complete batch 1245 add data 746 rows
# complete batch 1246 add data 746 rows
# complete batch 1247 add data 746 rows
# complete batch 1248 add data 746 rows
# complete batch 1249 add data 746 rows
# complete batch 1250 add data 746 rows
# complete batch 1251 add data 746 rows
# complete batch 1252 add data 746 rows
# complete batch 1253 add data 746 rows
# complete batch 1254 add data 746 rows
# complete batch 1255 add data 746 rows
# complete batch 1256 add data 746 rows
# complete batch 1257 add data 746 rows
# complete batch 1258 add data 746 rows
# complete batch 1259 add data 746 rows
# complete batch 1260 add data 746 rows
# complete batch 1261 add data 746 rows
# complete batch 1262 add data 746 rows
# complete batch 1263 add data 746 rows
# complete batch 1264 add data 746 rows
# complete batch 1265 add data 746 rows
# complete batch 1266 add data 746 rows
# complete batch 1267 add data 746 rows
# complete batch 1268 add data 746 rows
# complete batch 1269 add data 746 rows
# complete batch 1270 add data 746 rows
# complete batch 1271 add data 746 rows
# complete batch 1272 add data 746 rows
# complete batch 1273 add data 746 rows
# complete batch 1274 add data 746 rows
# complete batch 1275 add data 746 rows
# complete batch 1276 add data 746 rows
# complete batch 1277 add data 746 rows
# complete batch 1278 add data 746 rows
# complete batch 1279 add data 746 rows
# complete batch 1280 add data 746 rows
# complete batch 1281 add data 746 rows
# complete batch 1282 add data 746 rows
# complete batch 1283 add data 746 rows
# complete batch 1284 add data 746 rows
# complete batch 1285 add data 746 rows
# complete batch 1286 add data 746 rows
# complete batch 1287 add data 746 rows
# complete batch 1288 add data 746 rows
# complete batch 1289 add data 746 rows
# complete batch 1290 add data 746 rows
# complete batch 1291 add data 746 rows
# complete batch 1292 add data 746 rows
# complete batch 1293 add data 746 rows
# complete batch 1294 add data 746 rows
# complete batch 1295 add data 746 rows
# complete batch 1296 add data 746 rows
# complete batch 1297 add data 746 rows
# complete batch 1298 add data 746 rows
# complete batch 1299 add data 746 rows
# complete batch 1300 add data 746 rows
# complete batch 1301 add data 746 rows
# complete batch 1302 add data 746 rows
# complete batch 1303 add data 746 rows
# complete batch 1304 add data 746 rows
# complete batch 1305 add data 746 rows
# complete batch 1306 add data 746 rows
# complete batch 1307 add data 746 rows
# complete batch 1308 add data 746 rows
# complete batch 1309 add data 746 rows
# complete batch 1310 add data 746 rows
# complete batch 1311 add data 746 rows
# complete batch 1312 add data 746 rows
# complete batch 1313 add data 746 rows
# complete batch 1314 add data 746 rows
# complete batch 1315 add data 746 rows
# complete batch 1316 add data 746 rows
# complete batch 1317 add data 746 rows
# complete batch 1318 add data 746 rows
# complete batch 1319 add data 746 rows
# complete batch 1320 add data 746 rows
# complete batch 1321 add data 746 rows
# complete batch 1322 add data 746 rows
# complete batch 1323 add data 746 rows
# complete batch 1324 add data 746 rows
# complete batch 1325 add data 746 rows
# complete batch 1326 add data 746 rows
# complete batch 1327 add data 746 rows
# complete batch 1328 add data 746 rows
# complete batch 1329 add data 746 rows
# complete batch 1330 add data 746 rows
# complete batch 1331 add data 746 rows
# complete batch 1332 add data 746 rows
# complete batch 1333 add data 746 rows
# complete batch 1334 add data 746 rows
# complete batch 1335 add data 746 rows
# complete batch 1336 add data 746 rows
# complete batch 1337 add data 746 rows
# complete batch 1338 add data 746 rows
# complete batch 1339 add data 746 rows
# complete batch 1340 add data 746 rows
# complete batch 1341 add data 746 rows
# complete batch 1342 add data 746 rows
# complete batch 1343 add data 746 rows
# complete batch 1344 add data 746 rows
# complete batch 1345 add data 746 rows
# complete batch 1346 add data 746 rows
# complete batch 1347 add data 746 rows
# complete batch 1348 add data 746 rows
# complete batch 1349 add data 746 rows
# complete batch 1350 add data 746 rows
# complete batch 1351 add data 746 rows
# complete batch 1352 add data 746 rows
# complete batch 1353 add data 746 rows
# complete batch 1354 add data 746 rows
# complete batch 1355 add data 746 rows
# complete batch 1356 add data 746 rows
# complete batch 1357 add data 746 rows
# complete batch 1358 add data 746 rows
# complete batch 1359 add data 746 rows
# complete batch 1360 add data 746 rows
# complete batch 1361 add data 746 rows
# complete batch 1362 add data 746 rows
# complete batch 1363 add data 746 rows
# complete batch 1364 add data 746 rows
# complete batch 1365 add data 746 rows
# complete batch 1366 add data 746 rows
# complete batch 1367 add data 746 rows
# complete batch 1368 add data 746 rows
# complete batch 1369 add data 746 rows
# complete batch 1370 add data 746 rows
# complete batch 1371 add data 746 rows
# complete batch 1372 add data 746 rows
# complete batch 1373 add data 746 rows
# complete batch 1374 add data 746 rows
# complete batch 1375 add data 746 rows
# complete batch 1376 add data 746 rows
# complete batch 1377 add data 746 rows
# complete batch 1378 add data 746 rows
# complete batch 1379 add data 746 rows
# complete batch 1380 add data 746 rows
# complete batch 1381 add data 746 rows
# complete batch 1382 add data 746 rows
# complete batch 1383 add data 746 rows
# complete batch 1384 add data 746 rows
# complete batch 1385 add data 746 rows
# complete batch 1386 add data 746 rows
# complete batch 1387 add data 746 rows
# complete batch 1388 add data 746 rows
# complete batch 1389 add data 746 rows
# complete batch 1390 add data 746 rows
# complete batch 1391 add data 746 rows
# complete batch 1392 add data 746 rows
# complete batch 1393 add data 746 rows
# complete batch 1394 add data 746 rows
# complete batch 1395 add data 746 rows
# complete batch 1396 add data 746 rows
# complete batch 1397 add data 746 rows
# complete batch 1398 add data 746 rows
# complete batch 1399 add data 746 rows
# complete batch 1400 add data 746 rows
# complete batch 1401 add data 746 rows
# complete batch 1402 add data 746 rows
# complete batch 1403 add data 746 rows
# complete batch 1404 add data 746 rows
# complete batch 1405 add data 746 rows
# complete batch 1406 add data 746 rows
# complete batch 1407 add data 746 rows
# complete batch 1408 add data 746 rows
# complete batch 1409 add data 746 rows
# complete batch 1410 add data 746 rows
# complete batch 1411 add data 746 rows
# complete batch 1412 add data 746 rows
# complete batch 1413 add data 746 rows
# complete batch 1414 add data 746 rows
# complete batch 1415 add data 746 rows
# complete batch 1416 add data 746 rows
# complete batch 1417 add data 746 rows
# complete batch 1418 add data 746 rows
# complete batch 1419 add data 746 rows
# complete batch 1420 add data 746 rows
# complete batch 1421 add data 746 rows
# complete batch 1422 add data 746 rows
# complete batch 1423 add data 746 rows
# complete batch 1424 add data 746 rows
# complete batch 1425 add data 746 rows
# complete batch 1426 add data 746 rows
# complete batch 1427 add data 746 rows
# complete batch 1428 add data 746 rows
# complete batch 1429 add data 746 rows
# complete batch 1430 add data 746 rows
# complete batch 1431 add data 746 rows
# complete batch 1432 add data 746 rows
# complete batch 1433 add data 746 rows
# complete batch 1434 add data 746 rows
# complete batch 1435 add data 746 rows
# complete batch 1436 add data 746 rows
# complete batch 1437 add data 746 rows
# complete batch 1438 add data 746 rows
# complete batch 1439 add data 746 rows
# complete batch 1440 add data 746 rows
# complete batch 1441 add data 746 rows
# complete batch 1442 add data 746 rows
# complete batch 1443 add data 746 rows
# complete batch 1444 add data 746 rows
# complete batch 1445 add data 746 rows
# complete batch 1446 add data 746 rows
# complete batch 1447 add data 746 rows
# complete batch 1448 add data 746 rows
# complete batch 1449 add data 746 rows
# complete batch 1450 add data 746 rows
# complete batch 1451 add data 746 rows
# complete batch 1452 add data 746 rows
# complete batch 1453 add data 746 rows
# complete batch 1454 add data 746 rows
# complete batch 1455 add data 746 rows
# complete batch 1456 add data 746 rows
# complete batch 1457 add data 746 rows
# complete batch 1458 add data 746 rows
# complete batch 1459 add data 746 rows
# complete batch 1460 add data 746 rows
# complete batch 1461 add data 746 rows
# complete batch 1462 add data 746 rows
# complete batch 1463 add data 746 rows
# complete batch 1464 add data 746 rows
# complete batch 1465 add data 746 rows
# complete batch 1466 add data 746 rows
# complete batch 1467 add data 746 rows
# complete batch 1468 add data 746 rows
# complete batch 1469 add data 746 rows
# complete batch 1470 add data 746 rows
# complete batch 1471 add data 746 rows
# complete batch 1472 add data 746 rows
# complete batch 1473 add data 746 rows
# complete batch 1474 add data 746 rows
# complete batch 1475 add data 746 rows
# complete batch 1476 add data 746 rows
# complete batch 1477 add data 746 rows
# complete batch 1478 add data 746 rows
# complete batch 1479 add data 746 rows
# complete batch 1480 add data 746 rows
# complete batch 1481 add data 746 rows
# complete batch 1482 add data 746 rows
# complete batch 1483 add data 746 rows
# complete batch 1484 add data 746 rows
# complete batch 1485 add data 746 rows
# complete batch 1486 add data 746 rows
# complete batch 1487 add data 746 rows
# complete batch 1488 add data 746 rows
# complete batch 1489 add data 746 rows
# complete batch 1490 add data 746 rows
# complete batch 1491 add data 746 rows
# complete batch 1492 add data 746 rows
# complete batch 1493 add data 746 rows
# complete batch 1494 add data 746 rows
# complete batch 1495 add data 746 rows
# complete batch 1496 add data 746 rows
# complete batch 1497 add data 746 rows
# complete batch 1498 add data 746 rows
# complete batch 1499 add data 746 rows
# complete batch 1500 add data 746 rows
# 1119746 1119746

# %%
hpv_table = pd.DataFrame(columns=['client_id', 'RACE_DESC', 'ETHNICITY_DESC','PatientZip','PatientCounty','GENDER',
                                   2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015,
                                   2016, 2017, 2018, 2019, 2020, 2021,2022,2023])
batches= len(df_hpv_distinct)//800
cur = 0
for i in range(801):

    tmp_df = df_hpv_distinct.iloc[cur:cur+batches]
    final = cur + batches
    if final > len(df_hpv_distinct):
        final = len(df_hpv_distinct)
    for j in range(cur,final):
        tmp = {}
        tmp['client_id'] = df_hpv_distinct['client_id'][j]
        tmp['ETHNICITY_DESC'] = df_hpv_distinct['ETHNICITY_DESC'][j]
        tmp['RACE_DESC'] = df_hpv_distinct['RACE_DESC'][j]
        tmp['PatientZip'] = df_hpv_distinct['PatientZip'][j]
        tmp['GENDER'] = df_hpv_distinct['GENDER'][j]
        tmp['PatientCounty'] = df_hpv_distinct['PatientCounty'][j]
        vax_year = df_hpv_distinct['vax_year'][j]
        vax_age = df_hpv_distinct['PatientAge'][j]
        for year in years:
            if year<vax_year:
                tmp[year] = np.nan
            else:
                tmp[year] = vax_age
                vax_age += 1
    #     print(tmp)
        tmp_df = pd.DataFrame([tmp])
        hpv_table = pd.concat([hpv_table, tmp_df], ignore_index=True)
    hpv_table.to_csv('../Data/Merged_data/AgeOut_hpv.csv', mode='a', header=(i==0), index=False)
    cur += batches
    print('complete batch',i,'add data',len(hpv_table),'rows')
    hpv_table = hpv_table.iloc[0:0]

print(cur,final)
# Out:
# complete batch 0 add data 592 rows
# complete batch 1 add data 592 rows
# complete batch 2 add data 592 rows
# complete batch 3 add data 592 rows
# complete batch 4 add data 592 rows
# complete batch 5 add data 592 rows
# complete batch 6 add data 592 rows
# complete batch 7 add data 592 rows
# complete batch 8 add data 592 rows
# complete batch 9 add data 592 rows
# complete batch 10 add data 592 rows
# complete batch 11 add data 592 rows
# complete batch 12 add data 592 rows
# complete batch 13 add data 592 rows
# complete batch 14 add data 592 rows
# complete batch 15 add data 592 rows
# complete batch 16 add data 592 rows
# complete batch 17 add data 592 rows
# complete batch 18 add data 592 rows
# complete batch 19 add data 592 rows
# complete batch 20 add data 592 rows
# complete batch 21 add data 592 rows
# complete batch 22 add data 592 rows
# complete batch 23 add data 592 rows
# complete batch 24 add data 592 rows
# complete batch 25 add data 592 rows
# complete batch 26 add data 592 rows
# complete batch 27 add data 592 rows
# complete batch 28 add data 592 rows
# complete batch 29 add data 592 rows
# complete batch 30 add data 592 rows
# complete batch 31 add data 592 rows
# complete batch 32 add data 592 rows
# complete batch 33 add data 592 rows
# complete batch 34 add data 592 rows
# complete batch 35 add data 592 rows
# complete batch 36 add data 592 rows
# complete batch 37 add data 592 rows
# complete batch 38 add data 592 rows
# complete batch 39 add data 592 rows
# complete batch 40 add data 592 rows
# complete batch 41 add data 592 rows
# complete batch 42 add data 592 rows
# complete batch 43 add data 592 rows
# complete batch 44 add data 592 rows
# complete batch 45 add data 592 rows
# complete batch 46 add data 592 rows
# complete batch 47 add data 592 rows
# complete batch 48 add data 592 rows
# complete batch 49 add data 592 rows
# complete batch 50 add data 592 rows
# complete batch 51 add data 592 rows
# complete batch 52 add data 592 rows
# complete batch 53 add data 592 rows
# complete batch 54 add data 592 rows
# complete batch 55 add data 592 rows
# complete batch 56 add data 592 rows
# complete batch 57 add data 592 rows
# complete batch 58 add data 592 rows
# complete batch 59 add data 592 rows
# complete batch 60 add data 592 rows
# complete batch 61 add data 592 rows
# complete batch 62 add data 592 rows
# complete batch 63 add data 592 rows
# complete batch 64 add data 592 rows
# complete batch 65 add data 592 rows
# complete batch 66 add data 592 rows
# complete batch 67 add data 592 rows
# complete batch 68 add data 592 rows
# complete batch 69 add data 592 rows
# complete batch 70 add data 592 rows
# complete batch 71 add data 592 rows
# complete batch 72 add data 592 rows
# complete batch 73 add data 592 rows
# complete batch 74 add data 592 rows
# complete batch 75 add data 592 rows
# complete batch 76 add data 592 rows
# complete batch 77 add data 592 rows
# complete batch 78 add data 592 rows
# complete batch 79 add data 592 rows
# complete batch 80 add data 592 rows
# complete batch 81 add data 592 rows
# complete batch 82 add data 592 rows
# complete batch 83 add data 592 rows
# complete batch 84 add data 592 rows
# complete batch 85 add data 592 rows
# complete batch 86 add data 592 rows
# complete batch 87 add data 592 rows
# complete batch 88 add data 592 rows
# complete batch 89 add data 592 rows
# complete batch 90 add data 592 rows
# complete batch 91 add data 592 rows
# complete batch 92 add data 592 rows
# complete batch 93 add data 592 rows
# complete batch 94 add data 592 rows
# complete batch 95 add data 592 rows
# complete batch 96 add data 592 rows
# complete batch 97 add data 592 rows
# complete batch 98 add data 592 rows
# complete batch 99 add data 592 rows
# complete batch 100 add data 592 rows
# complete batch 101 add data 592 rows
# complete batch 102 add data 592 rows
# complete batch 103 add data 592 rows
# complete batch 104 add data 592 rows
# complete batch 105 add data 592 rows
# complete batch 106 add data 592 rows
# complete batch 107 add data 592 rows
# complete batch 108 add data 592 rows
# complete batch 109 add data 592 rows
# complete batch 110 add data 592 rows
# complete batch 111 add data 592 rows
# complete batch 112 add data 592 rows
# complete batch 113 add data 592 rows
# complete batch 114 add data 592 rows
# complete batch 115 add data 592 rows
# complete batch 116 add data 592 rows
# complete batch 117 add data 592 rows
# complete batch 118 add data 592 rows
# complete batch 119 add data 592 rows
# complete batch 120 add data 592 rows
# complete batch 121 add data 592 rows
# complete batch 122 add data 592 rows
# complete batch 123 add data 592 rows
# complete batch 124 add data 592 rows
# complete batch 125 add data 592 rows
# complete batch 126 add data 592 rows
# complete batch 127 add data 592 rows
# complete batch 128 add data 592 rows
# complete batch 129 add data 592 rows
# complete batch 130 add data 592 rows
# complete batch 131 add data 592 rows
# complete batch 132 add data 592 rows
# complete batch 133 add data 592 rows
# complete batch 134 add data 592 rows
# complete batch 135 add data 592 rows
# complete batch 136 add data 592 rows
# complete batch 137 add data 592 rows
# complete batch 138 add data 592 rows
# complete batch 139 add data 592 rows
# complete batch 140 add data 592 rows
# complete batch 141 add data 592 rows
# complete batch 142 add data 592 rows
# complete batch 143 add data 592 rows
# complete batch 144 add data 592 rows
# complete batch 145 add data 592 rows
# complete batch 146 add data 592 rows
# complete batch 147 add data 592 rows
# complete batch 148 add data 592 rows
# complete batch 149 add data 592 rows
# complete batch 150 add data 592 rows
# complete batch 151 add data 592 rows
# complete batch 152 add data 592 rows
# complete batch 153 add data 592 rows
# complete batch 154 add data 592 rows
# complete batch 155 add data 592 rows
# complete batch 156 add data 592 rows
# complete batch 157 add data 592 rows
# complete batch 158 add data 592 rows
# complete batch 159 add data 592 rows
# complete batch 160 add data 592 rows
# complete batch 161 add data 592 rows
# complete batch 162 add data 592 rows
# complete batch 163 add data 592 rows
# complete batch 164 add data 592 rows
# complete batch 165 add data 592 rows
# complete batch 166 add data 592 rows
# complete batch 167 add data 592 rows
# complete batch 168 add data 592 rows
# complete batch 169 add data 592 rows
# complete batch 170 add data 592 rows
# complete batch 171 add data 592 rows
# complete batch 172 add data 592 rows
# complete batch 173 add data 592 rows
# complete batch 174 add data 592 rows
# complete batch 175 add data 592 rows
# complete batch 176 add data 592 rows
# complete batch 177 add data 592 rows
# complete batch 178 add data 592 rows
# complete batch 179 add data 592 rows
# complete batch 180 add data 592 rows
# complete batch 181 add data 592 rows
# complete batch 182 add data 592 rows
# complete batch 183 add data 592 rows
# complete batch 184 add data 592 rows
# complete batch 185 add data 592 rows
# complete batch 186 add data 592 rows
# complete batch 187 add data 592 rows
# complete batch 188 add data 592 rows
# complete batch 189 add data 592 rows
# complete batch 190 add data 592 rows
# complete batch 191 add data 592 rows
# complete batch 192 add data 592 rows
# complete batch 193 add data 592 rows
# complete batch 194 add data 592 rows
# complete batch 195 add data 592 rows
# complete batch 196 add data 592 rows
# complete batch 197 add data 592 rows
# complete batch 198 add data 592 rows
# complete batch 199 add data 592 rows
# complete batch 200 add data 592 rows
# complete batch 201 add data 592 rows
# complete batch 202 add data 592 rows
# complete batch 203 add data 592 rows
# complete batch 204 add data 592 rows
# complete batch 205 add data 592 rows
# complete batch 206 add data 592 rows
# complete batch 207 add data 592 rows
# complete batch 208 add data 592 rows
# complete batch 209 add data 592 rows
# complete batch 210 add data 592 rows
# complete batch 211 add data 592 rows
# complete batch 212 add data 592 rows
# complete batch 213 add data 592 rows
# complete batch 214 add data 592 rows
# complete batch 215 add data 592 rows
# complete batch 216 add data 592 rows
# complete batch 217 add data 592 rows
# complete batch 218 add data 592 rows
# complete batch 219 add data 592 rows
# complete batch 220 add data 592 rows
# complete batch 221 add data 592 rows
# complete batch 222 add data 592 rows
# complete batch 223 add data 592 rows
# complete batch 224 add data 592 rows
# complete batch 225 add data 592 rows
# complete batch 226 add data 592 rows
# complete batch 227 add data 592 rows
# complete batch 228 add data 592 rows
# complete batch 229 add data 592 rows
# complete batch 230 add data 592 rows
# complete batch 231 add data 592 rows
# complete batch 232 add data 592 rows
# complete batch 233 add data 592 rows
# complete batch 234 add data 592 rows
# complete batch 235 add data 592 rows
# complete batch 236 add data 592 rows
# complete batch 237 add data 592 rows
# complete batch 238 add data 592 rows
# complete batch 239 add data 592 rows
# complete batch 240 add data 592 rows
# complete batch 241 add data 592 rows
# complete batch 242 add data 592 rows
# complete batch 243 add data 592 rows
# complete batch 244 add data 592 rows
# complete batch 245 add data 592 rows
# complete batch 246 add data 592 rows
# complete batch 247 add data 592 rows
# complete batch 248 add data 592 rows
# complete batch 249 add data 592 rows
# complete batch 250 add data 592 rows
# complete batch 251 add data 592 rows
# complete batch 252 add data 592 rows
# complete batch 253 add data 592 rows
# complete batch 254 add data 592 rows
# complete batch 255 add data 592 rows
# complete batch 256 add data 592 rows
# complete batch 257 add data 592 rows
# complete batch 258 add data 592 rows
# complete batch 259 add data 592 rows
# complete batch 260 add data 592 rows
# complete batch 261 add data 592 rows
# complete batch 262 add data 592 rows
# complete batch 263 add data 592 rows
# complete batch 264 add data 592 rows
# complete batch 265 add data 592 rows
# complete batch 266 add data 592 rows
# complete batch 267 add data 592 rows
# complete batch 268 add data 592 rows
# complete batch 269 add data 592 rows
# complete batch 270 add data 592 rows
# complete batch 271 add data 592 rows
# complete batch 272 add data 592 rows
# complete batch 273 add data 592 rows
# complete batch 274 add data 592 rows
# complete batch 275 add data 592 rows
# complete batch 276 add data 592 rows
# complete batch 277 add data 592 rows
# complete batch 278 add data 592 rows
# complete batch 279 add data 592 rows
# complete batch 280 add data 592 rows
# complete batch 281 add data 592 rows
# complete batch 282 add data 592 rows
# complete batch 283 add data 592 rows
# complete batch 284 add data 592 rows
# complete batch 285 add data 592 rows
# complete batch 286 add data 592 rows
# complete batch 287 add data 592 rows
# complete batch 288 add data 592 rows
# complete batch 289 add data 592 rows
# complete batch 290 add data 592 rows
# complete batch 291 add data 592 rows
# complete batch 292 add data 592 rows
# complete batch 293 add data 592 rows
# complete batch 294 add data 592 rows
# complete batch 295 add data 592 rows
# complete batch 296 add data 592 rows
# complete batch 297 add data 592 rows
# complete batch 298 add data 592 rows
# complete batch 299 add data 592 rows
# complete batch 300 add data 592 rows
# complete batch 301 add data 592 rows
# complete batch 302 add data 592 rows
# complete batch 303 add data 592 rows
# complete batch 304 add data 592 rows
# complete batch 305 add data 592 rows
# complete batch 306 add data 592 rows
# complete batch 307 add data 592 rows
# complete batch 308 add data 592 rows
# complete batch 309 add data 592 rows
# complete batch 310 add data 592 rows
# complete batch 311 add data 592 rows
# complete batch 312 add data 592 rows
# complete batch 313 add data 592 rows
# complete batch 314 add data 592 rows
# complete batch 315 add data 592 rows
# complete batch 316 add data 592 rows
# complete batch 317 add data 592 rows
# complete batch 318 add data 592 rows
# complete batch 319 add data 592 rows
# complete batch 320 add data 592 rows
# complete batch 321 add data 592 rows
# complete batch 322 add data 592 rows
# complete batch 323 add data 592 rows
# complete batch 324 add data 592 rows
# complete batch 325 add data 592 rows
# complete batch 326 add data 592 rows
# complete batch 327 add data 592 rows
# complete batch 328 add data 592 rows
# complete batch 329 add data 592 rows
# complete batch 330 add data 592 rows
# complete batch 331 add data 592 rows
# complete batch 332 add data 592 rows
# complete batch 333 add data 592 rows
# complete batch 334 add data 592 rows
# complete batch 335 add data 592 rows
# complete batch 336 add data 592 rows
# complete batch 337 add data 592 rows
# complete batch 338 add data 592 rows
# complete batch 339 add data 592 rows
# complete batch 340 add data 592 rows
# complete batch 341 add data 592 rows
# complete batch 342 add data 592 rows
# complete batch 343 add data 592 rows
# complete batch 344 add data 592 rows
# complete batch 345 add data 592 rows
# complete batch 346 add data 592 rows
# complete batch 347 add data 592 rows
# complete batch 348 add data 592 rows
# complete batch 349 add data 592 rows
# complete batch 350 add data 592 rows
# complete batch 351 add data 592 rows
# complete batch 352 add data 592 rows
# complete batch 353 add data 592 rows
# complete batch 354 add data 592 rows
# complete batch 355 add data 592 rows
# complete batch 356 add data 592 rows
# complete batch 357 add data 592 rows
# complete batch 358 add data 592 rows
# complete batch 359 add data 592 rows
# complete batch 360 add data 592 rows
# complete batch 361 add data 592 rows
# complete batch 362 add data 592 rows
# complete batch 363 add data 592 rows
# complete batch 364 add data 592 rows
# complete batch 365 add data 592 rows
# complete batch 366 add data 592 rows
# complete batch 367 add data 592 rows
# complete batch 368 add data 592 rows
# complete batch 369 add data 592 rows
# complete batch 370 add data 592 rows
# complete batch 371 add data 592 rows
# complete batch 372 add data 592 rows
# complete batch 373 add data 592 rows
# complete batch 374 add data 592 rows
# complete batch 375 add data 592 rows
# complete batch 376 add data 592 rows
# complete batch 377 add data 592 rows
# complete batch 378 add data 592 rows
# complete batch 379 add data 592 rows
# complete batch 380 add data 592 rows
# complete batch 381 add data 592 rows
# complete batch 382 add data 592 rows
# complete batch 383 add data 592 rows
# complete batch 384 add data 592 rows
# complete batch 385 add data 592 rows
# complete batch 386 add data 592 rows
# complete batch 387 add data 592 rows
# complete batch 388 add data 592 rows
# complete batch 389 add data 592 rows
# complete batch 390 add data 592 rows
# complete batch 391 add data 592 rows
# complete batch 392 add data 592 rows
# complete batch 393 add data 592 rows
# complete batch 394 add data 592 rows
# complete batch 395 add data 592 rows
# complete batch 396 add data 592 rows
# complete batch 397 add data 592 rows
# complete batch 398 add data 592 rows
# complete batch 399 add data 592 rows
# complete batch 400 add data 592 rows
# complete batch 401 add data 592 rows
# complete batch 402 add data 592 rows
# complete batch 403 add data 592 rows
# complete batch 404 add data 592 rows
# complete batch 405 add data 592 rows
# complete batch 406 add data 592 rows
# complete batch 407 add data 592 rows
# complete batch 408 add data 592 rows
# complete batch 409 add data 592 rows
# complete batch 410 add data 592 rows
# complete batch 411 add data 592 rows
# complete batch 412 add data 592 rows
# complete batch 413 add data 592 rows
# complete batch 414 add data 592 rows
# complete batch 415 add data 592 rows
# complete batch 416 add data 592 rows
# complete batch 417 add data 592 rows
# complete batch 418 add data 592 rows
# complete batch 419 add data 592 rows
# complete batch 420 add data 592 rows
# complete batch 421 add data 592 rows
# complete batch 422 add data 592 rows
# complete batch 423 add data 592 rows
# complete batch 424 add data 592 rows
# complete batch 425 add data 592 rows
# complete batch 426 add data 592 rows
# complete batch 427 add data 592 rows
# complete batch 428 add data 592 rows
# complete batch 429 add data 592 rows
# complete batch 430 add data 592 rows
# complete batch 431 add data 592 rows
# complete batch 432 add data 592 rows
# complete batch 433 add data 592 rows
# complete batch 434 add data 592 rows
# complete batch 435 add data 592 rows
# complete batch 436 add data 592 rows
# complete batch 437 add data 592 rows
# complete batch 438 add data 592 rows
# complete batch 439 add data 592 rows
# complete batch 440 add data 592 rows
# complete batch 441 add data 592 rows
# complete batch 442 add data 592 rows
# complete batch 443 add data 592 rows
# complete batch 444 add data 592 rows
# complete batch 445 add data 592 rows
# complete batch 446 add data 592 rows
# complete batch 447 add data 592 rows
# complete batch 448 add data 592 rows
# complete batch 449 add data 592 rows
# complete batch 450 add data 592 rows
# complete batch 451 add data 592 rows
# complete batch 452 add data 592 rows
# complete batch 453 add data 592 rows
# complete batch 454 add data 592 rows
# complete batch 455 add data 592 rows
# complete batch 456 add data 592 rows
# complete batch 457 add data 592 rows
# complete batch 458 add data 592 rows
# complete batch 459 add data 592 rows
# complete batch 460 add data 592 rows
# complete batch 461 add data 592 rows
# complete batch 462 add data 592 rows
# complete batch 463 add data 592 rows
# complete batch 464 add data 592 rows
# complete batch 465 add data 592 rows
# complete batch 466 add data 592 rows
# complete batch 467 add data 592 rows
# complete batch 468 add data 592 rows
# complete batch 469 add data 592 rows
# complete batch 470 add data 592 rows
# complete batch 471 add data 592 rows
# complete batch 472 add data 592 rows
# complete batch 473 add data 592 rows
# complete batch 474 add data 592 rows
# complete batch 475 add data 592 rows
# complete batch 476 add data 592 rows
# complete batch 477 add data 592 rows
# complete batch 478 add data 592 rows
# complete batch 479 add data 592 rows
# complete batch 480 add data 592 rows
# complete batch 481 add data 592 rows
# complete batch 482 add data 592 rows
# complete batch 483 add data 592 rows
# complete batch 484 add data 592 rows
# complete batch 485 add data 592 rows
# complete batch 486 add data 592 rows
# complete batch 487 add data 592 rows
# complete batch 488 add data 592 rows
# complete batch 489 add data 592 rows
# complete batch 490 add data 592 rows
# complete batch 491 add data 592 rows
# complete batch 492 add data 592 rows
# complete batch 493 add data 592 rows
# complete batch 494 add data 592 rows
# complete batch 495 add data 592 rows
# complete batch 496 add data 592 rows
# complete batch 497 add data 592 rows
# complete batch 498 add data 592 rows
# complete batch 499 add data 592 rows
# complete batch 500 add data 592 rows
# complete batch 501 add data 592 rows
# complete batch 502 add data 592 rows
# complete batch 503 add data 592 rows
# complete batch 504 add data 592 rows
# complete batch 505 add data 592 rows
# complete batch 506 add data 592 rows
# complete batch 507 add data 592 rows
# complete batch 508 add data 592 rows
# complete batch 509 add data 592 rows
# complete batch 510 add data 592 rows
# complete batch 511 add data 592 rows
# complete batch 512 add data 592 rows
# complete batch 513 add data 592 rows
# complete batch 514 add data 592 rows
# complete batch 515 add data 592 rows
# complete batch 516 add data 592 rows
# complete batch 517 add data 592 rows
# complete batch 518 add data 592 rows
# complete batch 519 add data 592 rows
# complete batch 520 add data 592 rows
# complete batch 521 add data 592 rows
# complete batch 522 add data 592 rows
# complete batch 523 add data 592 rows
# complete batch 524 add data 592 rows
# complete batch 525 add data 592 rows
# complete batch 526 add data 592 rows
# complete batch 527 add data 592 rows
# complete batch 528 add data 592 rows
# complete batch 529 add data 592 rows
# complete batch 530 add data 592 rows
# complete batch 531 add data 592 rows
# complete batch 532 add data 592 rows
# complete batch 533 add data 592 rows
# complete batch 534 add data 592 rows
# complete batch 535 add data 592 rows
# complete batch 536 add data 592 rows
# complete batch 537 add data 592 rows
# complete batch 538 add data 592 rows
# complete batch 539 add data 592 rows
# complete batch 540 add data 592 rows
# complete batch 541 add data 592 rows
# complete batch 542 add data 592 rows
# complete batch 543 add data 592 rows
# complete batch 544 add data 592 rows
# complete batch 545 add data 592 rows
# complete batch 546 add data 592 rows
# complete batch 547 add data 592 rows
# complete batch 548 add data 592 rows
# complete batch 549 add data 592 rows
# complete batch 550 add data 592 rows
# complete batch 551 add data 592 rows
# complete batch 552 add data 592 rows
# complete batch 553 add data 592 rows
# complete batch 554 add data 592 rows
# complete batch 555 add data 592 rows
# complete batch 556 add data 592 rows
# complete batch 557 add data 592 rows
# complete batch 558 add data 592 rows
# complete batch 559 add data 592 rows
# complete batch 560 add data 592 rows
# complete batch 561 add data 592 rows
# complete batch 562 add data 592 rows
# complete batch 563 add data 592 rows
# complete batch 564 add data 592 rows
# complete batch 565 add data 592 rows
# complete batch 566 add data 592 rows
# complete batch 567 add data 592 rows
# complete batch 568 add data 592 rows
# complete batch 569 add data 592 rows
# complete batch 570 add data 592 rows
# complete batch 571 add data 592 rows
# complete batch 572 add data 592 rows
# complete batch 573 add data 592 rows
# complete batch 574 add data 592 rows
# complete batch 575 add data 592 rows
# complete batch 576 add data 592 rows
# complete batch 577 add data 592 rows
# complete batch 578 add data 592 rows
# complete batch 579 add data 592 rows
# complete batch 580 add data 592 rows
# complete batch 581 add data 592 rows
# complete batch 582 add data 592 rows
# complete batch 583 add data 592 rows
# complete batch 584 add data 592 rows
# complete batch 585 add data 592 rows
# complete batch 586 add data 592 rows
# complete batch 587 add data 592 rows
# complete batch 588 add data 592 rows
# complete batch 589 add data 592 rows
# complete batch 590 add data 592 rows
# complete batch 591 add data 592 rows
# complete batch 592 add data 592 rows
# complete batch 593 add data 592 rows
# complete batch 594 add data 592 rows
# complete batch 595 add data 592 rows
# complete batch 596 add data 592 rows
# complete batch 597 add data 592 rows
# complete batch 598 add data 592 rows
# complete batch 599 add data 592 rows
# complete batch 600 add data 592 rows
# complete batch 601 add data 592 rows
# complete batch 602 add data 592 rows
# complete batch 603 add data 592 rows
# complete batch 604 add data 592 rows
# complete batch 605 add data 592 rows
# complete batch 606 add data 592 rows
# complete batch 607 add data 592 rows
# complete batch 608 add data 592 rows
# complete batch 609 add data 592 rows
# complete batch 610 add data 592 rows
# complete batch 611 add data 592 rows
# complete batch 612 add data 592 rows
# complete batch 613 add data 592 rows
# complete batch 614 add data 592 rows
# complete batch 615 add data 592 rows
# complete batch 616 add data 592 rows
# complete batch 617 add data 592 rows
# complete batch 618 add data 592 rows
# complete batch 619 add data 592 rows
# complete batch 620 add data 592 rows
# complete batch 621 add data 592 rows
# complete batch 622 add data 592 rows
# complete batch 623 add data 592 rows
# complete batch 624 add data 592 rows
# complete batch 625 add data 592 rows
# complete batch 626 add data 592 rows
# complete batch 627 add data 592 rows
# complete batch 628 add data 592 rows
# complete batch 629 add data 592 rows
# complete batch 630 add data 592 rows
# complete batch 631 add data 592 rows
# complete batch 632 add data 592 rows
# complete batch 633 add data 592 rows
# complete batch 634 add data 592 rows
# complete batch 635 add data 592 rows
# complete batch 636 add data 592 rows
# complete batch 637 add data 592 rows
# complete batch 638 add data 592 rows
# complete batch 639 add data 592 rows
# complete batch 640 add data 592 rows
# complete batch 641 add data 592 rows
# complete batch 642 add data 592 rows
# complete batch 643 add data 592 rows
# complete batch 644 add data 592 rows
# complete batch 645 add data 592 rows
# complete batch 646 add data 592 rows
# complete batch 647 add data 592 rows
# complete batch 648 add data 592 rows
# complete batch 649 add data 592 rows
# complete batch 650 add data 592 rows
# complete batch 651 add data 592 rows
# complete batch 652 add data 592 rows
# complete batch 653 add data 592 rows
# complete batch 654 add data 592 rows
# complete batch 655 add data 592 rows
# complete batch 656 add data 592 rows
# complete batch 657 add data 592 rows
# complete batch 658 add data 592 rows
# complete batch 659 add data 592 rows
# complete batch 660 add data 592 rows
# complete batch 661 add data 592 rows
# complete batch 662 add data 592 rows
# complete batch 663 add data 592 rows
# complete batch 664 add data 592 rows
# complete batch 665 add data 592 rows
# complete batch 666 add data 592 rows
# complete batch 667 add data 592 rows
# complete batch 668 add data 592 rows
# complete batch 669 add data 592 rows
# complete batch 670 add data 592 rows
# complete batch 671 add data 592 rows
# complete batch 672 add data 592 rows
# complete batch 673 add data 592 rows
# complete batch 674 add data 592 rows
# complete batch 675 add data 592 rows
# complete batch 676 add data 592 rows
# complete batch 677 add data 592 rows
# complete batch 678 add data 592 rows
# complete batch 679 add data 592 rows
# complete batch 680 add data 592 rows
# complete batch 681 add data 592 rows
# complete batch 682 add data 592 rows
# complete batch 683 add data 592 rows
# complete batch 684 add data 592 rows
# complete batch 685 add data 592 rows
# complete batch 686 add data 592 rows
# complete batch 687 add data 592 rows
# complete batch 688 add data 592 rows
# complete batch 689 add data 592 rows
# complete batch 690 add data 592 rows
# complete batch 691 add data 592 rows
# complete batch 692 add data 592 rows
# complete batch 693 add data 592 rows
# complete batch 694 add data 592 rows
# complete batch 695 add data 592 rows
# complete batch 696 add data 592 rows
# complete batch 697 add data 592 rows
# complete batch 698 add data 592 rows
# complete batch 699 add data 592 rows
# complete batch 700 add data 592 rows
# complete batch 701 add data 592 rows
# complete batch 702 add data 592 rows
# complete batch 703 add data 592 rows
# complete batch 704 add data 592 rows
# complete batch 705 add data 592 rows
# complete batch 706 add data 592 rows
# complete batch 707 add data 592 rows
# complete batch 708 add data 592 rows
# complete batch 709 add data 592 rows
# complete batch 710 add data 592 rows
# complete batch 711 add data 592 rows
# complete batch 712 add data 592 rows
# complete batch 713 add data 592 rows
# complete batch 714 add data 592 rows
# complete batch 715 add data 592 rows
# complete batch 716 add data 592 rows
# complete batch 717 add data 592 rows
# complete batch 718 add data 592 rows
# complete batch 719 add data 592 rows
# complete batch 720 add data 592 rows
# complete batch 721 add data 592 rows
# complete batch 722 add data 592 rows
# complete batch 723 add data 592 rows
# complete batch 724 add data 592 rows
# complete batch 725 add data 592 rows
# complete batch 726 add data 592 rows
# complete batch 727 add data 592 rows
# complete batch 728 add data 592 rows
# complete batch 729 add data 592 rows
# complete batch 730 add data 592 rows
# complete batch 731 add data 592 rows
# complete batch 732 add data 592 rows
# complete batch 733 add data 592 rows
# complete batch 734 add data 592 rows
# complete batch 735 add data 592 rows
# complete batch 736 add data 592 rows
# complete batch 737 add data 592 rows
# complete batch 738 add data 592 rows
# complete batch 739 add data 592 rows
# complete batch 740 add data 592 rows
# complete batch 741 add data 592 rows
# complete batch 742 add data 592 rows
# complete batch 743 add data 592 rows
# complete batch 744 add data 592 rows
# complete batch 745 add data 592 rows
# complete batch 746 add data 592 rows
# complete batch 747 add data 592 rows
# complete batch 748 add data 592 rows
# complete batch 749 add data 592 rows
# complete batch 750 add data 592 rows
# complete batch 751 add data 592 rows
# complete batch 752 add data 592 rows
# complete batch 753 add data 592 rows
# complete batch 754 add data 592 rows
# complete batch 755 add data 592 rows
# complete batch 756 add data 592 rows
# complete batch 757 add data 592 rows
# complete batch 758 add data 592 rows
# complete batch 759 add data 592 rows
# complete batch 760 add data 592 rows
# complete batch 761 add data 592 rows
# complete batch 762 add data 592 rows
# complete batch 763 add data 592 rows
# complete batch 764 add data 592 rows
# complete batch 765 add data 592 rows
# complete batch 766 add data 592 rows
# complete batch 767 add data 592 rows
# complete batch 768 add data 592 rows
# complete batch 769 add data 592 rows
# complete batch 770 add data 592 rows
# complete batch 771 add data 592 rows
# complete batch 772 add data 592 rows
# complete batch 773 add data 592 rows
# complete batch 774 add data 592 rows
# complete batch 775 add data 592 rows
# complete batch 776 add data 592 rows
# complete batch 777 add data 592 rows
# complete batch 778 add data 592 rows
# complete batch 779 add data 592 rows
# complete batch 780 add data 592 rows
# complete batch 781 add data 592 rows
# complete batch 782 add data 592 rows
# complete batch 783 add data 592 rows
# complete batch 784 add data 592 rows
# complete batch 785 add data 592 rows
# complete batch 786 add data 592 rows
# complete batch 787 add data 592 rows
# complete batch 788 add data 592 rows
# complete batch 789 add data 592 rows
# complete batch 790 add data 592 rows
# complete batch 791 add data 592 rows
# complete batch 792 add data 592 rows
# complete batch 793 add data 592 rows
# complete batch 794 add data 592 rows
# complete batch 795 add data 592 rows
# complete batch 796 add data 592 rows
# complete batch 797 add data 592 rows
# complete batch 798 add data 592 rows
# complete batch 799 add data 592 rows
# complete batch 800 add data 400 rows
# 474192 474000

# %% [markdown]
# # Creating the Distinct HPV vaccination Patient Table

# %%
def calculate12Gaps(df,doses):
    gaps = []
    ages = []
    ids = []
    for i in range(0,len(df),doses):
    #     print(df['vax_year'][i+1])
        gap = (df['vax_year'][i+1]-df['vax_year'][i])*12 + df['vax_month'][i+1]-df['vax_month'][i]
    #     print(gap)
        ages.append(df['PatientAge'][i])
        gaps.append(gap)
        ids.append(df['client_id'][i])
    dct = {
        'gaps':gaps,
        'ages':ages,
        'client_id':ids
    }
    res = pd.DataFrame(dct)
    return res
    
def SplitClientsByNumberOfDose(patients):
    lst_of_df = []
    grouped = patients.groupby(['client_id']).size().reset_index(name='count')
    print(grouped['count'].unique())
    numbers = list(grouped['count'].unique())
    lst_of_df.append(numbers)
    for number in numbers:
        clients = np.array(grouped[grouped['count']==number]['client_id'])
        clients = set(clients)
        lst_of_df.append(patients[patients['client_id'].isin(clients)]
                         .sort_values(by=['client_id','vax_year','vax_month'],ascending=True).reset_index())
    return lst_of_df,grouped

def calculate13Gaps(df,doses):
    gaps = []
    ages = []
    ids = []
    for i in range(0,len(df),doses):
    #     print(df['vax_year'][i+1])
        gap = (df['vax_year'][i+2]-df['vax_year'][i])*12 + df['vax_month'][i+2]-df['vax_month'][i]
    #     print(gap)
        ages.append(df['PatientAge'][i])
        gaps.append(gap)
        ids.append(df['client_id'][i])
    dct = {
        'gaps':gaps,
        'ages':ages,
        'client_id':ids
    }
    res = pd.DataFrame(dct)
    return res

# %%
df_hpv_distinct = df_hpv_distinct.sort_values(by=['client_id'],ascending=True)
df_hpv_distinct=df_hpv_distinct.reset_index()

grouped = df_hpv.groupby(['client_id']).size().reset_index(name='count')
grouped = grouped.sort_values(by=['client_id'],ascending=True)
grouped = grouped.reset_index()

# %%
grouped['count'].unique()
# Out:
# array([1, 2, 3, 4])

# %% [markdown]
# ### Here's the problem we have 5 patients who got 4 doses in total. We have to delete those patients.

# %% [markdown]
# ### add the 'number of doses' column

# %%
df_hpv_distinct['Doses'] = grouped['count']
df_hpv_distinct['Doses'].isna().any()
# df_hpv_distinct
# Out:
#         level_0  index  client_id  vax_month  vax_year  \
# 0        243042      0       9910          7      2017
# 1        321936      1      12409          6      2019
# 2         75954      3      21455          1      2013
# 3             0      4      21656          1      2008
# 4             1      6      25161          1      2008
# ...         ...    ...        ...        ...       ...
# 473995   445067  61717   25255074          1      2023
# 473996   449100  61719   25255370          3      2023
# 473997   453062  61720   25255470          5      2023
# 473998   433030  61397   25257514          9      2022
# 473999   460987  61399   25258136          8      2023
#
#                         RACE_DESC          ETHNICITY_DESC  PatientAge  \
# 0                           WHITE  NOT HISPANIC OR LATINO          24
# 1                           OTHER  NOT HISPANIC OR LATINO          22
# 2                           ASIAN  NOT HISPANIC OR LATINO          17
# 3       BLACK OR AFRICAN-AMERICAN  NOT HISPANIC OR LATINO          15
# 4                           WHITE  NOT HISPANIC OR LATINO          15
# ...                           ...                     ...         ...
# 473995                      OTHER                 UNKNOWN          10
# 473996                    UNKNOWN      HISPANIC OR LATINO          10
# 473997                      WHITE  NOT HISPANIC OR LATINO          10
# 473998                      OTHER      HISPANIC OR LATINO          13
# 473999                      OTHER                 UNKNOWN          17
#
#         Trade_name  PatientZip PatientCounty ProviderCounty GENDER  Doses
# 0       Gardasil 9     11756.0        Nassau         Nassau      M      1
# 1         Gardasil     11590.0        Nassau         Nassau      M      2
# 2         Gardasil     11040.0        Nassau       New York      M      1
# 3         Gardasil     11520.0        Nassau         Broome      F      2
# 4         Gardasil     11561.0        Nassau         Cayuga      F      1
# ...            ...         ...           ...            ...    ...    ...
# 473995  Gardasil 9     11933.0       Suffolk        Suffolk      F      2
# 473996  Gardasil 9     11742.0       Suffolk        Suffolk      F      1
# 473997  Gardasil 9     11949.0       Suffolk        Suffolk      M      2
# 473998  Gardasil 9     11580.0        Nassau         Nassau      M      2
# 473999  Gardasil 9     11575.0        Nassau         Nassau      M      1
#
# [474000 rows x 14 columns]

# %% [markdown]
# ### add the dose12gap column

# %%
df_hpv_distinct=df_hpv_distinct.drop('index',axis=1)

# %%
res,gp = SplitClientsByNumberOfDose(df_hpv)
dose3 = calculate12Gaps(res[3],3)
dose2 = calculate12Gaps(res[2],2)

print(len(dose3)+len(dose2)+len(res[1]),len(df_hpv_distinct))
# Out:
# [1 2 3 4]
# 473995 474000

# %%
# We have to drop the patients who got 4 doses.
condition = df_hpv_distinct['Doses'] > 3
df_hpv_distinct = df_hpv_distinct.drop(df_hpv_distinct[condition].index)
len(df_hpv_distinct)
# Out:
# 473995

# %% [markdown]
# dose12 = pd.concat([dose3,dose2])
# dose12.set_index('client_id', inplace=True)
# df_hpv_distinct.set_index('client_id',inplace = True)

# %%
df_hpv_distinct['dose12gap'] = dose12['gaps']

# %%
df_hpv_distinct
# Out:
#            level_0  vax_month  vax_year                  RACE_DESC  \
# client_id
# 9910        243042          7      2017                      WHITE
# 12409       321936          6      2019                      OTHER
# 21455        75954          1      2013                      ASIAN
# 21656            0          1      2008  BLACK OR AFRICAN-AMERICAN
# 25161            1          1      2008                      WHITE
# ...            ...        ...       ...                        ...
# 25255074    445067          1      2023                      OTHER
# 25255370    449100          3      2023                    UNKNOWN
# 25255470    453062          5      2023                      WHITE
# 25257514    433030          9      2022                      OTHER
# 25258136    460987          8      2023                      OTHER
#
#                    ETHNICITY_DESC  PatientAge  Trade_name  PatientZip  \
# client_id
# 9910       NOT HISPANIC OR LATINO          24  Gardasil 9     11756.0
# 12409      NOT HISPANIC OR LATINO          22    Gardasil     11590.0
# 21455      NOT HISPANIC OR LATINO          17    Gardasil     11040.0
# 21656      NOT HISPANIC OR LATINO          15    Gardasil     11520.0
# 25161      NOT HISPANIC OR LATINO          15    Gardasil     11561.0
# ...                           ...         ...         ...         ...
# 25255074                  UNKNOWN          10  Gardasil 9     11933.0
# 25255370       HISPANIC OR LATINO          10  Gardasil 9     11742.0
# 25255470   NOT HISPANIC OR LATINO          10  Gardasil 9     11949.0
# 25257514       HISPANIC OR LATINO          13  Gardasil 9     11580.0
# 25258136                  UNKNOWN          17  Gardasil 9     11575.0
#
#           PatientCounty ProviderCounty GENDER  Doses  dose12gap
# client_id
# 9910             Nassau         Nassau      M      1        NaN
# 12409            Nassau         Nassau      M      2        2.0
# 21455            Nassau       New York      M      1        NaN
# 21656            Nassau         Broome      F      2        4.0
# 25161            Nassau         Cayuga      F      1        NaN
# ...                 ...            ...    ...    ...        ...
# 25255074        Suffolk        Suffolk      F      2        7.0
# 25255370        Suffolk        Suffolk      F      1        NaN
# 25255470        Suffolk        Suffolk      M      2        6.0
# 25257514         Nassau         Nassau      M      2       12.0
# 25258136         Nassau         Nassau      M      1        NaN
#
# [473995 rows x 13 columns]

# %%
df_hpv_distinct.reset_index(inplace=True)
df_hpv_distinct
# Out:
#         client_id  level_0  vax_month  vax_year                  RACE_DESC  \
# 0            9910   243042          7      2017                      WHITE
# 1           12409   321936          6      2019                      OTHER
# 2           21455    75954          1      2013                      ASIAN
# 3           21656        0          1      2008  BLACK OR AFRICAN-AMERICAN
# 4           25161        1          1      2008                      WHITE
# ...           ...      ...        ...       ...                        ...
# 473990   25255074   445067          1      2023                      OTHER
# 473991   25255370   449100          3      2023                    UNKNOWN
# 473992   25255470   453062          5      2023                      WHITE
# 473993   25257514   433030          9      2022                      OTHER
# 473994   25258136   460987          8      2023                      OTHER
#
#                 ETHNICITY_DESC  PatientAge  Trade_name  PatientZip  \
# 0       NOT HISPANIC OR LATINO          24  Gardasil 9     11756.0
# 1       NOT HISPANIC OR LATINO          22    Gardasil     11590.0
# 2       NOT HISPANIC OR LATINO          17    Gardasil     11040.0
# 3       NOT HISPANIC OR LATINO          15    Gardasil     11520.0
# 4       NOT HISPANIC OR LATINO          15    Gardasil     11561.0
# ...                        ...         ...         ...         ...
# 473990                 UNKNOWN          10  Gardasil 9     11933.0
# 473991      HISPANIC OR LATINO          10  Gardasil 9     11742.0
# 473992  NOT HISPANIC OR LATINO          10  Gardasil 9     11949.0
# 473993      HISPANIC OR LATINO          13  Gardasil 9     11580.0
# 473994                 UNKNOWN          17  Gardasil 9     11575.0
#
#        PatientCounty ProviderCounty GENDER  Doses  dose12gap
# 0             Nassau         Nassau      M      1        NaN
# 1             Nassau         Nassau      M      2        2.0
# 2             Nassau       New York      M      1        NaN
# 3             Nassau         Broome      F      2        4.0
# 4             Nassau         Cayuga      F      1        NaN
# ...              ...            ...    ...    ...        ...
# 473990       Suffolk        Suffolk      F      2        7.0
# 473991       Suffolk        Suffolk      F      1        NaN
# 473992       Suffolk        Suffolk      M      2        6.0
# 473993        Nassau         Nassau      M      2       12.0
# 473994        Nassau         Nassau      M      1        NaN
#
# [473995 rows x 14 columns]

# %% [markdown]
# ## add the wholeseries gap

# %%
dose3w = calculate13Gaps(res[3],3)

dosewhole = pd.concat([dose2,dose3w])

# %%
df_hpv_distinct.set_index('client_id',inplace = True)
dosewhole.set_index('client_id',inplace = True)

# %%
df_hpv_distinct['wholeSeriesGap'] = dosewhole['gaps']

# %%
df_hpv_distinct[df_hpv_distinct['Doses'] == 3]
# Out:
#         client_id  level_0  vax_month  vax_year                  RACE_DESC  \
# 5           28751   224421         12      2016  BLACK OR AFRICAN-AMERICAN
# 6           33176   254881          9      2017  BLACK OR AFRICAN-AMERICAN
# 7           34816   172240          9      2015                      WHITE
# 16          53770    13942          9      2008                    UNKNOWN
# 18          66483   229535          2      2017                      WHITE
# ...           ...      ...        ...       ...                        ...
# 473416   25009592   445943          2      2023                      OTHER
# 473565   25055926   443124         12      2022                      WHITE
# 473607   25065247   453054          5      2023                      WHITE
# 473775   25122667   447985          3      2023                      ASIAN
# 473828   25143938   435142          9      2022                    UNKNOWN
#
#                 ETHNICITY_DESC  PatientAge   Trade_name  PatientZip  \
# 5       NOT HISPANIC OR LATINO          11   Gardasil 9     11510.0
# 6       NOT HISPANIC OR LATINO          16     Gardasil     11510.0
# 7       NOT HISPANIC OR LATINO          13     Gardasil     11950.0
# 16                     UNKNOWN          11     Gardasil     11722.0
# 18      NOT HISPANIC OR LATINO          15   Gardasil 9     11572.0
# ...                        ...         ...          ...         ...
# 473416  NOT HISPANIC OR LATINO          17   Gardasil 9     11714.0
# 473565      HISPANIC OR LATINO          15   Gardasil 9     11706.0
# 473607      HISPANIC OR LATINO          15   Gardasil 9     11722.0
# 473775  NOT HISPANIC OR LATINO          16   Gardasil 9     11753.0
# 473828                 UNKNOWN          15  Unspecified     11795.0
#
#        PatientCounty ProviderCounty GENDER  Doses  dose12gap  wholeSeriesGap
# 5             Nassau         Nassau      M      3        3.0             6.0
# 6             Nassau         Nassau      F      3        3.0             6.0
# 7            Suffolk          Tioga      M      3        2.0             8.0
# 16           Suffolk        Suffolk      F      3        3.0             6.0
# 18            Nassau         Nassau      F      3       20.0            29.0
# ...              ...            ...    ...    ...        ...             ...
# 473416        Nassau         Nassau      F      3        4.0             9.0
# 473565       Suffolk        Suffolk      F      3        4.0            12.0
# 473607       Suffolk    Westchester      M      3        3.0             7.0
# 473775        Nassau       New York      F      3        2.0             8.0
# 473828       Suffolk         Nassau      M      3        4.0            14.0
#
# [128771 rows x 15 columns]

# %%
len(df_hpv_distinct)
# Out:
# 473995

# %%
df_hpv_distinct['dose12gap'].unique()
# Out:
# array([ nan,   2.,   4.,   3.,   5.,  13.,  51.,  20.,   8.,  88.,   7.,
#         17.,   9.,  14.,  27.,  12.,   1.,  16.,  15.,  31.,  34.,  79.,
#         25.,  58.,  10.,  19.,  18.,  39.,  24.,   6.,  11.,  23.,  21.,
#         62.,  33.,  28.,  40.,  26.,  22.,  29.,  47.,  64.,  55.,  59.,
#         49.,  32.,  60.,  30.,  44.,  69.,  70.,  37.,  50.,  46.,  36.,
#         38.,  73.,  45.,  53.,  35.,  48.,  57.,  42.,  41.,  43.,  61.,
#         86.,  52.,  63.,  83., 179.,  77., 102.,  72.,  84.,  65.,  96.,
#         54., 132., 120.,  71.,  89.,  92.,  66.,  81.,  74.,  67., 107.,
#         56.,  80.,  76.,   0., 143., 182., 110.,  91.,  68., 130., 118.,
#         78., 115.,  85., 101., 121.,  99.,  95.,  75.,  82., 123., 111.,
#         90., 114., 100.,  87.,  94., 144., 116.,  98., 168., 165., 173.,
#        147., 113.,  97.,  93., 105., 128., 117., 137., 190., 104., 124.,
#        109., 108., 127., 142., 162., 141., 145., 103., 106., 148., 136.,
#        112., 131., 156., 153., 134., 133., 126., 119., 125., 138., 150.])

# %%
df_hpv_distinct.to_csv('../Data/Merged_data/distinct_hpv_patients.csv', index=False)
