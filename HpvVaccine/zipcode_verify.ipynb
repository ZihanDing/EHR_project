# %%
import pandas as pd

# %%
file_address = '../Data/zip/longislandzip.csv'

df1 = pd.read_csv(file_address)

# %%
file_address = '../Data/zip/New_York_State_ZIP_Codes-County_FIPS_Cross-Reference.csv'

df2 = pd.read_csv(file_address)

# %%
file_address = '../Data/zip/nyslongislandzip.csv'

df3 = pd.read_csv(file_address)

# %%
file_address = '../Data/zip/zip_code_database.csv'

df4 = pd.read_csv(file_address)

# %%
len(df1)
# Out:
# 220

# %%
df1
# Out:
#        zip      type  decommissioned       primary_city  \
# 0      501    UNIQUE               0         Holtsville
# 1      544    UNIQUE               0         Holtsville
# 2     6390    PO BOX               0     Fishers Island
# 3    11001  STANDARD               0        Floral Park
# 4    11003  STANDARD               0             Elmont
# ..     ...       ...             ...                ...
# 215  11975    PO BOX               0          Wainscott
# 216  11976  STANDARD               0         Water Mill
# 217  11977  STANDARD               0        Westhampton
# 218  11978  STANDARD               0  Westhampton Beach
# 219  11980  STANDARD               0            Yaphank
#
#                                      acceptable_cities  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                         Fishers Isle
# 3    Bellerose Vil, Bellerose Village, S Floral Par...
# ...

# %%
df2[df2['County Name'].isin(['Suffolk','Nassau'])]
# Out:
#      County Name  State FIPS  County Code  County FIPS  ZIP Code   File Date
# 1079      Nassau          36           59        36059     11001  07/25/2007
# 1080      Nassau          36           59        36059     11002  07/25/2007
# 1081      Nassau          36           59        36059     11003  07/25/2007
# 1082      Nassau          36           59        36059     11010  07/25/2007
# 1083      Nassau          36           59        36059     11020  07/25/2007
# ...          ...         ...          ...          ...       ...         ...
# 2161     Suffolk          36          103        36103     11975  07/25/2007
# 2162     Suffolk          36          103        36103     11976  07/25/2007
# 2163     Suffolk          36          103        36103     11977  07/25/2007
# 2164     Suffolk          36          103        36103     11978  07/25/2007
# 2165     Suffolk          36          103        36103     11980  07/25/2007
#
# [219 rows x 6 columns]

# %%
df3
# Out:
#     County Name  State FIPS  County Code  County FIPS  ZIP Code  File Date
# 0        Nassau          36           59        36059     11001  7/25/2007
# 1        Nassau          36           59        36059     11002  7/25/2007
# 2        Nassau          36           59        36059     11003  7/25/2007
# 3        Nassau          36           59        36059     11010  7/25/2007
# 4        Nassau          36           59        36059     11020  7/25/2007
# ..          ...         ...          ...          ...       ...        ...
# 214     Suffolk          36          103        36103     11975  7/25/2007
# 215     Suffolk          36          103        36103     11976  7/25/2007
# 216     Suffolk          36          103        36103     11977  7/25/2007
# 217     Suffolk          36          103        36103     11978  7/25/2007
# 218     Suffolk          36          103        36103     11980  7/25/2007
#
# [219 rows x 6 columns]

# %%
df4
# Out:
#          zip      type  decommissioned primary_city acceptable_cities  \
# 0        501    UNIQUE               0   Holtsville               NaN
# 1        544    UNIQUE               0   Holtsville               NaN
# 2        601  STANDARD               0     Adjuntas               NaN
# 3        602  STANDARD               0       Aguada               NaN
# 4        603  STANDARD               0    Aguadilla             Ramey
# ...      ...       ...             ...          ...               ...
# 42627  99926    PO BOX               0   Metlakatla               NaN
# 42628  99927    PO BOX               0  Point Baker               NaN
# 42629  99928    PO BOX               0    Ward Cove               NaN
# 42630  99929    PO BOX               0     Wrangell               NaN
# 42631  99950    PO BOX               0    Ketchikan  Edna Bay, Kasaan
#
#                                      unacceptable_cities state  \
# ...

# %%
df4['county'].unique()
# Out:
# array(['Suffolk County', 'Adjuntas Municipio', 'Aguada Municipio', ...,
#        'Wrangell City and Borough', 'Prince of Wales-Hyder Census Area',
#        'Prince of Wales-Outer Ketchikan Borough'], dtype=object)
