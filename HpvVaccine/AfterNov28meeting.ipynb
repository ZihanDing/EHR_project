# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
file_address = '../Data/Ageout_tdap.csv'

df_age_tdap = pd.read_csv(file_address)


file_address = '../Data/Ageout_hpv.csv'

df_age_hpv = pd.read_csv(file_address)


file_address = '../Data/Ageout_total.csv'

df_age_total = pd.read_csv(file_address)

# %%
df_age_tdap
# Out:
#         client_id  PatientZip                  RACE_DESC GENDER  2008  2009  \
# 0         2127579     11722.0                      OTHER      F  11.0  12.0
# 1         7075021     11726.0                    UNKNOWN      F  11.0  12.0
# 2         7075061     11953.0  BLACK OR AFRICAN-AMERICAN      M  11.0  12.0
# 3         7075159     11706.0                      WHITE      F  10.0  11.0
# 4         5141625     11783.0                    UNKNOWN      F  14.0  15.0
# ...           ...         ...                        ...    ...   ...   ...
# 816809    9040275     11554.0                    UNKNOWN      M   NaN   NaN
# 816810    9070862     11554.0                      WHITE      M   NaN   NaN
# 816811    9081272     11554.0                      WHITE      M   NaN   NaN
# 816812    9081389     11554.0                      OTHER      F   NaN   NaN
# 816813    8677064     11554.0                      WHITE      M   NaN   NaN
#
#         2010  2011  2012  2013  2014  2015  2016  2017  2018  2019  2020  2021
# 0       13.0  14.0  15.0  16.0  17.0  18.0  19.0  20.0  21.0  22.0  23.0    24
# 1       13.0  14.0  15.0  16.0  17.0  18.0  19.0  20.0  21.0  22.0  23.0    24
# 2       13.0  14.0  15.0  16.0  17.0  18.0  19.0  20.0  21.0  22.0  23.0    24
# 3       12.0  13.0  14.0  15.0  16.0  17.0  18.0  19.0  20.0  21.0  22.0    23
# 4       16.0  17.0  18.0  19.0  20.0  21.0  22.0  23.0  24.0  25.0  26.0    27
# ...      ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 816809   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    11
# 816810   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    10
# 816811   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    26
# 816812   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    44
# 816813   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    11
#
# [816814 rows x 18 columns]

# %%
df_age_total
# Out:
#         client_id  PatientZip                  RACE_DESC GENDER  2008  2009  \
# 0        11549954     11746.0                      WHITE      F  10.0  11.0
# 1         2821980     11003.0                      OTHER      M  15.0  16.0
# 2         2822587     11003.0  BLACK OR AFRICAN-AMERICAN      F  18.0  19.0
# 3         2822600     11003.0                      WHITE      F  10.0  11.0
# 4         2823201     11003.0  BLACK OR AFRICAN-AMERICAN      M  11.0  12.0
# ...           ...         ...                        ...    ...   ...   ...
# 888272   20621590     11771.0                      WHITE      M   NaN   NaN
# 888273   20619677     11771.0                      OTHER      M   NaN   NaN
# 888274   20616417     11771.0                      WHITE      M   NaN   NaN
# 888275   20590548     11771.0                      WHITE      M   NaN   NaN
# 888276    6997565     11542.0                      WHITE      F   NaN   NaN
#
#         2010  2011  2012  2013  2014  2015  2016  2017  2018  2019  2020  2021
# 0       12.0  13.0  14.0  15.0  16.0  17.0  18.0  19.0  20.0  21.0  22.0    23
# 1       17.0  18.0  19.0  20.0  21.0  22.0  23.0  24.0  25.0  26.0  27.0    28
# 2       20.0  21.0  22.0  23.0  24.0  25.0  26.0  27.0  28.0  29.0  30.0    31
# 3       12.0  13.0  14.0  15.0  16.0  17.0  18.0  19.0  20.0  21.0  22.0    23
# 4       13.0  14.0  15.0  16.0  17.0  18.0  19.0  20.0  21.0  22.0  23.0    24
# ...      ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 888272   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    50
# 888273   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    27
# 888274   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    50
# 888275   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    26
# 888276   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    11
#
# [888277 rows x 18 columns]

# %%
df_age_hpv
# Out:
#         client_id  PatientZip RACE_DESC GENDER  2008  2009  2010  2011  2012  \
# 0         4399655     11772.0     WHITE      F  13.0  14.0  15.0  16.0  17.0
# 1         2920340     11561.0   UNKNOWN      F  13.0  14.0  15.0  16.0  17.0
# 2         2099305     11520.0     OTHER      F  12.0  13.0  14.0  15.0  16.0
# 3         4566203     11743.0     WHITE      F  15.0  16.0  17.0  18.0  19.0
# 4         5430731     11940.0   UNKNOWN      F  13.0  14.0  15.0  16.0  17.0
# ...           ...         ...       ...    ...   ...   ...   ...   ...   ...
# 410773    4309767     11010.0     WHITE      F   NaN   NaN   NaN   NaN   NaN
# 410774    4309774     11542.0     WHITE      M   NaN   NaN   NaN   NaN   NaN
# 410775    2880383     11766.0     OTHER      M   NaN   NaN   NaN   NaN   NaN
# 410776    4309975     11040.0     ASIAN      M   NaN   NaN   NaN   NaN   NaN
# 410777    7623991     11717.0     WHITE      F   NaN   NaN   NaN   NaN   NaN
#
#         2013  2014  2015  2016  2017  2018  2019  2020  2021
# 0       18.0  19.0  20.0  21.0  22.0  23.0  24.0  25.0    26
# 1       18.0  19.0  20.0  21.0  22.0  23.0  24.0  25.0    26
# 2       17.0  18.0  19.0  20.0  21.0  22.0  23.0  24.0    25
# 3       20.0  21.0  22.0  23.0  24.0  25.0  26.0  27.0    28
# 4       18.0  19.0  20.0  21.0  22.0  23.0  24.0  25.0    26
# ...      ...   ...   ...   ...   ...   ...   ...   ...   ...
# 410773   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    15
# 410774   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    15
# 410775   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    13
# 410776   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    15
# 410777   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    10
#
# [410778 rows x 18 columns]

# %%
# Read Hpv data
file_address = '../Data/NassauCountyHPV.csv'

df_hpv_nassau = pd.read_csv(file_address)

file_address = '../Data/SuffolkCountyHPV.csv'

df_hpv_suffolk = pd.read_csv(file_address)

# %%
file_address = '../Data/longislandzip.csv'

df_zipcode = pd.read_csv(file_address)

# Clean Data , drop N/A zipcode
df_hpv_nassau.dropna(subset=['PatientZip'], inplace=True)
df_hpv_suffolk.dropna(subset=['PatientZip'], inplace=True)

zips = np.array(df_zipcode['zip'])
# Clean Data, drop zipcode not on the Long Island
df_hpv_nassau = df_hpv_nassau[df_hpv_nassau['PatientZip'].isin(zips)]
df_hpv_suffolk = df_hpv_suffolk[df_hpv_suffolk['PatientZip'].isin(zips)]

# %%
df_hpv= pd.concat([df_hpv_nassau,df_hpv_suffolk])

# %%
df_hpv_distinct = df_hpv.drop_duplicates(subset=['client_id','vax_year'], keep='first')

# %% [markdown]
# let's pick 2015

# %%
lst = list(df_age_hpv['2015'])

# %%
lst = list(df_age_hpv['2015'])
count = 0
for i in range(len(lst)):
    if lst[i]:
        if lst[i]<=13 and lst[i]>=9:
            count += 1
print(count)
# Out:
# 36383

# %%
lst = list(df_age_total['2015'])
count = 0
for i in range(len(lst)):
    if lst[i]:
        if lst[i]<=13 and lst[i]>=9:
            count += 1
print(count)
# Out:
# 67487

# %%
years = list(df_age_total.columns)[4:]

# %%
years
# Out:
# ['2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '2017',
#  '2018',
#  '2019',
#  '2020',
#  '2021']

# %%
def calamount(df,years,start,end):
    rate = []
    for year in years:
        lst = list(df[year])
        count = 0
        for i in range(len(lst)):
            if lst[i]:
                if lst[i]<=end and lst[i]>=start:
                    count += 1
#     print(count)
        rate.append(count)
    return rate

# %%
hpv_amount = calamount(df_age_hpv,years,9,13)
total_amount = calamount(df_age_total,years,9,13)
tdap_amount = calamount(df_age_tdap,years,9,13)


hpv_amount= np.array(hpv_amount)
total_amount = np.array(total_amount)
tdap_amount = np.array(tdap_amount)

hpv_Rate = hpv_amount/total_amount
tdap_Rate = tdap_amount/total_amount
hpv_Rate
# Out:
# array([0.21629109, 0.14120398, 0.1166874 , 0.12372146, 0.15596571,
#        0.20462293, 0.23096106, 0.2803004 , 0.33133316, 0.3668877 ,
#        0.40897801, 0.45060299, 0.4469871 , 0.42882062])

# %%
tdap_Rate
# Out:
# array([0.83708914, 0.92124729, 0.96621137, 0.98236388, 0.98064886,
#        0.97582806, 0.97552436, 0.97017292, 0.96949411, 0.96949329,
#        0.96740019, 0.96141968, 0.96496276, 0.96829011])

# %%
hpv_Rate = hpv_amount/total_amount
hpv_Rate
# Out:
# array([0.26328314, 0.15678532, 0.12404079, 0.1292429 , 0.16306512,
#        0.21478992, 0.24277024, 0.29571741, 0.34883026, 0.38544462,
#        0.42824949, 0.47347001, 0.46719314, 0.44645469])

# %%
plt.figure(figsize=(10, 4))

plt.bar(years, total_amount,alpha=0.7)
# plt.plot(years, hpv_Rate,'*-', color='red', label='rate')
# plt.plot(years, values1,'s-', color='blue', label='Age 11')
# plt.plot(years, values2,'o-', color='red', label='Age 12')
# plt.plot(years, values3,'^-', color='g', label='Age 13')

# plt.ylim([0.2,0.65])
plt.xlabel('Year')
plt.ylabel('Number of Populations')
plt.title('Total Populations (Age group 9 - 13)')

# plt.vlines([2], 0.05, 0.50, linestyles='dashed', colors='black')
# plt.vlines([12], 0.05, 0.50, linestyles='dashed', colors='blue')

plt.xticks(years)
# plt.legend()
# 
plt.grid(True,linestyle='--', color='gray', linewidth=0.5, alpha=0.5)

plt.show()

# %%
plt.figure(figsize=(10, 4))

plt.bar(years, hpv_Rate,alpha=0.7)
# plt.plot(years, hpv_Rate,'*-', color='red', label='rate')
# plt.plot(years, values1,'s-', color='blue', label='Age 11')
# plt.plot(years, values2,'o-', color='red', label='Age 12')
# plt.plot(years, values3,'^-', color='g', label='Age 13')

# plt.ylim([0.2,0.65])
plt.xlabel('Vaccine Year')
plt.ylabel('Rate')
plt.title('Hpv vaccine Rate (Age group 9 - 13)')

plt.vlines([2], 0.05, 0.50, linestyles='dashed', colors='black')
plt.vlines([12], 0.05, 0.50, linestyles='dashed', colors='blue')

plt.xticks(years)
# plt.legend()
# 
plt.grid(True,linestyle='--', color='gray', linewidth=0.5, alpha=0.5)

plt.show()

# %%
split_rate = []
split_rate.append()

# %%
hpv_amount = calamount(df_age_hpv,years,9,9)
total_amount = calamount(df_age_total,years,9,9)
# tdap_amount = calamount(df_age_total,years,9,11)
hpv_amount= np.array(hpv_amount)
total_amount = np.array(total_amount)
hpv_Rate9 = hpv_amount/total_amount
hpv_Rate9
# Out:
# array([0.34355828, 0.14214464, 0.10976314, 0.121802  , 0.12004405,
#        0.1342013 , 0.12962963, 0.20306025, 0.21368513, 0.27610554,
#        0.41743869, 0.42633229, 0.39635678, 0.41267868])

# %%
hpv_amount = calamount(df_age_hpv,years,10,10)
total_amount = calamount(df_age_total,years,10,10)
# tdap_amount = calamount(df_age_total,years,11,13)
hpv_amount= np.array(hpv_amount)
total_amount = np.array(total_amount)
hpv_Rate10 = hpv_amount/total_amount
hpv_Rate10
# Out:
# array([0.06524981, 0.05760194, 0.04674094, 0.05482271, 0.05389222,
#        0.05905642, 0.0519378 , 0.08711896, 0.10597202, 0.1228133 ,
#        0.15385002, 0.2224331 , 0.20557092, 0.18792998])

# %%
hpv_amount = calamount(df_age_hpv,years,11,11)
total_amount = calamount(df_age_total,years,11,11)
# tdap_amount = calamount(df_age_total,years,11,13)
hpv_amount= np.array(hpv_amount)
total_amount = np.array(total_amount)
hpv_Rate11 = hpv_amount/total_amount
hpv_Rate11
# Out:
# array([0.10158554, 0.05846896, 0.0702846 , 0.08229915, 0.10028738,
#        0.13671475, 0.16346587, 0.19540844, 0.24363259, 0.27089831,
#        0.30878361, 0.33621922, 0.32219758, 0.31263011])

# %%
hpv_amount = calamount(df_age_hpv,years,12,12)
total_amount = calamount(df_age_total,years,12,12)
# tdap_amount = calamount(df_age_total,years,11,13)
hpv_amount= np.array(hpv_amount)
total_amount = np.array(total_amount)
hpv_Rate12 = hpv_amount/total_amount
hpv_Rate12
# Out:
# array([0.55008832, 0.14730185, 0.10962046, 0.1342109 , 0.17145875,
#        0.22664333, 0.26406991, 0.33535022, 0.38485388, 0.42628509,
#        0.47108848, 0.5010439 , 0.49475773, 0.46382226])

# %%
hpv_amount = calamount(df_age_hpv,years,13,13)
total_amount = calamount(df_age_total,years,13,13)
# tdap_amount = calamount(df_age_total,years,11,13)
hpv_amount= np.array(hpv_amount)
total_amount = np.array(total_amount)
hpv_Rate13 = hpv_amount/total_amount
hpv_Rate13
# Out:
# array([0.55914226, 0.56795201, 0.21326649, 0.18502121, 0.23923117,
#        0.31270524, 0.3612275 , 0.42143759, 0.49482523, 0.53174352,
#        0.5773661 , 0.60643246, 0.60973482, 0.58806206])

# %%
hpv_amount
# Out:
# array([ 2162,  2950,  2940,  3859,  5286,  7423,  9090, 11832, 14523,
#        15945, 17618, 18854, 18630, 16556])

# %%
total_amount
# Out:
# array([ 2081, 18267, 25769, 27919, 29775, 31350, 32908, 33842, 36168,
#        36048, 35877, 36345, 36445, 34820])

# %%
plt.figure(figsize=(10, 4))

plt.plot(years, hpv_Rate,'*-', color='red', label='rate')
plt.plot(years, values1,'s-', color='blue', label='Age 11')
plt.plot(years, values2,'o-', color='red', label='Age 12')
plt.plot(years, values3,'^-', color='g', label='Age 13')

plt.ylim([0,0.6])
plt.xlabel('Vaccine Year')
plt.ylabel('Rate')
plt.title('Hpv vaccine Rate (Age group 9 - 13)')

plt.vlines([3], 0.05, 0.55, linestyles='dashed', colors='black')
plt.vlines([11], 0.05, 0.55, linestyles='dashed', colors='blue')

plt.xticks(years)
# plt.legend()
# 
plt.grid(True,linestyle='--', color='gray', linewidth=0.5, alpha=0.5)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/6m/wc_77wtn3sd7gb5y6h6yz01w0000gn/T/ipykernel_50777/3185133835.py in <module>
#       2
#       3 plt.plot(years, hpv_Rate,'*-', color='red', label='rate')
# ----> 4 plt.plot(years, values1,'s-', color='blue', label='Age 11')
#       5 plt.plot(years, values2,'o-', color='red', label='Age 12')
#       6 plt.plot(years, values3,'^-', color='g', label='Age 13')
#
# NameError: name 'values1' is not defined

# %% [markdown]
# 12 year old bug fixing:

# %%
tmplist = list(df_age_total['2008'])

# %%
c=0
for i in range(len(tmplist)):
    if tmplist[i] and tmplist[i] == 12.0:
        c += 1
print(c)
# Out:
# 3081

# %%
total_amount = calamount(df_age_tdap,years,12,12)

# %%
split_rate = []
split_rate.append(hpv_Rate9)
split_rate.append(hpv_Rate10)
split_rate.append(hpv_Rate11)
split_rate.append(hpv_Rate12)
split_rate.append(hpv_Rate13)

# %%
plt.figure(figsize=(10, 4))

# plt.plot(years, values0,'*-', color='black', label='Age 10')
# plt.plot(years, values1,'s-', color='blue', label='Age 11')
# plt.plot(years, values2,'o-', color='red', label='Age 12')
# plt.plot(years, values3,'^-', color='g', label='Age 13')
colors = ['#4B0082','#ee82ee','#0000FF','#00FF00','#FFFF00','#FF7F00','#FF0000']
for i in range(len(split_rate)):
    plt.plot(years,split_rate[i],'o-',color =colors[i+2],label = 'Age '+str(i+9) )
    
plt.xlabel('Vaccine Year')
plt.ylabel('Rate')
plt.title('Hpv vaccine Rate from 2008 to 2021 (Age 9 - 13)')

plt.xticks(years)
plt.legend(loc = 'best')
# 
plt.grid(True,linestyle='--', color='gray', linewidth=0.5, alpha=0.5)

plt.show()

# %%
hpv_Rate
# Out:
# array([0.41448139, 0.31499811, 0.28018675, 0.30775202, 0.37541058,
#        0.45600333, 0.4915334 , 0.53911124, 0.56832183, 0.57628439,
#        0.57608261, 0.56088817, 0.5008121 , 0.42914144])

# %%
tdap_Rate
# Out:
# array([1.57428003, 2.00910465, 2.25882748, 2.38119085, 2.30221259,
#        2.1230202 , 2.02468555, 1.82306222, 1.62922169, 1.49511594,
#        1.34520326, 1.18463294, 1.07195947, 0.96122059])

# %%
from matplotlib_venn import venn2
# from matplotlib_venn import venn
import numpy as np

fig, axes = plt.subplots(3, 5, figsize=(15, 9))
axes = axes.flatten()

# percentages = np.linspace(0, 1, 14)  # 生成14个不同的百分比值

for i in range(len(hpv_Rate)):
    ax = axes[i]
    set1_percentage = round(hpv_amount[i],2)
    set2_percentage = round(tdap_amount[i],2)
    intersection_percentage = round(set1_percentage+set2_percentage-total_amount[i],2)
    print(set1_percentage,set2_percentage,intersection_percentage,years[i])

    venn = venn2(subsets=(set1_percentage, set2_percentage, intersection_percentage),
          set_labels=('hpv', 'tdap'), ax=ax)

    ax.set_title(years[i])

#     for text in venn.subset_labels:
#         text.set_text()
for j in range(len(years), len(axes)):
    axes[j].axis('off')
    

plt.tight_layout()


plt.show()
# Out:
# 6949 26894 1715 2008
# 8151 53179 3605 2009
# 9756 80783 6931 2010
# 11975 95083 10268 2011
# 16047 100897 14056 2012
# 22450 107062 19798 2013
# 27507 116183 24592 2014
# 35532 122983 31751 2015
# 43456 127154 39455 2016
# 48635 128517 44591 2017
# 54008 127751 49703 2018
# 58363 124525 53366 2019
# 56235 121401 51827 2020
# 52362 118235 48490 2021

# %% [markdown]
# fixing tdap bug

# %%
tdap_amount
# Out:
# array([ 26895,  53181,  80796,  95100, 100929, 107100, 116221, 123033,
#        127208, 128571, 127797, 124576, 121438, 118283])

# %%
tmplist = list(df_age_tdap['2008'])
c=0
for i in range(len(tmplist)):
    if tmplist[i] and tmplist[i]<=13.0 and tmplist[i]>=9:
        c += 1
print(c)
# Out:
# 26894

# %%
tmplist = list(df_age_total['2008'])
c=0
for i in range(len(tmplist)):
    if tmplist[i] and tmplist[i]<=13.0 and tmplist[i]>=9:
        c += 1
print(c)
# Out:
# 32128

# %%
total_amount
# Out:
# array([ 4337,  5835, 20744, 26878, 29135, 31365, 33173, 34864, 35847,
#        37866, 37678, 38057, 37823, 38030])

# %% [markdown]
# ## generate race

# %%
df_age_hpv
# Out:
#         client_id  PatientZip RACE_DESC GENDER  2008  2009  2010  2011  2012  \
# 0         4399655     11772.0     WHITE      F  13.0  14.0  15.0  16.0  17.0
# 1         2920340     11561.0   UNKNOWN      F  13.0  14.0  15.0  16.0  17.0
# 2         2099305     11520.0     OTHER      F  12.0  13.0  14.0  15.0  16.0
# 3         4566203     11743.0     WHITE      F  15.0  16.0  17.0  18.0  19.0
# 4         5430731     11940.0   UNKNOWN      F  13.0  14.0  15.0  16.0  17.0
# ...           ...         ...       ...    ...   ...   ...   ...   ...   ...
# 410773    4309767     11010.0     WHITE      F   NaN   NaN   NaN   NaN   NaN
# 410774    4309774     11542.0     WHITE      M   NaN   NaN   NaN   NaN   NaN
# 410775    2880383     11766.0     OTHER      M   NaN   NaN   NaN   NaN   NaN
# 410776    4309975     11040.0     ASIAN      M   NaN   NaN   NaN   NaN   NaN
# 410777    7623991     11717.0     WHITE      F   NaN   NaN   NaN   NaN   NaN
#
#         2013  2014  2015  2016  2017  2018  2019  2020  2021
# 0       18.0  19.0  20.0  21.0  22.0  23.0  24.0  25.0    26
# 1       18.0  19.0  20.0  21.0  22.0  23.0  24.0  25.0    26
# 2       17.0  18.0  19.0  20.0  21.0  22.0  23.0  24.0    25
# 3       20.0  21.0  22.0  23.0  24.0  25.0  26.0  27.0    28
# 4       18.0  19.0  20.0  21.0  22.0  23.0  24.0  25.0    26
# ...      ...   ...   ...   ...   ...   ...   ...   ...   ...
# 410773   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    15
# 410774   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    15
# 410775   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    13
# 410776   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    15
# 410777   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    10
#
# [410778 rows x 18 columns]

# %%
races = list(df_age_hpv['RACE_DESC'].unique())

# %%
def calamount(df,years,start,end):
    rate = []
    for year in years:
        lst = list(df[year])
        count = 0
        for i in range(len(lst)):
            if lst[i]:
                if lst[i]<=end and lst[i]>=start:
                    count += 1
#     print(count)
        rate.append(count)
    return rate

# %%
races = list(df_age_hpv['RACE_DESC'].unique())

def RaceCalAmount(df,years,races,start,end):
    
    race_val = {}
    for race in races:
        tmp_df = df[df['RACE_DESC']==race]
        amount = calamount(tmp_df,years,start,end)
        race_val[race] = np.array(amount)
    return race_val

# %%
hpv_amount = RaceCalAmount(df_age_hpv,years,races,9,13)
total_amount = RaceCalAmount(df_age_total,years,races,9,13)

rate = {}
for race in races:
    rate[race]=hpv_amount[race]/total_amount[race]
rate
# Out:
# {'WHITE': array([0.18503013, 0.1108175 , 0.08665307, 0.0919827 , 0.12153488,
#         0.16849308, 0.18807072, 0.2296961 , 0.27990512, 0.31743233,
#         0.36196036, 0.4060248 , 0.40525191, 0.38123002]),
#  'UNKNOWN': array([0.24015265, 0.15969287, 0.1332465 , 0.13904158, 0.17017917,
#         0.21297776, 0.24116653, 0.28274279, 0.32621073, 0.35696913,
#         0.38084414, 0.40688872, 0.38448668, 0.3601047 ]),
#  'OTHER': array([0.27071006, 0.19148936, 0.16872733, 0.19041605, 0.22296818,
#         0.27420018, 0.31709248, 0.37397988, 0.41853356, 0.45331126,
#         0.4941228 , 0.5321187 , 0.52715831, 0.51488331]),
#  'BLACK OR AFRICAN-AMERICAN': array([0.24145121, 0.18083938, 0.15917768, 0.16255918, 0.20355644,
#         0.25879244, 0.29531206, 0.36726406, 0.4318026 , 0.45340367,
#         0.49323033, 0.53872447, 0.53250261, 0.51943873]),
#  'ASIAN': array([0.21262887, 0.16042032, 0.14400189, 0.146573  , 0.19212572,
#         0.24635742, 0.2661332 , 0.32861317, 0.37828225, 0.40456473,
#         0.44409356, 0.48310676, 0.48842616, 0.4851972 ]),
#  'NATIVE HAWAIIAN OR OTHER PACIFIC': array([0.19125683, 0.14792899, 0.12393162, 0.13131313, 0.19807692,
#         0.28601253, 0.32121212, 0.32845188, 0.33870968, 0.38722555,
#         0.43444227, 0.44299065, 0.40858209, 0.43421053]),
#  'AMERICAN INDIAN OR ALASKA NATIVE': array([0.27950311, 0.18808777, 0.18297872, 0.18402778, 0.22063492,
#         0.2970451 , 0.36571429, 0.43508287, 0.45618557, 0.46041413,
#         0.52122642, 0.57670773, 0.61169591, 0.60906863])}

# %%
race
# Out:
# 'AMERICAN INDIAN OR ALASKA NATIVE'

# %%
pd.DataFrame(hpv_amount)
# Out:
#     WHITE  UNKNOWN  OTHER  BLACK OR AFRICAN-AMERICAN  ASIAN  \
# 0    2917     1762   1281                        579    330
# 1    3271     1851   1638                        823    458
# 2    3824     2046   2047                       1084    611
# 3    4829     2150   2714                       1339    772
# 4    6892     2479   3454                       1843   1137
# 5   10317     2931   4671                       2546   1657
# 6   12584     3283   6007                       3156   2062
# 7   16152     3942   7882                       4160   2924
# 8   19824     4870   9584                       5040   3616
# 9   21966     5724  10952                       5415   4006
# 10  24306     6199  12401                       5938   4500
# 11  26256     6450  13610                       6462   4833
# 12  25402     5745  13403                       6111   4832
# 13  23016     5228  12973                       5812   4638
#
#     NATIVE HAWAIIAN OR OTHER PACIFIC  AMERICAN INDIAN OR ALASKA NATIVE
# 0                                 35                                45
# 1                                 50                                60
# 2                                 58                                86
# 3                                 65                               106
# 4                                103                               139
# 5                                137                               191
# 6                                159                               256
# 7                                157                               315
# 8                                168                               354
# 9                                194                               378
# 10                               222                               442
# 11                               237                               515
# 12                               219                               523
# 13                               198                               497

# %%
cols = list(hpv_amount)
cols
# Out:
# ['WHITE',
#  'UNKNOWN',
#  'OTHER',
#  'BLACK OR AFRICAN-AMERICAN',
#  'ASIAN',
#  'NATIVE HAWAIIAN OR OTHER PACIFIC',
#  'AMERICAN INDIAN OR ALASKA NATIVE']

# %%
csv_df_total = {}
for i in range(len(years)):
    csv_df_total[years[i]]=[]
    for race in races:
        csv_df_total[years[i]].append(total_amount[race][i])
csv_df_total
# Out:
# {'2008': [15765, 7337, 4732, 2398, 1552, 183, 161],
#  '2009': [29517, 11591, 8554, 4551, 2855, 338, 319],
#  '2010': [44130, 15355, 12132, 6810, 4243, 468, 470],
#  '2011': [52499, 15463, 14253, 8237, 5267, 495, 576],
#  '2012': [56708, 14567, 15491, 9054, 5918, 520, 630],
#  '2013': [61231, 13762, 17035, 9838, 6726, 479, 643],
#  '2014': [66911, 13613, 18944, 10687, 7748, 495, 700],
#  '2015': [70319, 13942, 21076, 11327, 8898, 478, 724],
#  '2016': [70824, 14929, 22899, 11672, 9559, 496, 776],
#  '2017': [69199, 16035, 24160, 11943, 9902, 501, 821],
#  '2018': [67151, 16277, 25097, 12039, 10133, 511, 848],
#  '2019': [64666, 15852, 25577, 11995, 10004, 535, 893],
#  '2020': [62682, 14942, 25425, 11476, 9893, 536, 855],
#  '2021': [60373, 14518, 25196, 11189, 9559, 456, 816]}

# %%
csv_df_total['race'] = cols
csv_df_total=pd.DataFrame(csv_df_total)
col = list(csv_df_total.columns)
col = [col[-1]] + col[:-1]
csv_df_total = csv_df_total[col]
csv_df_total
# Out:
#                                race   2008   2009   2010   2011   2012   2013  \
# 0                             WHITE  15765  29517  44130  52499  56708  61231
# 1                           UNKNOWN   7337  11591  15355  15463  14567  13762
# 2                             OTHER   4732   8554  12132  14253  15491  17035
# 3         BLACK OR AFRICAN-AMERICAN   2398   4551   6810   8237   9054   9838
# 4                             ASIAN   1552   2855   4243   5267   5918   6726
# 5  NATIVE HAWAIIAN OR OTHER PACIFIC    183    338    468    495    520    479
# 6  AMERICAN INDIAN OR ALASKA NATIVE    161    319    470    576    630    643
#
#     2014   2015   2016   2017   2018   2019   2020   2021
# 0  66911  70319  70824  69199  67151  64666  62682  60373
# 1  13613  13942  14929  16035  16277  15852  14942  14518
# 2  18944  21076  22899  24160  25097  25577  25425  25196
# 3  10687  11327  11672  11943  12039  11995  11476  11189
# 4   7748   8898   9559   9902  10133  10004   9893   9559
# 5    495    478    496    501    511    535    536    456
# 6    700    724    776    821    848    893    855    816

# %%
csv_df_total.to_csv('../Data/total_population.csv',index=False)

# %%
csv_df_hpv = {}
for i in range(len(years)):
    csv_df_hpv[years[i]]=[]
    for race in races:
        csv_df_hpv[years[i]].append(hpv_amount[race][i])
csv_df_hpv
# Out:
# {'2008': [2917, 1762, 1281, 579, 330, 35, 45],
#  '2009': [3271, 1851, 1638, 823, 458, 50, 60],
#  '2010': [3824, 2046, 2047, 1084, 611, 58, 86],
#  '2011': [4829, 2150, 2714, 1339, 772, 65, 106],
#  '2012': [6892, 2479, 3454, 1843, 1137, 103, 139],
#  '2013': [10317, 2931, 4671, 2546, 1657, 137, 191],
#  '2014': [12584, 3283, 6007, 3156, 2062, 159, 256],
#  '2015': [16152, 3942, 7882, 4160, 2924, 157, 315],
#  '2016': [19824, 4870, 9584, 5040, 3616, 168, 354],
#  '2017': [21966, 5724, 10952, 5415, 4006, 194, 378],
#  '2018': [24306, 6199, 12401, 5938, 4500, 222, 442],
#  '2019': [26256, 6450, 13610, 6462, 4833, 237, 515],
#  '2020': [25402, 5745, 13403, 6111, 4832, 219, 523],
#  '2021': [23016, 5228, 12973, 5812, 4638, 198, 497]}

# %%
csv_df_hpv['race'] = cols

# %%
csv_df_hpv=pd.DataFrame(csv_df_hpv)

# %%
csv_df_hpv=pd.DataFrame(csv_df_hpv)
col = list(csv_df_hpv.columns)
col = [col[-1]] + col[:-1]
csv_df_hpv = csv_df_hpv[col]

# %%
csv_df_hpv.to_csv('../Data/race_hpv.csv',index=False)

# %%
pd.DataFrame(csv_df_hpv)
# Out:
#    2008  2009  2010  2011  2012   2013   2014   2015   2016   2017   2018  \
# 0  2917  3271  3824  4829  6892  10317  12584  16152  19824  21966  24306
# 1  1762  1851  2046  2150  2479   2931   3283   3942   4870   5724   6199
# 2  1281  1638  2047  2714  3454   4671   6007   7882   9584  10952  12401
# 3   579   823  1084  1339  1843   2546   3156   4160   5040   5415   5938
# 4   330   458   611   772  1137   1657   2062   2924   3616   4006   4500
# 5    35    50    58    65   103    137    159    157    168    194    222
# 6    45    60    86   106   139    191    256    315    354    378    442
#
#     2019   2020   2021                              race
# 0  26256  25402  23016                             WHITE
# 1   6450   5745   5228                           UNKNOWN
# 2  13610  13403  12973                             OTHER
# 3   6462   6111   5812         BLACK OR AFRICAN-AMERICAN
# 4   4833   4832   4638                             ASIAN
# 5    237    219    198  NATIVE HAWAIIAN OR OTHER PACIFIC
# 6    515    523    497  AMERICAN INDIAN OR ALASKA NATIVE

# %%
hpv_amount.keys()
# Out:
# dict_keys(['WHITE', 'UNKNOWN', 'OTHER', 'BLACK OR AFRICAN-AMERICAN', 'ASIAN', 'NATIVE HAWAIIAN OR OTHER PACIFIC', 'AMERICAN INDIAN OR ALASKA NATIVE'])

# %%
# years = list(grouped_tdap['vax_year'])

plt.figure(figsize=(10, 4))

# plt.plot(years, values0,'*-', color='black', label='Age 10')
# plt.plot(years, values1,'s-', color='blue', label='Age 11')
# plt.plot(years, values2,'o-', color='red', label='Age 12')
# plt.plot(years, values3,'^-', color='g', label='Age 13')
colors = ['#4B0082','#ee82ee','#0000FF','#00FF00','#FFFF00','#FF7F00','#FF0000']
for i in range(len(races)):
    plt.plot(years,rate[races[i]],'o-',color =colors[i],label = races[i] )
    
plt.xlabel('Vaccine Year')
plt.ylabel('Rate')
plt.title('Hpv vaccine towards tdap populations from 2008 to 2021 (Age 9 - 13)')

plt.xticks(years)
plt.legend()
# 
plt.grid(True,linestyle='--', color='gray', linewidth=0.5, alpha=0.5)

plt.show()

# %% [markdown]
# ## generate zipcode map used rate
