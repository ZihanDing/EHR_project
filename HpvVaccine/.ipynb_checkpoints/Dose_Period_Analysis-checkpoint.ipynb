# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt


from scipy import stats

import seaborn as sns

# %%
# Read Hpv data
file_address = '../Data/NassauCountyHPV.csv'

df_hpv_nassau = pd.read_csv(file_address)

file_address = '../Data/SuffolkCountyHPV.csv'

df_hpv_suffolk = pd.read_csv(file_address)

# Read TDAP data
file_address = '../Data/NassauCountyTDAP.csv'

df_tdap_nassau = pd.read_csv(file_address)

file_address = '../Data/SuffolkCountyTDAP.csv'

df_tdap_suffolk = pd.read_csv(file_address)


file_address = '../Data/longislandzip.csv'

df_zipcode = pd.read_csv(file_address)

# %%
file_address = '../Data/Ageout_hpv.csv'

df_age_hpv = pd.read_csv(file_address)


file_address = '../Data/Ageout_total.csv'

df_age_total = pd.read_csv(file_address)

# %%
# Clean Data , drop N/A zipcode
df_hpv_nassau.dropna(subset=['PatientZip'], inplace=True)
df_hpv_suffolk.dropna(subset=['PatientZip'], inplace=True)
df_tdap_nassau.dropna(subset=['PatientZip'], inplace=True)
df_tdap_suffolk.dropna(subset=['PatientZip'], inplace=True)


zips = np.array(df_zipcode['zip'])
# Clean Data, drop zipcode not on the Long Island
df_hpv_nassau = df_hpv_nassau[df_hpv_nassau['PatientZip'].isin(zips)]
df_hpv_suffolk = df_hpv_suffolk[df_hpv_suffolk['PatientZip'].isin(zips)]
df_tdap_nassau = df_tdap_nassau[df_tdap_nassau['PatientZip'].isin(zips)]
df_tdap_suffolk = df_tdap_suffolk[df_tdap_suffolk['PatientZip'].isin(zips)]

df_tdap = pd.concat([df_tdap_nassau,df_tdap_suffolk])

# %%
# Make data: I have 3 groups and 7 subgroups
group_names=['groupA', 'groupB', 'groupC']
group_size=[12,11,30]
subgroup_names=['A.1', 'A.2', 'A.3', 'B.1', 'B.2', 'C.1', 'C.2', 'C.3', 
'C.4', 'C.5']
subgroup_size=[4,3,5,6,5,10,5,5,4,6]

# Create colors
a, b, c=[plt.cm.Blues, plt.cm.Reds, plt.cm.Greens]

# First Ring (outside)
fig, ax = plt.subplots()
ax.axis('equal')
mypie, _ = ax.pie(group_size, radius=1.3-0.3, labels=group_names, labeldistance=0.65,colors= 
[a(0.6), b(0.6), c(0.6)] )
plt.setp( mypie, width=0.4, edgecolor='white')

# Second Ring (Inside)
mypie2, _ = ax.pie(subgroup_size, radius=1.3, 
labels=subgroup_names, labeldistance=0.85, colors=[a(0.5), a(0.4), 
a(0.3), b(0.5), b(0.4), c(0.6), c(0.5), c(0.4), c(0.3), c(0.2)])
plt.setp( mypie2, width=0.3, edgecolor='white')
plt.margins(0,0)

plt.legend(loc=(0.9, 0.1))
handles, labels = ax.get_legend_handles_labels()

ax.legend(handles[3:], subgroup_names_legs, loc=(0.9, 0.1))
plt.show()

# %% [markdown]
# ## TASK 1:  Split the dataset into 3 parts.
# 1. No hpv vaccine.
# 2. first dose before <15.
# 3. first dose after >= 15
# ### Those populations are based on all the patients from the whole datasets no matther which years.

# %%
has_empty=df_age_total['2021'].isna().any()
print('total populations until 2021 is',len(df_age_total),',has nan?',has_empty)
# Out:
# total populations until 2021 is 888277 ,has nan? False

# %%
df_hpv = pd.concat([df_hpv_nassau,df_hpv_suffolk])

# %%
# df_tdap = df_tdap.sort_values(by='vax_year',ascending=True)
df_hpv = df_hpv.sort_values(by=['vax_year','vax_month'],ascending=True)
# df=df.sort_values(by='vax_year',ascending=True)
df_hpv_distinct = df_hpv.drop_duplicates(subset = ['client_id'],keep='first')

# %%
df_filter_hpv= df_hpv_distinct[df_hpv_distinct['PatientAge']<15]

# %%
print('The number of populations received first hpv dose after Age 15:',len(df_hpv_distinct) - len(df_filter_hpv))
print('The number of populations received first hpv dose before Age 15:',len(df_filter_hpv))
print('The number of populations didn\'t receive hpv dose:',len(df_age_total) - len(df_hpv_distinct))
# Out:
# The number of populations received first hpv dose after Age 15: 138226
# The number of populations received first hpv dose before Age 15: 272552
# The number of populations didn't receive hpv dose: 477499

# %%
# 11-13 age group
labels = ["0 dose", "First dose < 15", "First dose >= 15"]
value = [len(df_age_total) - len(df_hpv_distinct),len(df_filter_hpv),len(df_hpv_distinct) - len(df_filter_hpv)]
colors = ["#B9DDF1", "#73A4CA", "#2E5B88"]

# Pie chart
fig, ax = plt.subplots()
ax.pie(value, labels = labels, colors = colors,autopct='%1.1f%%', labeldistance=0.4,
      wedgeprops = {"linewidth": 1, "edgecolor": "white"})
plt.title('Distribution of Hpv First dose Age')
# plt.show()
# Out:
# Text(0.5, 1.0, 'Distribution of Hpv First dose Age')

# %% [markdown]
# ## TASK 2: See the Distribution of Completeness in each Age Group
# 1. The age group is divided to < 15 and >= 15 groups
# 2. We can tell how many kids receive the complete serious of hpv vaccine

# %%
clients = np.array(df_hpv_distinct[(df_hpv_distinct['PatientAge']<15)]['client_id'])
clients = set(clients)

qual_patients_records = df_hpv[df_hpv['client_id'].isin(clients)]

grouped = qual_patients_records.groupby(['client_id']).size().reset_index(name='count')

group = grouped.groupby(['count']).size().reset_index(name='c')
group
# Out:
#    count       c
# 0      1   49312
# 1      2  163939
# 2      3   59301

# %%
clients = np.array(df_hpv_distinct[(df_hpv_distinct['PatientAge']<15)]['client_id'])
clients = set(clients)

qual_patients_records = df_hpv[df_hpv['client_id'].isin(clients)]

grouped = qual_patients_records.groupby(['client_id']).size().reset_index(name='count')

group = grouped.groupby(['count']).size().reset_index(name='c')
# group



labels = ["1 dose (incomplete)", "2 dose (complete)", "3 dose (complete)"]
value = list(group['c'])
print(value)
colors = ["#B9DDF1", "#73A4CA", "#2E5B88"]

# Pie chart
fig, ax = plt.subplots()
ax.pie(value, labels = labels, colors = colors,autopct='%1.1f%%', labeldistance=0.8,
      wedgeprops = {"linewidth": 1, "edgecolor": "white"})
plt.title('Distribution of Age < 15 kids Hpv Vaccine Completeness')
# plt.show()
# Out:
# [49312, 163939, 59301]
# Text(0.5, 1.0, 'Distribution of Age < 15 kids Hpv Vaccine Completeness')

# %%
clients = np.array(df_hpv_distinct[(df_hpv_distinct['PatientAge']>=15)]['client_id'])
clients = set(clients)

qual_patients_records = df_hpv[df_hpv['client_id'].isin(clients)]

grouped = qual_patients_records.groupby(['client_id']).size().reset_index(name='count')

group = grouped.groupby(['count']).size().reset_index(name='c')



labels = ["1 dose (incomplete)", "2 dose (incomplete)", "3 dose (complete)"]
value = list(group['c'])
print(value)
colors = ["#B9DDF1", "#73A4CA", "#2E5B88"]

# Pie chart
fig, ax = plt.subplots()
ax.pie(value, labels = labels, colors = colors,autopct='%1.1f%%', labeldistance=0.4,
      wedgeprops = {"linewidth": 1, "edgecolor": "white"})
plt.title('Distribution of Age >= 15 populations Hpv Vaccine Completeness')
# plt.show()
# Out:
# [38598, 37043, 64956]
# Text(0.5, 1.0, 'Distribution of Age >= 15 populations Hpv Vaccine Completeness')

# %%
# Make data: I have 3 groups and 7 subgroups
group_names=["0 dose", "1st dose < 15", "1st dose >= 15"]
group_size=[477499, 270181, 140597]
subgroup_names=['0 dose','1 dose', '2 dose', '3 dose', '1 dose', '2 dose', '3 dose']
subgroup_size=[477499,49312, 163025, 57844,38598, 37043, 64956]

# Create colors
a, b, c=[plt.cm.Blues, plt.cm.Reds, plt.cm.Greens]

# First Ring (inside)
fig, ax = plt.subplots()
ax.axis('equal')
mypie, _ = ax.pie(group_size, radius=1.4-0.4, labels=group_names, labeldistance=0.28,colors= 
[c(0.6), a(0.6), b(0.6)] )
plt.setp( mypie, width=0.4, edgecolor='white')

# Second Ring (outside)
mypie2, _ = ax.pie(subgroup_size, radius=1.4, 
labels=subgroup_names, labeldistance=0.8, colors=[c(0.5),a(0.5), a(0.4), 
a(0.3), b(0.5), b(0.4), b(0.3)])
plt.setp( mypie2, width=0.4, edgecolor='white')
plt.margins(0,0)

# plt.legend(loc=(0.9, 0.1))
handles, labels = ax.get_legend_handles_labels()

plt.title('Distribution of Hpv Vaccine Completeness and Age range',pad=40)
# plt.subplots_adjust(top=0.9) 

# ax.legend(handles[3:], subgroup_names_legs, loc=(0.9, 0.1))
plt.show()

# %% [markdown]
# ## TASK3 Analysis the gap between each dose.

# %%
clients = np.array(df_hpv_distinct[(df_hpv_distinct['PatientAge']<15)]['client_id'])
clients = set(clients)

patients_u14 = df_hpv[df_hpv['client_id'].isin(clients)]

# grouped = qual_patients_records.groupby(['client_id']).size().reset_index(name='count')
# grouped

# group = grouped.groupby(['count']).size().reset_index(name='c')

# %%
grouped = qual_patients_records.groupby(['client_id']).size().reset_index(name='count')

# %%
def SplitClientsByNumberOfDose(patients):
    lst_of_df = []
    grouped = patients.groupby(['client_id']).size().reset_index(name='count')
    print(grouped['count'].unique())
    numbers = list(grouped['count'].unique())
    lst_of_df.append(numbers)
    for number in numbers:
        clients = np.array(grouped[grouped['count']==number]['client_id'])
        clients = set(clients)
        lst_of_df.append(patients[patients['client_id'].isin(clients)]
                         .sort_values(by=['client_id','vax_year','vax_month'],ascending=True).reset_index())
    return lst_of_df,grouped

# %%
res,gp = SplitClientsByNumberOfDose(patients_u14)
# Out:
# [3 2 1]

# %%
print(len(res[0]),len(res[1]),len(res[2]),len(res[3]))
# Out:
# 3 177903 327878 49312

# %%
df = res[2]
df
# Out:
#         client_id  vax_month  vax_year RACE_DESC ETHNICITY_DESC  PatientAge  \
# 141766        NaN        NaN       NaN       NaN            NaN         NaN
# 195533        NaN        NaN       NaN       NaN            NaN         NaN
# 47134   2759913.0        NaN       NaN       NaN            NaN         NaN
# 93584   3029209.0        NaN       NaN       NaN            NaN         NaN
# 172386        NaN        NaN       NaN       NaN            NaN         NaN
# ...           ...        ...       ...       ...            ...         ...
# 118244  4238267.0        NaN       NaN       NaN            NaN         NaN
# 83792   2924580.0        NaN       NaN       NaN            NaN         NaN
# 118245  4238267.0        NaN       NaN       NaN            NaN         NaN
# 15413   2045008.0        NaN       NaN       NaN            NaN         NaN
# 16394   2053537.0        NaN       NaN       NaN            NaN         NaN
#
#        Trade_name  PatientZip PatientCounty ProviderCounty GENDER
# 141766        NaN         NaN           NaN            NaN    NaN
# 195533        NaN         NaN           NaN            NaN    NaN
# 47134         NaN         NaN           NaN            NaN    NaN
# 93584         NaN         NaN           NaN            NaN    NaN
# 172386        NaN         NaN           NaN            NaN    NaN
# ...           ...         ...           ...            ...    ...
# 118244        NaN         NaN           NaN            NaN    NaN
# 83792         NaN         NaN           NaN            NaN    NaN
# 118245        NaN         NaN           NaN            NaN    NaN
# 15413         NaN         NaN           NaN            NaN    NaN
# 16394         NaN         NaN           NaN            NaN    NaN
#
# [548894 rows x 11 columns]

# %%
# calculate gaps
df = res[2]
def calculateGaps(df,doses):
    gaps = []
    ages = []
    for i in range(0,len(df),doses):
    #     print(df['vax_year'][i+1])
        gap = (df['vax_year'][i+1]-df['vax_year'][i])*12 + df['vax_month'][i+1]-df['vax_month'][i]
    #     print(gap)
        ages.append(df['PatientAge'][i])
        gaps.append(gap)
    return np.array(gaps),np.array(ages)

# %%
gaps,ages = calculateGaps(res[2],2)
gaps.min()
# Out:
# 0

# %%
np.median(gaps)
# Out:
# 12.0

# %%
gaps.mean()
# Out:
# 12.77633754018263

# %%
(patients_u14['vax_year'][2+1]-patients_u14['vax_year'][2+1]+1)*12+patients_u14['vax_month'][2+1]
# Out:
# 17

# %%
plt.scatter(ages, gaps, label='Data Points',alpha = 0.5)


plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.title('Scatter Plot Example')


plt.legend()

plt.show()

# %%
legend_font = {"family": "Times New Roman", "size":10}
title_font = {"family": "Times New Roman", "size":15}

# %%
grouped = df.groupby('vax_year').size().reset_index(name='Count')
years = list(grouped['vax_year'])

age_data_by_year = list(df.groupby('vax_year')['PatientAge'].apply(list))
len(age_data_by_year[0])

data_to_plot = age_data_by_year

plt.figure(figsize=(9, 5))
# Create multiple boxplots
plt.boxplot(gaps)



# Customize the display with title and labels
plt.title('Patient Age Distribution (25% and 75%)',fontproperties = title_font)
plt.xlabel('Patient Age',fontproperties = title_font)
plt.ylabel('Year',fontproperties = title_font)
lambda_function = lambda x: x  
# array_from_lambda = np.array([lambda_function(x) for x in range(1, 15)])
# plt.xticks(array_from_lambda, years,fontproperties = legend_font)

# Show the plot
plt.show()

res = []
for i in range(len(data_to_plot)):
    res.append(int(np.median(data_to_plot[i])))
print(res)
# Out:
# [13, 13, 13, 13, 13, 13, 13, 13, 13, 12, 12, 12, 12, 13]

# %%
box_res[0]
# Out:
# [13, 68, 6, 48, 15, 20]

# %%
def cleanforbox(inp):
    res = []
    for lst in inp:
        data = np.array(lst)
        z_scores = np.abs(stats.zscore(data))
        threshold = 2  # 通常使用2或3作为阈值
        outlier_indices = np.where(z_scores > threshold)
        cleaned_data = data[(z_scores <= threshold)]
        res.append(cleaned_data)
    return res

# %%
box_res = [[],[],[],[],[],[],[]]
for i in range(len(ages)):
    box_res[ages[i]-8].append(gaps[i])
len(box_res[0])

box_clean=cleanforbox(box_res)

plt.figure(figsize=(10, 6))
sns.violinplot(data=box_clean[1:])

xtick = np.array(list(set(ages))[1:])

# 添加标题和轴标签
plt.title('1st and 2nd gaps within 2 dose schedule study')
plt.xticks(xtick-9,xtick)
plt.xlabel('Ages')
plt.ylabel('Months')
# Out:
# Text(0, 0.5, 'Months')

# %%
len(patients_u14)
# Out:
# 555093

# %%
patients_u14()

# %%
clients = np.array(df_hpv_distinct[(df_hpv_distinct['PatientAge']<15)]['client_id'])
clients = set(clients)

qual_patients_records = df_hpv[df_hpv['client_id'].isin(clients)]

grouped = qual_patients_records.groupby(['client_id']).size().reset_index(name='count')

group = grouped.groupby(['count']).size().reset_index(name='c')
# group



labels = ["1 dose (incomplete)", "2 dose (complete)", "3 dose (complete)"]
value = list(group['c'])
print(value)
colors = ["#B9DDF1", "#73A4CA", "#2E5B88"]

# Pie chart
fig, ax = plt.subplots()
ax.pie(value, labels = labels, colors = colors,autopct='%1.1f%%', labeldistance=0.8,
      wedgeprops = {"linewidth": 1, "edgecolor": "white"})
plt.title('Distribution of Age < 15 kids Hpv Vaccine Completeness')
# plt.show()
# Out:
# [49312, 163939, 59301]
# Text(0.5, 1.0, 'Distribution of Age < 15 kids Hpv Vaccine Completeness')

# %%
res=[0,0,0]
for i in gaps:
    if i <= 5:
        res[0] += 1
    elif i <= 12:
        res[1] += 1
#     elif i <= 36:
#         res[2] += 1
    else:
        res[2] +=1


labels = ["0-5 Months", "6-12 Months(Recommended)", "Over 1 Year"]
value = res
print(value)
colors = ["#B9DDF1", "#73A4CA", "#2E5B88"]

# Pie chart
fig, ax = plt.subplots()
ax.pie(value, labels = labels, colors = colors,autopct='%1.1f%%', labeldistance=0.8,
      wedgeprops = {"linewidth": 1, "edgecolor": "white"})
plt.title('Kids(under 15) Hpv Vaccine Gaps Between 1st and 2nd Dose')
# plt.show()
# Out:
# [8507, 96050, 59382]
# Text(0.5, 1.0, 'Kids(under 15) Hpv Vaccine Gaps Between 1st and 2nd Dose')

# %%
patients_u14
# Out:
#         client_id  vax_month  vax_year RACE_DESC      ETHNICITY_DESC  \
# 139        289434          1      2008     WHITE             UNKNOWN
# 518        609892          1      2008   UNKNOWN             UNKNOWN
# 528        609898          1      2008     OTHER  HISPANIC OR LATINO
# 574        609933          1      2008     OTHER  HISPANIC OR LATINO
# 575        609934          1      2008     ASIAN  HISPANIC OR LATINO
# ...           ...        ...       ...       ...                 ...
# 449374   23391819         12      2021     OTHER  HISPANIC OR LATINO
# 449386   23400371         12      2021     WHITE  HISPANIC OR LATINO
# 449387   23406579         12      2021     OTHER  HISPANIC OR LATINO
# 449393   23411001         12      2021     OTHER  HISPANIC OR LATINO
# 449485   23495650         12      2021     WHITE  HISPANIC OR LATINO
#
#         PatientAge  Trade_name  PatientZip PatientCounty ProviderCounty GENDER
# 139             13    Gardasil     11803.0        Nassau         Warren      F
# 518             11    Gardasil     11575.0        Nassau         Nassau      F
# 528             14    Gardasil     11575.0        Nassau         Nassau      F
# 574             13    Gardasil     11553.0        Nassau         Nassau      F
# 575             14    Gardasil     11801.0        Nassau         Nassau      F
# ...            ...         ...         ...           ...            ...    ...
# 449374          12  Gardasil 9     11941.0       Suffolk        Suffolk      F
# 449386          12  Gardasil 9     11967.0       Suffolk        Suffolk      F
# 449387          11  Gardasil 9     11704.0       Suffolk        Suffolk      F
# 449393          14  Gardasil 9     11784.0       Suffolk        Suffolk      F
# 449485          14  Gardasil 9     11776.0       Suffolk        Suffolk      M
#
# [555093 rows x 11 columns]

# %%
clients = np.array(df_hpv_distinct[(df_hpv_distinct['PatientAge']>=15)]['client_id'])
clients = set(clients)

qual_patients_records = df_hpv[df_hpv['client_id'].isin(clients)]

grouped = qual_patients_records.groupby(['client_id']).size().reset_index(name='count')

group = grouped.groupby(['count']).size().reset_index(name='c')

# %%
len(df_hpv_distinct)
# Out:
# 410778

# %%
len(grouped['client_id'].unique())
# Out:
# 410778

# %%
df_hpv_distinct = df_hpv_distinct.sort_values(by=['client_id'],ascending=True)
df_hpv_distinct=df_hpv_distinct.reset_index()
grouped = grouped.sort_values(by=['client_id'],ascending=True)
grouped = grouped.reset_index()

# %%
grouped = df_hpv.groupby(['client_id']).size().reset_index(name='count')
grouped
# Out:
#         client_id  count
# 0            9910      1
# 1           12409      2
# 2           21455      1
# 3           21656      2
# 4           25161      1
# ...           ...    ...
# 410773   23573852      2
# 410774   23574078      2
# 410775   23574745      2
# 410776   23577049      2
# 410777   23577071      2
#
# [410778 rows x 2 columns]

# %%
len(grouped['count'])
# Out:
# 410778

# %%
df_hpv_distinct['Doses'] = grouped['count']

# %%
df_hpv_distinct['Doses'].isna().any()
# Out:
# False

# %%
df_hpv_distinct
# Out:
#          index  client_id  vax_month  vax_year  \
# 0            0       9910          7      2017
# 1            1      12409          6      2019
# 2            3      21455          1      2013
# 3            4      21656          1      2008
# 4            6      25161          1      2008
# ...        ...        ...        ...       ...
# 410773  449589   23573852          8      2016
# 410774  449591   23574078          7      2018
# 410775  415192   23574745          7      2017
# 410776  415194   23577049         12      2019
# 410777  415196   23577071          6      2019
#
#                                RACE_DESC          ETHNICITY_DESC  PatientAge  \
# 0                                  WHITE  NOT HISPANIC OR LATINO          24
# 1                                  OTHER  NOT HISPANIC OR LATINO          22
# 2                                  ASIAN  NOT HISPANIC OR LATINO          17
# 3              BLACK OR AFRICAN-AMERICAN  NOT HISPANIC OR LATINO          15
# 4                                  WHITE  NOT HISPANIC OR LATINO          15
# ...                                  ...                     ...         ...
# 410773  NATIVE HAWAIIAN OR OTHER PACIFIC                 UNKNOWN          12
# 410774                             WHITE      HISPANIC OR LATINO          14
# 410775                           UNKNOWN                 UNKNOWN          12
# 410776                             WHITE  NOT HISPANIC OR LATINO          12
# 410777                             ASIAN  NOT HISPANIC OR LATINO          12
#
#          Trade_name  PatientZip PatientCounty ProviderCounty GENDER  Doses
# 0        Gardasil 9     11756.0        Nassau         Nassau      M      1
# 1          Gardasil     11590.0        Nassau         Nassau      M      2
# 2          Gardasil     11040.0        Nassau       New York      M      1
# 3          Gardasil     11520.0        Nassau         Broome      F      2
# 4          Gardasil     11561.0        Nassau         Cayuga      F      1
# ...             ...         ...           ...            ...    ...    ...
# 410773     Gardasil     11790.0       Suffolk        Suffolk      F      2
# 410774   Gardasil 9     11786.0       Suffolk        Suffolk      M      2
# 410775   Gardasil 9     11510.0        Nassau         Nassau      F      2
# 410776  Unspecified     11791.0        Nassau         Nassau      F      2
# 410777   Gardasil 9     11753.0        Nassau       New York      M      2
#
# [410778 rows x 13 columns]

# %%
import plotly.express as px
import numpy as np
df = px.data.gapminder().query("year == 2007")
fig = px.sunburst(df, path=['continent', 'country'], values='pop',
                  color='lifeExp', hover_data=['iso_alpha'],
                  color_continuous_scale='RdBu',
                  color_continuous_midpoint=np.average(df['lifeExp'], weights=df['pop']))
fig.show()
# Out:
# <div>                            <div id="a61b06ca-b41d-4451-a77b-d8327249b326" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a61b06ca-b41d-4451-a77b-d8327249b326")) {                    Plotly.newPlot(                        "a61b06ca-b41d-4451-a77b-d8327249b326",                        [{"branchvalues":"total","customdata":[["AFG",43.828],["ALB",76.423],["DZA",72.301],["AGO",42.731],["ARG",75.32],["AUS",81.235],["AUT",79.829],["BHR",75.635],["BGD",64.062],["BEL",79.441],["BEN",56.728],["BOL",65.554],["BIH",74.852],["BWA",50.728],["BRA",72.39],["BGR",73.005],["BFA",52.295],["BDI",49.58],["KHM",59.723],["CMR",50.43],["CAN",80.65300000000002],["CAF",44.74100000000001],["TCD",50.651],["CHL",78.553],["CHN",72.961],["COL",72.889],["COM",65.152],["COD",46.462],["COG",55.322],["CRI",78.782],["CIV",48.328],["HRV",75.748],["CUB",78.273],["CZE",76.486],["DNK",78.332],["DJI",54.791],["DOM",72.235],["ECU",74.994],["EGY",71.33800000000002],["SLV",71.878],["GNQ",51.57899999999999],["ERI",58.03999999999999],["ETH",52.947],["FIN",79.313],["FRA",80.65699999999998],["GAB",56.73500000000001],["GMB",59.448],["DEU",79.406],["GHA",60.02199999999999],["GRC",79.483],["GTM",70.259],["GIN",56.007],["GNB",46.38800000000001],["HTI",60.916],["HND",70.19800000000001],["HKG",82.208],["HUN",73.33800000000002],["ISL",81.757],["IND",64.69800000000001],["IDN",70.65],["IRN",70.964],["IRQ",59.545],["IRL",78.885],["ISR",80.745],["ITA",80.546],["JAM",72.567],["JPN",82.603],["JOR",72.535],["KEN",54.11],["KOR",67.297],["KOR",78.623],["KWT",77.58800000000002],["LBN",71.993],["LSO",42.592],["LBR",45.678],["LBY",73.952],["MDG",59.443000000000005],["MWI",48.303],["MYS",74.241],["MLI",54.467],["MRT",64.164],["MUS",72.801],["MEX",76.195],["MNG",66.803],["MNE",74.543],["MAR",71.164],["MOZ",42.082],["MMR",62.06900000000001],["NAM",52.90600000000001],["NPL",63.785],["NLD",79.762],["NZL",80.204],["NIC",72.899],["NER",56.867],["NGA",46.859],["NOR",80.196],["OMN",75.64],["PAK",65.483],["PAN",75.53699999999998],["PRY",71.752],["PER",71.421],["PHL",71.688],["POL",75.563],["PRT",78.098],["PRI",78.74600000000002],["REU",76.442],["ROU",72.476],["RWA",46.242],["STP",65.528],["SAU",72.777],["SEN",63.062],["SRB",74.002],["SLE",42.56800000000001],["SGP",79.972],["SVK",74.663],["SVN",77.926],["SOM",48.159],["ZAF",49.339],["ESP",80.941],["LKA",72.396],["SDN",58.55599999999999],["SWZ",39.613],["SWE",80.884],["CHE",81.70100000000002],["SYR",74.143],["TWN",78.4],["TZA",52.517],["THA",70.616],["TGO",58.42],["TTO",69.819],["TUN",73.923],["TUR",71.777],["UGA",51.542],["GBR",79.425],["USA",78.242],["URY",76.384],["VEN",73.747],["VNM",74.249],["PSE",73.422],["YEM",62.698],["ZMB",42.38399999999999],["ZWE",43.487],["(?)",54.56441057558197],["(?)",75.35668222743027],["(?)",69.44386304205017],["(?)",77.89057081069897],["(?)",81.06215400970112]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>pop=%{value}<br>parent=%{parent}<br>id=%{id}<br>iso_alpha=%{customdata[0]}<br>lifeExp=%{color}<extra></extra>","ids":["Asia/Afghanistan","Europe/Albania","Africa/Algeria","Africa/Angola","Americas/Argentina","Oceania/Australia","Europe/Austria","Asia/Bahrain","Asia/Bangladesh","Europe/Belgium","Africa/Benin","Americas/Bolivia","Europe/Bosnia and Herzegovina","Africa/Botswana","Americas/Brazil","Europe/Bulgaria","Africa/Burkina Faso","Africa/Burundi","Asia/Cambodia","Africa/Cameroon","Americas/Canada","Africa/Central African Republic","Africa/Chad","Americas/Chile","Asia/China","Americas/Colombia","Africa/Comoros","Africa/Congo, Dem. Rep.","Africa/Congo, Rep.","Americas/Costa Rica","Africa/Cote d'Ivoire","Europe/Croatia","Americas/Cuba","Europe/Czech Republic","Europe/Denmark","Africa/Djibouti","Americas/Dominican Republic","Americas/Ecuador","Africa/ ...

# %%
import plotly.graph_objects as go

fig = go.Figure(go.Sunburst(
    labels=["Parent", "Child 1", "Child 2", "Child 1.1", "Child 1.2", "Child 2.1"],
    parents=["", "Parent", "Parent", "Child 1", "Child 1", "Child 2"],
    values=[10, 20, 30, 40, 50, 60],
    marker=dict(
        colors=["blue", "red", "green", "yellow", "purple", "orange"],
        pattern="hourglass"  # Set the 'pattern' property for markers
    )
))

fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/6m/wc_77wtn3sd7gb5y6h6yz01w0000gn/T/ipykernel_40728/1112716863.py in <module>
#       1 import plotly.graph_objects as go
#       2
# ----> 3 fig = go.Figure(go.Sunburst(
#       4     labels=["Parent", "Child 1", "Child 2", "Child 1.1", "Child 1.2", "Child 2.1"],
#       5     parents=["", "Parent", "Parent", "Child 1", "Child 1", "Child 2"],
#
# ~/opt/anaconda3/lib/python3.9/site-packages/plotly/graph_objs/_sunburst.py in __init__(self, arg, branchvalues, count, customdata, customdatasrc, domain, hoverinfo, hoverinfosrc, hoverlabel, hovertemplate, hovertemplatesrc, hovertext, hovertextsrc, ids, idssrc, insidetextfont, insidetextorientation, labels, labelssrc, leaf, legendgrouptitle, legendrank, level, marker, maxdepth, meta, metasrc, name, opacity, outsidetextfont, parents, parentssrc, root, rotation, sort, stream, text, textfont, textinfo, textsrc, texttemplate, texttemplatesrc, uid, uirevision, values, valuessrc, visible, **kwargs)
#    2101         _v = marker if marker is not None else _v
#    2102         if _v is not None:
# -> 2103             self["marker"] = _v
#    2104         _v = arg.pop("maxdepth", None)
#    2105         _v = maxdepth if maxdepth is not None else _v
#
# ~/opt/anaconda3/lib/python3.9/site-packages/plotly/basedatatypes.py in __setitem__(self, prop, value)
#    4849                 # ### Handle compound property ###
#    4850                 if isinstance(validator, CompoundValidator):
# -> 4851                     self._set_compound_prop(prop, value)
#    4852
#    4853                 # ### Handle compound array property ###
#
# ~/opt/anaconda3/lib/python3.9/site-packages/plotly/basedatatypes.py in _set_compound_prop(self, prop, val)
#    5260         # ------------
#    5261         validator = self._get_validator(prop)
# -> 5262         val = validator.validate_coerce(val, skip_invalid=self._skip_invalid)
#    5263
#    5264         # Save deep copies of current and new states
#
# ~/opt/anaconda3/lib/python3.9/site-packages/_plotly_utils/basevalidators.py in validate_coerce(self, v, skip_invalid, _validate)
#    2453
#    2454         elif isinstance(v, dict):
# -> 2455             v = self.data_class(v, skip_invalid=skip_invalid, _validate=_validate)
#    2456
#    2457         elif isinstance(v, self.data_class):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/plotly/graph_objs/sunburst/_marker.py in __init__(self, arg, autocolorscale, cauto, cmax, cmid, cmin, coloraxis, colorbar, colors, colorscale, colorssrc, line, reversescale, showscale, **kwargs)
#     891         # Process unknown kwargs
#     892         # ----------------------
# --> 893         self._process_kwargs(**dict(arg, **kwargs))
#     894
#     895         # Reset skip_invalid
#
# ~/opt/anaconda3/lib/python3.9/site-packages/plotly/basedatatypes.py in _process_kwargs(self, **kwargs)
#    4375                 self[k] = v
#    4376             elif not self._skip_invalid:
# -> 4377                 raise err
#    4378         # No need to call _raise_on_invalid_property_error here,
#    4379         # because we have it set up so that the singular case of calling
#
# ValueError: Invalid property specified for object of type plotly.graph_objs.sunburst.Marker: 'pattern'
#
# Did you mean "cauto"?
#
#     Valid properties:
#         autocolorscale
#             Determines whether the colorscale is a default palette
#             (`autocolorscale: true`) or the palette determined by
#             `marker.colorscale`. Has an effect only if colors is
#             set to a numerical array. In case `colorscale` is
#             unspecified or `autocolorscale` is true, the default
#             palette will be chosen according to whether numbers in
#             the `color` array are all positive, all negative or
#             mixed.
#         cauto
#             Determines whether or not the color domain is computed
#             with respect to the input data (here colors) or the
#             bounds set in `marker.cmin` and `marker.cmax` Has an
#             effect only if colors is set to a numerical array.
#             Defaults to `false` when `marker.cmin` and
#             `marker.cmax` are set by the user.
#         cmax
#             Sets the upper bound of the color domain. Has an effect
#             only if colors is set to a numerical array. Value
#             should have the same units as colors and if set,
#             `marker.cmin` must be set as well.
#         cmid
#             Sets the mid-point of the color domain by scaling
#             `marker.cmin` and/or `marker.cmax` to be equidistant to
#             this point. Has an effect only if colors is set to a
#             numerical array. Value should have the same units as
#             colors. Has no effect when `marker.cauto` is `false`.
#         cmin
#             Sets the lower bound of the color domain. Has an effect
#             only if colors is set to a numerical array. Value
#             should have the same units as colors and if set,
#             `marker.cmax` must be set as well.
#         coloraxis
#             Sets a reference to a shared color axis. References to
#             these shared color axes are "coloraxis", "coloraxis2",
#             "coloraxis3", etc. Settings for these shared color axes
#             are set in the layout, under `layout.coloraxis`,
#             `layout.coloraxis2`, etc. Note that multiple color
#             scales can be linked to the same color axis.
#         colorbar
#             :class:`plotly.graph_objects.sunburst.marker.ColorBar`
#             instance or dict with compatible properties
#         colors
#             Sets the color of each sector of this trace. If not
#             specified, the default trace color set is used to pick
#             the sector colors.
#         colorscale
#             Sets the colorscale. Has an effect only if colors is
#             set to a numerical array. The colorscale must be an
#             array containing arrays mapping a normalized value to
#             an rgb, rgba, hex, hsl, hsv, or named color string. At
#             minimum, a mapping for the lowest (0) and highest (1)
#             values are required. For example, `[[0,
#             'rgb(0,0,255)'], [1, 'rgb(255,0,0)']]`. To control the
#             bounds of the colorscale in color space, use
#             `marker.cmin` and `marker.cmax`. Alternatively,
#             `colorscale` may be a palette name string of the
#             following list: Blackbody,Bluered,Blues,Cividis,Earth,E
#             lectric,Greens,Greys,Hot,Jet,Picnic,Portland,Rainbow,Rd
#             Bu,Reds,Viridis,YlGnBu,YlOrRd.
#         colorssrc
#             Sets the source reference on Chart Studio Cloud for
#             `colors`.
#         line
#             :class:`plotly.graph_objects.sunburst.marker.Line`
#             instance or dict with compatible properties
#         reversescale
#             Reverses the color mapping if true. Has an effect only
#             if colors is set to a numerical array. If true,
#             `marker.cmin` will correspond to the last color in the
#             array and `marker.cmax` will correspond to the first
#             color.
#         showscale
#             Determines whether or not a colorbar is displayed for
#             this trace. Has an effect only if colors is set to a
#             numerical array.
#
# Did you mean "cauto"?
#
# Bad property path:
# pattern
# ^^^^^^^

# %%
import pandas as pd

# Create a dictionary with sample data
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva'],
    'Age': [25, 30, 22, 35, 28],
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston', 'Miami']
}

# Create a DataFrame from the dictionary
df = pd.DataFrame(data)

df.set_index('Name', inplace=True)

# Display the DataFrame
df
# Out:
#          Age         City
# Name
# Alice     25     New York
# Bob       30  Los Angeles
# Charlie   22      Chicago
# David     35      Houston
# Eva       28        Miami

# %%
import pandas as pd

# Create a dictionary with sample data
data = {
    'Born': ['New York', 'Los Angeles', 'Chicago', 'Houston'],
    'Name': ['Bob', 'Charlie', 'David', 'Eva'],
#     'Age': [25, 30, 22, 35, 28],
#     'City': ['New York', 'Los Angeles', 'Chicago', 'Houston', 'Miami']
}

# Create a DataFrame from the dictionary
df1 = pd.DataFrame(data)

df1.set_index('Name', inplace=True)

# Display the DataFrame
df1
# Out:
#                 Born
# Name
# Bob         New York
# Charlie  Los Angeles
# David        Chicago
# Eva          Houston

# %%
df['born']=df1['Born']

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/6m/wc_77wtn3sd7gb5y6h6yz01w0000gn/T/ipykernel_67925/1396537375.py in <module>
# ----> 1 df
#
# NameError: name 'df' is not defined

# %% [markdown]
# gap between 1-2 have several types:
# 1. NaN ( they only have 1 dose, didn't have the 2 nd, so the gap will be nan)
# 2. interges:
#     a. they have 2 doses: 1 and 2 gap will be the whole series
#     b. they have 3 doses: 1,2,3, and thus will be the first part of the series

# %% [markdown]
# gap in the whole series have several types:
# 1. 0 they only have 1 doses
# 2. interges:
#     a. they have 2 doses: 1 and 2 gap will be the whole series
#     b. they have 3 doses: 1,2,3, and thus will be the gaps between 1 and 3

# %%
def calculate12Gaps(df,doses):
    gaps = []
    ages = []
    ids = []
    for i in range(0,len(df),doses):
    #     print(df['vax_year'][i+1])
        gap = (df['vax_year'][i+1]-df['vax_year'][i])*12 + df['vax_month'][i+1]-df['vax_month'][i]
    #     print(gap)
        ages.append(df['PatientAge'][i])
        gaps.append(gap)
        ids.append(df['client_id'][i])
    dct = {
        'gaps':gaps,
        'ages':ages,
        'client_id':ids
    }
    res = pd.DataFrame(dct)
    return res

# %%
def SplitClientsByNumberOfDose(patients):
    lst_of_df = []
    grouped = patients.groupby(['client_id']).size().reset_index(name='count')
    print(grouped['count'].unique())
    numbers = list(grouped['count'].unique())
    lst_of_df.append(numbers)
    for number in numbers:
        clients = np.array(grouped[grouped['count']==number]['client_id'])
        clients = set(clients)
        lst_of_df.append(patients[patients['client_id'].isin(clients)]
                         .sort_values(by=['client_id','vax_year','vax_month'],ascending=True).reset_index())
    return lst_of_df,grouped

# %%
len(patients_u14)
# Out:
# 555093

# %%
res,gp = SplitClientsByNumberOfDose(patients_u14)
# Out:
# [3 2 1]

# %%
res[1]
# Out:
#          index  client_id  vax_month  vax_year                  RACE_DESC  \
# 0            7      28751         12      2016  BLACK OR AFRICAN-AMERICAN
# 1            8      28751          3      2017  BLACK OR AFRICAN-AMERICAN
# 2            9      28751          6      2017  BLACK OR AFRICAN-AMERICAN
# 3            1      34816          9      2015                      WHITE
# 4            2      34816         11      2015                      WHITE
# ...        ...        ...        ...       ...                        ...
# 177898  415150   23557548          9      2013                      WHITE
# 177899  415151   23557548          1      2014                      WHITE
# 177900  449534   23559336          6      2013                      ASIAN
# 177901  449535   23559336         10      2013                      ASIAN
# 177902  449536   23559336          8      2014                      ASIAN
#
#                 ETHNICITY_DESC  PatientAge  Trade_name  PatientZip  \
# 0       NOT HISPANIC OR LATINO          11  Gardasil 9     11510.0
# 1       NOT HISPANIC OR LATINO          11  Gardasil 9     11510.0
# 2       NOT HISPANIC OR LATINO          11  Gardasil 9     11510.0
# 3       NOT HISPANIC OR LATINO          13    Gardasil     11950.0
# 4       NOT HISPANIC OR LATINO          13  Gardasil 9     11950.0
# ...                        ...         ...         ...         ...
# 177898  NOT HISPANIC OR LATINO          14    Gardasil     11758.0
# 177899  NOT HISPANIC OR LATINO          15    Gardasil     11758.0
# 177900  NOT HISPANIC OR LATINO          11    Gardasil     11755.0
# 177901  NOT HISPANIC OR LATINO          11    Gardasil     11755.0
# 177902  NOT HISPANIC OR LATINO          12    Gardasil     11755.0
#
#        PatientCounty ProviderCounty GENDER
# 0             Nassau         Nassau      M
# 1             Nassau         Nassau      M
# 2             Nassau         Nassau      M
# 3            Suffolk          Tioga      M
# 4            Suffolk          Tioga      M
# ...              ...            ...    ...
# 177898        Nassau         Nassau      M
# 177899        Nassau         Nassau      M
# 177900       Suffolk         Nassau      M
# 177901       Suffolk         Nassau      M
# 177902       Suffolk         Nassau      M
#
# [177903 rows x 12 columns]

# %%
len(res[1])
# Out:
# 177903

# %%
res1 = calculate12Gaps(res[2],2)

# %%
res1
# Out:
#         gaps  ages  client_id
# 0          5    14      35656
# 1         13    11      46635
# 2         13    12      47959
# 3         51    11      54798
# 4         88    11      67631
# ...      ...   ...        ...
# 163934    61    12   23573852
# 163935    12    14   23574078
# 163936    13    12   23574745
# 163937     6    12   23577049
# 163938     7    12   23577071
#
# [163939 rows x 3 columns]

# %%
df_hpv_distinct
# Out:
#          index  client_id  vax_month  vax_year  \
# 0            0       9910          7      2017
# 1            1      12409          6      2019
# 2            3      21455          1      2013
# 3            4      21656          1      2008
# 4            6      25161          1      2008
# ...        ...        ...        ...       ...
# 410773  449589   23573852          8      2016
# 410774  449591   23574078          7      2018
# 410775  415192   23574745          7      2017
# 410776  415194   23577049         12      2019
# 410777  415196   23577071          6      2019
#
#                                RACE_DESC          ETHNICITY_DESC  PatientAge  \
# 0                                  WHITE  NOT HISPANIC OR LATINO          24
# 1                                  OTHER  NOT HISPANIC OR LATINO          22
# 2                                  ASIAN  NOT HISPANIC OR LATINO          17
# 3              BLACK OR AFRICAN-AMERICAN  NOT HISPANIC OR LATINO          15
# 4                                  WHITE  NOT HISPANIC OR LATINO          15
# ...                                  ...                     ...         ...
# 410773  NATIVE HAWAIIAN OR OTHER PACIFIC                 UNKNOWN          12
# 410774                             WHITE      HISPANIC OR LATINO          14
# 410775                           UNKNOWN                 UNKNOWN          12
# 410776                             WHITE  NOT HISPANIC OR LATINO          12
# 410777                             ASIAN  NOT HISPANIC OR LATINO          12
#
#          Trade_name  PatientZip PatientCounty ProviderCounty GENDER  Doses
# 0        Gardasil 9     11756.0        Nassau         Nassau      M      1
# 1          Gardasil     11590.0        Nassau         Nassau      M      2
# 2          Gardasil     11040.0        Nassau       New York      M      1
# 3          Gardasil     11520.0        Nassau         Broome      F      2
# 4          Gardasil     11561.0        Nassau         Cayuga      F      1
# ...             ...         ...           ...            ...    ...    ...
# 410773     Gardasil     11790.0       Suffolk        Suffolk      F      2
# 410774   Gardasil 9     11786.0       Suffolk        Suffolk      M      2
# 410775   Gardasil 9     11510.0        Nassau         Nassau      F      2
# 410776  Unspecified     11791.0        Nassau         Nassau      F      2
# 410777   Gardasil 9     11753.0        Nassau       New York      M      2
#
# [410778 rows x 13 columns]

# %% [markdown]
# ## add another two columns: 1st2ndgap and wholegap

# %%
df_hpv_distinct=df_hpv_distinct.drop('index',axis=1)

# %%
df_hpv
# Out:
#         client_id  vax_month  vax_year                  RACE_DESC  \
# 4           21656          1      2008  BLACK OR AFRICAN-AMERICAN
# 6           25161          1      2008                      WHITE
# 31          85387          1      2008                      WHITE
# 92         240100          1      2008                      WHITE
# 139        289434          1      2008                      WHITE
# ...           ...        ...       ...                        ...
# 449498   23509433         12      2021                      OTHER
# 449516   23537004         12      2021                      OTHER
# 449517   23537126         12      2021                      WHITE
# 449567   23565457         12      2021                      WHITE
# 449579   23572398         12      2021                      OTHER
#
#                 ETHNICITY_DESC  PatientAge   Trade_name  PatientZip  \
# 4       NOT HISPANIC OR LATINO          15     Gardasil     11520.0
# 6       NOT HISPANIC OR LATINO          15     Gardasil     11561.0
# 31      NOT HISPANIC OR LATINO          16     Gardasil     11758.0
# 92      NOT HISPANIC OR LATINO          15     Gardasil     11530.0
# 139                    UNKNOWN          13     Gardasil     11803.0
# ...                        ...         ...          ...         ...
# 449498      HISPANIC OR LATINO          17   Gardasil 9     11939.0
# 449516      HISPANIC OR LATINO          17   Gardasil 9     11901.0
# 449517      HISPANIC OR LATINO          16   Gardasil 9     11746.0
# 449567      HISPANIC OR LATINO          15   Gardasil 9     11777.0
# 449579      HISPANIC OR LATINO          16  Unspecified     11722.0
#
#        PatientCounty ProviderCounty GENDER
# 4             Nassau         Broome      F
# 6             Nassau         Cayuga      F
# 31            Nassau      Jefferson      F
# 92            Nassau       Saratoga      F
# 139           Nassau         Warren      F
# ...              ...            ...    ...
# 449498       Suffolk        Suffolk      M
# 449516       Suffolk        Suffolk      M
# 449517       Suffolk        Suffolk      M
# 449567       Suffolk        Suffolk      M
# 449579       Suffolk        Suffolk      F
#
# [856446 rows x 11 columns]

# %%
df_hpv_distinct
# Out:
#         client_id  vax_month  vax_year                         RACE_DESC  \
# 0            9910          7      2017                             WHITE
# 1           12409          6      2019                             OTHER
# 2           21455          1      2013                             ASIAN
# 3           21656          1      2008         BLACK OR AFRICAN-AMERICAN
# 4           25161          1      2008                             WHITE
# ...           ...        ...       ...                               ...
# 410773   23573852          8      2016  NATIVE HAWAIIAN OR OTHER PACIFIC
# 410774   23574078          7      2018                             WHITE
# 410775   23574745          7      2017                           UNKNOWN
# 410776   23577049         12      2019                             WHITE
# 410777   23577071          6      2019                             ASIAN
#
#                 ETHNICITY_DESC  PatientAge   Trade_name  PatientZip  \
# 0       NOT HISPANIC OR LATINO          24   Gardasil 9     11756.0
# 1       NOT HISPANIC OR LATINO          22     Gardasil     11590.0
# 2       NOT HISPANIC OR LATINO          17     Gardasil     11040.0
# 3       NOT HISPANIC OR LATINO          15     Gardasil     11520.0
# 4       NOT HISPANIC OR LATINO          15     Gardasil     11561.0
# ...                        ...         ...          ...         ...
# 410773                 UNKNOWN          12     Gardasil     11790.0
# 410774      HISPANIC OR LATINO          14   Gardasil 9     11786.0
# 410775                 UNKNOWN          12   Gardasil 9     11510.0
# 410776  NOT HISPANIC OR LATINO          12  Unspecified     11791.0
# 410777  NOT HISPANIC OR LATINO          12   Gardasil 9     11753.0
#
#        PatientCounty ProviderCounty GENDER  Doses
# 0             Nassau         Nassau      M      1
# 1             Nassau         Nassau      M      2
# 2             Nassau       New York      M      1
# 3             Nassau         Broome      F      2
# 4             Nassau         Cayuga      F      1
# ...              ...            ...    ...    ...
# 410773       Suffolk        Suffolk      F      2
# 410774       Suffolk        Suffolk      M      2
# 410775        Nassau         Nassau      F      2
# 410776        Nassau         Nassau      F      2
# 410777        Nassau       New York      M      2
#
# [410778 rows x 12 columns]

# %%
res,gp = SplitClientsByNumberOfDose(df_hpv)
# Out:
# [1 2 3]

# %%
dose2
# Out:
#         gaps  ages  client_id
# 0          3    11      28751
# 1          3    16      33176
# 2          2    13      34816
# 3          3    11      53770
# 4         20    15      66483
# ...      ...   ...        ...
# 122795     2    14   23557548
# 122796     4    11   23559336
# 122797     2    25   23560177
# 122798    25    15   23562090
# 122799     6    15   23573127
#
# [122800 rows x 3 columns]

# %%
dose3 = calculate12Gaps(res[3],3)

# %%
dose2 = calculate12Gaps(res[2],2)

# %%
len(dose3)+len(dose2)+len(res[1])
# Out:
# 410778

# %%
dose12 = pd.concat([dose3,dose2])

# %%
dose12.set_index('client_id', inplace=True)

# %%
df_hpv_distinct.set_index('client_id',inplace = True)

# %%
dose12
# Out:
#            gaps  ages
# client_id
# 28751         3    11
# 33176         3    16
# 34816         2    13
# 53770         3    11
# 66483        20    15
# ...         ...   ...
# 23573852     61    12
# 23574078     12    14
# 23574745     13    12
# 23577049      6    12
# 23577071      7    12
#
# [322868 rows x 2 columns]

# %%
df_hpv_distinct['dose12gap'] = dose12['gaps']

# %%
df_hpv_distinct
# Out:
#            vax_month  vax_year                         RACE_DESC  \
# client_id
# 9910               7      2017                             WHITE
# 12409              6      2019                             OTHER
# 21455              1      2013                             ASIAN
# 21656              1      2008         BLACK OR AFRICAN-AMERICAN
# 25161              1      2008                             WHITE
# ...              ...       ...                               ...
# 23573852           8      2016  NATIVE HAWAIIAN OR OTHER PACIFIC
# 23574078           7      2018                             WHITE
# 23574745           7      2017                           UNKNOWN
# 23577049          12      2019                             WHITE
# 23577071           6      2019                             ASIAN
#
#                    ETHNICITY_DESC  PatientAge   Trade_name  PatientZip  \
# client_id
# 9910       NOT HISPANIC OR LATINO          24   Gardasil 9     11756.0
# 12409      NOT HISPANIC OR LATINO          22     Gardasil     11590.0
# 21455      NOT HISPANIC OR LATINO          17     Gardasil     11040.0
# 21656      NOT HISPANIC OR LATINO          15     Gardasil     11520.0
# 25161      NOT HISPANIC OR LATINO          15     Gardasil     11561.0
# ...                           ...         ...          ...         ...
# 23573852                  UNKNOWN          12     Gardasil     11790.0
# 23574078       HISPANIC OR LATINO          14   Gardasil 9     11786.0
# 23574745                  UNKNOWN          12   Gardasil 9     11510.0
# 23577049   NOT HISPANIC OR LATINO          12  Unspecified     11791.0
# 23577071   NOT HISPANIC OR LATINO          12   Gardasil 9     11753.0
#
#           PatientCounty ProviderCounty GENDER  Doses  dose12gap
# client_id
# 9910             Nassau         Nassau      M      1        NaN
# 12409            Nassau         Nassau      M      2        2.0
# 21455            Nassau       New York      M      1        NaN
# 21656            Nassau         Broome      F      2        4.0
# 25161            Nassau         Cayuga      F      1        NaN
# ...                 ...            ...    ...    ...        ...
# 23573852        Suffolk        Suffolk      F      2       61.0
# 23574078        Suffolk        Suffolk      M      2       12.0
# 23574745         Nassau         Nassau      F      2       13.0
# 23577049         Nassau         Nassau      F      2        6.0
# 23577071         Nassau       New York      M      2        7.0
#
# [410778 rows x 12 columns]

# %%
df_hpv_distinct.reset_index(inplace=True)

# %%
df_hpv_distinct
# Out:
#         client_id  vax_month  vax_year                         RACE_DESC  \
# 0            9910          7      2017                             WHITE
# 1           12409          6      2019                             OTHER
# 2           21455          1      2013                             ASIAN
# 3           21656          1      2008         BLACK OR AFRICAN-AMERICAN
# 4           25161          1      2008                             WHITE
# ...           ...        ...       ...                               ...
# 410773   23573852          8      2016  NATIVE HAWAIIAN OR OTHER PACIFIC
# 410774   23574078          7      2018                             WHITE
# 410775   23574745          7      2017                           UNKNOWN
# 410776   23577049         12      2019                             WHITE
# 410777   23577071          6      2019                             ASIAN
#
#                 ETHNICITY_DESC  PatientAge   Trade_name  PatientZip  \
# 0       NOT HISPANIC OR LATINO          24   Gardasil 9     11756.0
# 1       NOT HISPANIC OR LATINO          22     Gardasil     11590.0
# 2       NOT HISPANIC OR LATINO          17     Gardasil     11040.0
# 3       NOT HISPANIC OR LATINO          15     Gardasil     11520.0
# 4       NOT HISPANIC OR LATINO          15     Gardasil     11561.0
# ...                        ...         ...          ...         ...
# 410773                 UNKNOWN          12     Gardasil     11790.0
# 410774      HISPANIC OR LATINO          14   Gardasil 9     11786.0
# 410775                 UNKNOWN          12   Gardasil 9     11510.0
# 410776  NOT HISPANIC OR LATINO          12  Unspecified     11791.0
# 410777  NOT HISPANIC OR LATINO          12   Gardasil 9     11753.0
#
#        PatientCounty ProviderCounty GENDER  Doses  dose12gap
# 0             Nassau         Nassau      M      1        NaN
# 1             Nassau         Nassau      M      2        2.0
# 2             Nassau       New York      M      1        NaN
# 3             Nassau         Broome      F      2        4.0
# 4             Nassau         Cayuga      F      1        NaN
# ...              ...            ...    ...    ...        ...
# 410773       Suffolk        Suffolk      F      2       61.0
# 410774       Suffolk        Suffolk      M      2       12.0
# 410775        Nassau         Nassau      F      2       13.0
# 410776        Nassau         Nassau      F      2        6.0
# 410777        Nassau       New York      M      2        7.0
#
# [410778 rows x 13 columns]

# %%
def calculate13Gaps(df,doses):
    gaps = []
    ages = []
    ids = []
    for i in range(0,len(df),doses):
    #     print(df['vax_year'][i+1])
        gap = (df['vax_year'][i+2]-df['vax_year'][i])*12 + df['vax_month'][i+2]-df['vax_month'][i]
    #     print(gap)
        ages.append(df['PatientAge'][i])
        gaps.append(gap)
        ids.append(df['client_id'][i])
    dct = {
        'gaps':gaps,
        'ages':ages,
        'client_id':ids
    }
    res = pd.DataFrame(dct)
    return res

# %%
dose3w = calculate13Gaps(res[3],3)

# %%
dose3w
# Out:
#         gaps  ages  client_id
# 0          6    11      28751
# 1          6    16      33176
# 2          8    13      34816
# 3          6    11      53770
# 4         29    15      66483
# ...      ...   ...        ...
# 122795     6    14   23557548
# 122796    14    11   23559336
# 122797    19    25   23560177
# 122798    37    15   23562090
# 122799    12    15   23573127
#
# [122800 rows x 3 columns]

# %%
dosewhole = pd.concat([dose2,dose3w])

# %%
df_hpv_distinct.set_index('client_id',inplace = True)
dosewhole.set_index('client_id',inplace = True)

# %%
df_hpv_distinct['wholeSeriesGap'] = dosewhole['gaps']

# %%
df_hpv_distinct.reset_index(inplace=True)

# %%
df_hpv_distinct
# Out:
#         client_id  vax_month  vax_year                         RACE_DESC  \
# 0            9910          7      2017                             WHITE
# 1           12409          6      2019                             OTHER
# 2           21455          1      2013                             ASIAN
# 3           21656          1      2008         BLACK OR AFRICAN-AMERICAN
# 4           25161          1      2008                             WHITE
# ...           ...        ...       ...                               ...
# 410773   23573852          8      2016  NATIVE HAWAIIAN OR OTHER PACIFIC
# 410774   23574078          7      2018                             WHITE
# 410775   23574745          7      2017                           UNKNOWN
# 410776   23577049         12      2019                             WHITE
# 410777   23577071          6      2019                             ASIAN
#
#                 ETHNICITY_DESC  PatientAge   Trade_name  PatientZip  \
# 0       NOT HISPANIC OR LATINO          24   Gardasil 9     11756.0
# 1       NOT HISPANIC OR LATINO          22     Gardasil     11590.0
# 2       NOT HISPANIC OR LATINO          17     Gardasil     11040.0
# 3       NOT HISPANIC OR LATINO          15     Gardasil     11520.0
# 4       NOT HISPANIC OR LATINO          15     Gardasil     11561.0
# ...                        ...         ...          ...         ...
# 410773                 UNKNOWN          12     Gardasil     11790.0
# 410774      HISPANIC OR LATINO          14   Gardasil 9     11786.0
# 410775                 UNKNOWN          12   Gardasil 9     11510.0
# 410776  NOT HISPANIC OR LATINO          12  Unspecified     11791.0
# 410777  NOT HISPANIC OR LATINO          12   Gardasil 9     11753.0
#
#        PatientCounty ProviderCounty GENDER  Doses  dose12gap  wholeSeriesGap
# 0             Nassau         Nassau      M      1        NaN             NaN
# 1             Nassau         Nassau      M      2        2.0             2.0
# 2             Nassau       New York      M      1        NaN             NaN
# 3             Nassau         Broome      F      2        4.0             4.0
# 4             Nassau         Cayuga      F      1        NaN             NaN
# ...              ...            ...    ...    ...        ...             ...
# 410773       Suffolk        Suffolk      F      2       61.0            61.0
# 410774       Suffolk        Suffolk      M      2       12.0            12.0
# 410775        Nassau         Nassau      F      2       13.0            13.0
# 410776        Nassau         Nassau      F      2        6.0             6.0
# 410777        Nassau       New York      M      2        7.0             7.0
#
# [410778 rows x 14 columns]

# %%
df_hpv_distinct[df_hpv_distinct['Doses'] == 3]
# Out:
#         client_id  vax_month  vax_year                  RACE_DESC  \
# 5           28751         12      2016  BLACK OR AFRICAN-AMERICAN
# 6           33176          9      2017  BLACK OR AFRICAN-AMERICAN
# 7           34816          9      2015                      WHITE
# 16          53770          9      2008                    UNKNOWN
# 18          66483          2      2017                      WHITE
# ...           ...        ...       ...                        ...
# 410711   23557548          7      2013                      WHITE
# 410718   23559336          6      2013                      ASIAN
# 410722   23560177          5      2019                      WHITE
# 410733   23562090          8      2018                      OTHER
# 410766   23573127          7      2015                      WHITE
#
#                 ETHNICITY_DESC  PatientAge  Trade_name  PatientZip  \
# 5       NOT HISPANIC OR LATINO          11  Gardasil 9     11510.0
# 6       NOT HISPANIC OR LATINO          16    Gardasil     11510.0
# 7       NOT HISPANIC OR LATINO          13    Gardasil     11950.0
# 16                     UNKNOWN          11    Gardasil     11722.0
# 18      NOT HISPANIC OR LATINO          15  Gardasil 9     11572.0
# ...                        ...         ...         ...         ...
# 410711  NOT HISPANIC OR LATINO          14    Gardasil     11758.0
# 410718  NOT HISPANIC OR LATINO          11    Gardasil     11755.0
# 410722  NOT HISPANIC OR LATINO          25  Gardasil 9     11040.0
# 410733  NOT HISPANIC OR LATINO          15  Gardasil 9     11720.0
# 410766      HISPANIC OR LATINO          15    Gardasil     11001.0
#
#        PatientCounty ProviderCounty GENDER  Doses  dose12gap  wholeSeriesGap
# 5             Nassau         Nassau      M      3        3.0             6.0
# 6             Nassau         Nassau      F      3        3.0             6.0
# 7            Suffolk          Tioga      M      3        2.0             8.0
# 16           Suffolk        Suffolk      F      3        3.0             6.0
# 18            Nassau         Nassau      F      3       20.0            29.0
# ...              ...            ...    ...    ...        ...             ...
# 410711        Nassau         Nassau      M      3        2.0             6.0
# 410718       Suffolk         Nassau      M      3        4.0            14.0
# 410722        Nassau         Nassau      F      3        2.0            19.0
# 410733       Suffolk        Suffolk      F      3       25.0            37.0
# 410766        Nassau         Nassau      F      3        6.0            12.0
#
# [122800 rows x 14 columns]

# %%
df_hpv_distinct.to_csv('../Data/distinct_hpv_patients.csv', index=False)

# %% [markdown]
# ## Start new line

# %%
df_hpv_distinct = pd.read_csv('../Data/distinct_hpv_patients.csv')

# %%
df_hpv_distinct
# Out:
#         client_id  vax_month  vax_year                         RACE_DESC  \
# 0            9910          7      2017                             WHITE
# 1           12409          6      2019                             OTHER
# 2           21455          1      2013                             ASIAN
# 3           21656          1      2008         BLACK OR AFRICAN-AMERICAN
# 4           25161          1      2008                             WHITE
# ...           ...        ...       ...                               ...
# 410773   23573852          8      2016  NATIVE HAWAIIAN OR OTHER PACIFIC
# 410774   23574078          7      2018                             WHITE
# 410775   23574745          7      2017                           UNKNOWN
# 410776   23577049         12      2019                             WHITE
# 410777   23577071          6      2019                             ASIAN
#
#                 ETHNICITY_DESC  PatientAge   Trade_name  PatientZip  \
# 0       NOT HISPANIC OR LATINO          24   Gardasil 9     11756.0
# 1       NOT HISPANIC OR LATINO          22     Gardasil     11590.0
# 2       NOT HISPANIC OR LATINO          17     Gardasil     11040.0
# 3       NOT HISPANIC OR LATINO          15     Gardasil     11520.0
# 4       NOT HISPANIC OR LATINO          15     Gardasil     11561.0
# ...                        ...         ...          ...         ...
# 410773                 UNKNOWN          12     Gardasil     11790.0
# 410774      HISPANIC OR LATINO          14   Gardasil 9     11786.0
# 410775                 UNKNOWN          12   Gardasil 9     11510.0
# 410776  NOT HISPANIC OR LATINO          12  Unspecified     11791.0
# 410777  NOT HISPANIC OR LATINO          12   Gardasil 9     11753.0
#
#        PatientCounty ProviderCounty GENDER  Doses  dose12gap  wholeSeriesGap
# 0             Nassau         Nassau      M      1        NaN             NaN
# 1             Nassau         Nassau      M      2        2.0             2.0
# 2             Nassau       New York      M      1        NaN             NaN
# 3             Nassau         Broome      F      2        4.0             4.0
# 4             Nassau         Cayuga      F      1        NaN             NaN
# ...              ...            ...    ...    ...        ...             ...
# 410773       Suffolk        Suffolk      F      2       61.0            61.0
# 410774       Suffolk        Suffolk      M      2       12.0            12.0
# 410775        Nassau         Nassau      F      2       13.0            13.0
# 410776        Nassau         Nassau      F      2        6.0             6.0
# 410777        Nassau       New York      M      2        7.0             7.0
#
# [410778 rows x 14 columns]

# %%
df_hpv_distinct[df_hpv_distinct['Doses'] == 3]
# Out:
#         client_id  vax_month  vax_year                  RACE_DESC  \
# 5           28751         12      2016  BLACK OR AFRICAN-AMERICAN
# 6           33176          9      2017  BLACK OR AFRICAN-AMERICAN
# 7           34816          9      2015                      WHITE
# 16          53770          9      2008                    UNKNOWN
# 18          66483          2      2017                      WHITE
# ...           ...        ...       ...                        ...
# 410711   23557548          7      2013                      WHITE
# 410718   23559336          6      2013                      ASIAN
# 410722   23560177          5      2019                      WHITE
# 410733   23562090          8      2018                      OTHER
# 410766   23573127          7      2015                      WHITE
#
#                 ETHNICITY_DESC  PatientAge  Trade_name  PatientZip  \
# 5       NOT HISPANIC OR LATINO          11  Gardasil 9     11510.0
# 6       NOT HISPANIC OR LATINO          16    Gardasil     11510.0
# 7       NOT HISPANIC OR LATINO          13    Gardasil     11950.0
# 16                     UNKNOWN          11    Gardasil     11722.0
# 18      NOT HISPANIC OR LATINO          15  Gardasil 9     11572.0
# ...                        ...         ...         ...         ...
# 410711  NOT HISPANIC OR LATINO          14    Gardasil     11758.0
# 410718  NOT HISPANIC OR LATINO          11    Gardasil     11755.0
# 410722  NOT HISPANIC OR LATINO          25  Gardasil 9     11040.0
# 410733  NOT HISPANIC OR LATINO          15  Gardasil 9     11720.0
# 410766      HISPANIC OR LATINO          15    Gardasil     11001.0
#
#        PatientCounty ProviderCounty GENDER  Doses  dose12gap  wholeSeriesGap
# 5             Nassau         Nassau      M      3        3.0             6.0
# 6             Nassau         Nassau      F      3        3.0             6.0
# 7            Suffolk          Tioga      M      3        2.0             8.0
# 16           Suffolk        Suffolk      F      3        3.0             6.0
# 18            Nassau         Nassau      F      3       20.0            29.0
# ...              ...            ...    ...    ...        ...             ...
# 410711        Nassau         Nassau      M      3        2.0             6.0
# 410718       Suffolk         Nassau      M      3        4.0            14.0
# 410722        Nassau         Nassau      F      3        2.0            19.0
# 410733       Suffolk        Suffolk      F      3       25.0            37.0
# 410766        Nassau         Nassau      F      3        6.0            12.0
#
# [122800 rows x 14 columns]

# %%
df_u14_distinct_3_dose = df_hpv_distinct[df_hpv_distinct['PatientAge'] <= 14]

# %%
df_u14_distinct_3_dose = df_u14_distinct_3_dose[df_u14_distinct_3_dose['Doses']==3]

# %%
gaps = np.array(df_u14_distinct_3_dose['dose12gap'])
ages = np.array(df_u14_distinct_3_dose['PatientAge'])
ages
# Out:
# array([11, 13, 11, ..., 14, 14, 11])
